# %%
import json
import pandas as pd
import requests
import datetime
from binance import Client
import matplotlib.pyplot as plt
import numpy as np
import os
from binance.client import Client
import datetime, time
from datetime import datetime
from numba import jit
import math

# %% [markdown]
# # Бэктест_начало

# %%
################### Задаем даты начала и конца бектеста ###############
start_date = '12/01/2020'
end_date = '26/12/2020'
################## Инициализация параметров обучения ######################
n_info = 12 # часов для обучения (не совсем обучение, скорее зависимая часть, задает инертность)
n_forcast = 24 # на какой период предсказываем
intervals_in_hour = 12 # какими интервалами оперируем здесь 12 - 5 минутки

################## Указываем ожидаемую доходность ##################
IR = 0.3 # ежедневная доходность выраженная в процентах

# %%
def GetHistoricalData(symbol, interval, fromDate, toDate):
    klines = client.get_historical_klines(symbol, interval, fromDate, toDate)
    df = pd.DataFrame(klines, columns=['dateTime', 'open', 'high', 'low', 'close', 'volume', 'closeTime', 'quoteAssetVolume', 'numberOfTrades', 'takerBuyBaseVol', 'takerBuyQuoteVol', 'ignore'])
    df.dateTime = pd.to_datetime(df.dateTime, unit='ms')
    df['date'] = df.dateTime.dt.strftime("%d/%m/%Y")
    df['time'] = df.dateTime.dt.strftime("%H:%M:%S")
    df = df.drop(['dateTime', 'closeTime', 'quoteAssetVolume', 'numberOfTrades', 'takerBuyBaseVol','takerBuyQuoteVol', 'ignore'], axis=1)
    column_names = ["date", "time", "open","close", "high", "low", "volume"]
    df = df.reindex(columns=column_names)
    return df
    
api_key = ""
api_secret = ""
client = Client(api_key, api_secret)


fromDate = str(datetime.strptime(start_date, '%d/%m/%Y'))
toDate = str(datetime.strptime(end_date, '%d/%m/%Y'))
symbol = "ETHUSDT"
interval = Client.KLINE_INTERVAL_5MINUTE
df = GetHistoricalData(symbol, interval, fromDate, toDate)

# %% [markdown]
# ## Определим функции прибыли:
# Пока они вне класса, нужно внести их.

# %%
def unforward_earnings(start_price, end_price, high_board, low_board):
    """Функция должна получить всю необходимую информацию и возвратить итоговую прибыль-убыток в пуле.
    Тут не учитываются заработанные комиссии. Только изменение стоимости токенов и их соотношение"""
    # Если после 24(или другого) периода цена оказалась выше изначальной
    p_ETH = (high_board-start_price)/(high_board-low_board)# доля ETH
    p_USDT = (1-p_ETH)# доля USDT
    if end_price >= start_price:
        if end_price >= high_board:
            res = ((high_board-start_price)/2+start_price)/start_price*p_ETH+p_USDT
        else:
            p = (end_price-start_price)/(high_board-start_price) # доля проданного ETH
            a1 = ((end_price-start_price)/2+start_price)/start_price*p*p_ETH
            a2 = p_USDT
            a3 = p_ETH*(1-p)*(end_price)/start_price #непроданный ETH
            res =  a1+a2+a3
    elif end_price < start_price:
        if end_price <= low_board:
            res = (p_USDT/(low_board+(start_price - low_board)/2)+p_ETH/start_price)*end_price
        else:
            p = (start_price-end_price)/(start_price-low_board) # доля обменянных долларов
            a1 = p_USDT*p/(end_price+(start_price - end_price)/2)*end_price# сумма от обменянных долларов
            a2 = p_USDT*(1-p) # остатки долларов
            a3 = p_ETH*end_price/start_price# изначальный подешевевший эфир
            res =  a1+a2+a3
    return (res-1)*100 # возвращаем результат в процентах!

def simple_hedge(start_price, end_price, ratio):
    '''Данная функция принимает начальную и конечную стоимость. А так же параметры хеджирования - долю хеджа
    Возвращает процентный заработок/убыток из за хеджа в % '''
    res = -(end_price-start_price)/start_price
    return res*100*ratio


def return_curent_eth(start_price, end_price, high_board, low_board, eth_pool, usd_pool):
    '''Функция возвращает количество эфира для хеджа, в долларах'''
    # Исходим из того, что равномерно размазаны именно доллары! И эфир в тиках в долларах
    if end_price >= start_price:
        if end_price >= high_board:
            # у нас только usdt
            res = 0
        else:
            p = (end_price-start_price)/(high_board-start_price) # доля проданного ETH (в долларах)
            res = eth_pool*(1-p)
    elif end_price < start_price:
        if end_price <= low_board:
            # долларов нет, все это эфир
            res = usd_pool+eth_pool # в результате имеем старый и новый эфир
        else:
            # рассчитаем сколько долларов стали ETH
            p = (start_price-end_price)/(start_price-low_board)# доля обменянных долларов
            res =  p*usd_pool+eth_pool
    return res


def dynamic_hedge(eth_pool, usd_pool, high_board,
                                   low_board, start_price, end_price, index, dict_res, n_forcast,
                  intervals_in_hour, n_info):
    """Будет делать рехедж n раз за все время
    Для этого нам потребуется open, close за все время сидения в пуле
    Изначально хеджируется весь эфир, затем, вместе с движением цены изменяется доля эфира в пуле.
    Требуется изменять хедж.
    Поскольку мы принебрегаем комиссиями, в данной реализации, считаем,
    что каждый раз мы закрываем позицию и открываем новую на другую сумму
    """
    n_rehedge = 3 # сколько раз делаеся рехедж
    # преобразуем индекс (сложная штука из за того, что до этого использовали каждую 24*12 строчку)
    i = index*n_forcast*intervals_in_hour # получаем индекс в массиве всех строк
    index_in_dict_res = i+intervals_in_hour*n_info # тут i это сплошной, 

    open_prices = dict_res[index_in_dict_res][1]['open'].values.astype(float)
    close_prices = dict_res[index_in_dict_res][1]['close'].values.astype(float)
    leverage = 1
    current_hedge = eth_pool
    money = eth_pool
    start_price0 = start_price
    for i in range(1, n_rehedge+2):
         # 1 - закрываем позицю по хеджу, фиксируем прибыль/убытки
        # 2 - считаем размер новой позиции. Тут потребуется плечо - то есть его рассчет и использование
        # перезаписываем текущую позицию
         
        # смотрим цену закрытия
        ind = i*n_forcast*intervals_in_hour/(n_rehedge+1)-1 # 5минутка для закрытия позиции
        ind = int(ind)
        close_price = close_prices[ind]
        # считаем доходы по закрытому хеджу (фьючу)
        earning = -(close_price-start_price)/start_price*current_hedge*leverage
        money += earning
        if i == n_rehedge+1:
            break
        # смотрим сколько эфира нужно захеджировать
        ETH_to_hedge = return_curent_eth(start_price0, close_price, high_board, low_board, eth_pool, usd_pool)
        
        # выбираем плечо, максимально 3е, не больше. Основываемся на том, сколько у нас средств
        leverage = math.ceil(ETH_to_hedge/money)
        if ETH_to_hedge == 0:
            current_hedge = 0
        elif leverage > 3:
            print('требуется плечо - ',leverage)
            leverage = 3
            # все деньги, максимальное плечо
            current_hedge = money
        elif leverage <= 3:
            current_hedge = ETH_to_hedge/leverage
        # изменяем цену старта для нового фьючерса
        start_price = open_prices[ind+1]
    

    return money-eth_pool
        

def persentage_earnings(const=1):
    '''Функция принимает необходимые параметры и рассчитывает доходность в % от всех изначальных инвестиций
    Для начала используем константу - 1%'''
#     res = const
    res = IR # тут ручками задать 
    return res

def calc_ratio(start_price, high_board, low_board):
    return (high_board-start_price)/(high_board-low_board)

# %% [markdown]
# ### Далее класс, его просто инициализировать

# %%
# Класс который принимаем в себя всю необходимую информацию и подготавливает данные, рассчитывает интервалы и тп
class Interval_calculator:
    def __init__(self, df, n_info, n_forcast, intervals_in_hour, calculation='slow'):
        self.calculation = calculation
        self.df = df
        self.n_info = n_info
        self.n_forcast = n_forcast
        self.intervals_in_hour = intervals_in_hour
        self.make_new_col()
        self.preob()
        self.calculate_intervals()
        self.make_data_for_back()
        self.get_periodic()
        self.make_dates()
    
    def make_dates(self):
        n_info, n_forcast, intervals_in_hour = self.n_info, self.n_forcast, self.intervals_in_hour
        df_for_dates = self.df.iloc[n_info*intervals_in_hour:len(df)-n_forcast*intervals_in_hour]
        dates = df_for_dates['date'].values
        final_dates = dates[::intervals_in_hour*n_forcast]
        self.dates = final_dates
        
    def make_new_col(self):
        '''Потребуются относительные изменения'''
        print('Добавляю относительные изменения')
        df = self.df
        mass = np.zeros(len(df))
        mass[0] = 1 # первую точку доопределяем 1
        values = df['open'].values.astype(float)
        for i in range(1, len(df)):
            mass[i] = values[i]/values[i-1]
            df['change'] = mass
        self.df = df
        return    
        
        
    def preob(self):
        '''Функция просто создает кучу разбивок для бутстрэпа и предсказания
        df - датасет
        n_info - сколько часов брать для "обучения"
        n_forcast - на сколько часов давать прогноз
        intervals_in_hour - количество выбранных интерваллов в часе (если минутные данные то 60)
        '''
        print('Создаю разбивку - данные для рассчета интервала и теста')
        df, n_info, n_forcast, intervals_in_hour = self.df, self.n_info, self.n_forcast, self.intervals_in_hour
        self.dict_res = {}
        for i in range(n_info*intervals_in_hour, len(df)-n_forcast*intervals_in_hour):
            fold_info = df[i-n_info*intervals_in_hour : i] # Срез датасета
            fold_res = df[i : i+n_forcast*intervals_in_hour] # Срез датасета
            self.dict_res[i] = [fold_info, fold_res] # В словаре лежат два датасета под каждым ключом
        return 
    
    @jit
    def bootstrap(self, mass, n_forcast, intervals_in_hour):
        '''Функция бутстрэпит изменения за прошедшие часы (это длина массива) n_forcast*intervals_in_hour раз, 
        процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
        mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
        mass = np.array(mass) # переводим в numpy
        n = len(mass) # длина выборки для обучения
        size_forecast = n_forcast*intervals_in_hour
        # случайно берем числа до n, размера n_forcast*intervals_in_hour
        indexes = np.random.randint(n, size=size_forecast*10000)
        change = mass[[indexes]]
        change = change.reshape((10000, size_forecast))
        # теперь рассомтрим куммулятивное перемножение- предсказанное поведение
        cum_change = np.cumprod(change, axis=1)
        # минимальное и максимальные значения внутри временного интервалла
        min_ = np.min(cum_change, axis=1)
        max_ = np.max(cum_change, axis=1)
        sorted_res_min = np.sort(min_)
        sorted_res_max = np.sort(max_)
        high, low = sorted_res_max[9900], sorted_res_min[100]
#         vol = max((high-1), (1-low))
#         return np.array([1+vol, 1-vol])
        return np.array([high, low])
    
    def get_real(self, df):
      '''Функция нужна для валидации - возвращает верхние и нижние границы'''
      high = df['high'].values.astype(float)
      low = df['low'].values.astype(float)
      return np.hstack([high, low])
    
    def calculate_intervals(self):
        print('Рассчитываю интерваллы')
        dict_res, n_forcast, intervals_in_hour = self.dict_res, self.n_forcast, self.intervals_in_hour
        calculated_intervals = np.zeros((len(dict_res), 2))
        real_intervals = np.zeros((len(dict_res), n_forcast*intervals_in_hour*2)) # запоминаем  всю динамику  умножение на 2 тк записываем для верха и для низа
        k = 0
        for key in dict_res:
            if (self.calculation == 'fast') and (k % (self.intervals_in_hour*self.n_forcast) != 0 ):
                # заполняем ненужные интервалы нулями
                calculated_intervals[k, 0:2] = 0
                real_intervals[k, :] = 0
                k += 1
                continue
            real_intervals[k, :] = self.get_real(dict_res[key][1])

            # требуется для абсолютных значений запомнить цену открытия
            last_value = dict_res[key][0]['open'].values.astype(float)[-1]

            calculated = self.bootstrap(dict_res[key][0]['change'].values, n_forcast, intervals_in_hour)

            calculated_intervals[k, 0:2] = calculated*last_value
            k += 1
            j = int(len(dict_res)/200)
            if k % j == 0:
                print('progress = {} %'.format(round(k/len(dict_res)*100, 3)))
        self.intervals = calculated_intervals, real_intervals
        return

    def make_data_for_back(self):
        print('Преобразую данные для бэктеста')
        intervals, n_forcast, intervals_in_hour = self.intervals, self.n_forcast, self.intervals_in_hour
        # mass high, low, start, end
#         k_end = n_forcast*intervals_in_hour-1
        mass = np.zeros((len(intervals[0]), 4))
        for i in range(len(intervals[0])):
            # вычислим индекс в словаре с нарезками, чтобы подтянуть реальную цену открытия и закрытия
            index_in_dict_res = i+intervals_in_hour*self.n_info
            # берем цену open, close 
            open_price = self.dict_res[index_in_dict_res][1]['open'].values[0]
            close_price = self.dict_res[index_in_dict_res][1]['close'].values[-1]
            mass[i, :] = *intervals[0][i], open_price, close_price
            ###### тут брались цены open,close как high в первую и последнюю 5 минутки 
#             mass[i, :] = *intervals[0][i] , intervals[1][i][0], intervals[1][i][k_end]
    #         intervals[0][i] - high, low
        
    #         intervals[1][i][0] - start
    #         intervals[1][i][k] - end
        self.data_for_back = mass
        return
  
    
    def get_periodic(self):
        data_for_back, n_forcast, intervals_in_hour = self.data_for_back, self.n_forcast, self.intervals_in_hour
        '''Просто обрезка, выбор каждого n часового результата'''
        self.periodic_data_for_back = data_for_back[::n_forcast*intervals_in_hour, :]
        return 
    
    def back_test(self):
        '''Функция проводит анализ стратегии, возвращает список прибыли/убытков в каждый период'''
        mass_for_back, n_forcast = self.periodic_data_for_back, self.n_forcast
        earnings = np.zeros(len(mass_for_back))
#         print(ratio_for_hedge, hadge_type)
        for i in range(len(mass_for_back)):
            high_board, low_board, start_price, end_price = mass_for_back[i, :]

            e1 = unforward_earnings(start_price, end_price, high_board, low_board)
            # тут есть допущение - хедж для нас не требует блокировку активов - фьючерсы в общем ,причем бесплатные
            ratio_for_hedge = calc_ratio(start_price, high_board, low_board)
            e2 = simple_hedge(start_price, end_price, ratio_for_hedge)
            e3 = persentage_earnings()*n_forcast/24
            print('{} день'.format(i))
            print('start_price = ',start_price)
            print('end_price = ', end_price) 
            print('high_board = ', high_board)
            print('low_board = ', low_board)
            print('Непрямые потери/прибыли ',e1)
            print('Доход от хеджа ', e2)
            print('Процентный заработок ',e3)
            earnings[i] = e1+e2+e3
        return earnings
    
    def back_test_alt(self, start_amount, gas_price, verbose, hedge_type):
        '''Функция проводит анализ стратегии, возвращает список прибыли/убытков в каждый период'''
        mass_for_back, n_forcast = self.periodic_data_for_back, self.n_forcast
        earnings = np.zeros(len(mass_for_back))
        current_amount = start_amount
        for i in range(len(mass_for_back)):
            high_board, low_board, start_price, end_price = mass_for_back[i, :]
            # Рассчитываем долю эфира в средствах, которые вкладываем в пул
            ratio_hedge = calc_ratio(start_price, high_board, low_board)
            # Итого all_money = eth_pool+usd_pool+usd_hedge, eth_pool=usd_hedge
            # ratio_hedge = eth_pool/(eth_pool+usd_pool)
            # требуется расщепить current_amount на эти части:
            # То есть решить эти два уравнения:
            # current_amount = usd_pool+2*eth_pool
            # ratio_hedge = eth_pool/(eth_pool+usd_pool)
            ###### решаем... #####
            # usd_pool = (current_amount - 2*eth_pool)
            # ##### подставляем
            # ratio_hedge = eth_pool/(eth_pool+(current_amount - 2*eth_pool))
            # #####
            # ratio_hedge = eth_pool/(current_amount - eth_pool)
            # #####
            # ratio_hedge*(current_amount - eth_pool)  = eth_pool
            # ####
            # ratio_hedge*current_amount  = eth_pool+ratio_hedge*eth_pool
            # #####
            # eth_pool = ratio_hedge*current_amount/(1+ratio_hedge) 
            # -> usd_pool = current_amount - 2*eth_pool

            eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
            usd_pool = current_amount - 2*eth_pool
            usd_hedge = eth_pool

            # Получим непрямые прибыли/убытки от пула в процентах
            e1 = unforward_earnings(start_price, end_price, high_board, low_board)
            e1 = e1/100*(eth_pool+usd_pool) # переведем в деньги: прибыль

            # получим прибыль/убыток от хеджа
            if hedge_type == 'simple':
                e2 = simple_hedge(start_price, end_price, ratio_hedge)
                # небольшой костыль, чтобы вернуться просто к процентам от хеджа
                e2 = e2/(100*ratio_hedge)
                e2 = usd_hedge*e2  # переведем в доллары
                
            elif hedge_type == 'dynamic':
                # изначально отправляем деньги как на статический, затем испоьзуем магию
                e2 = dynamic_hedge(eth_pool, usd_pool, high_board,
                                   low_board, start_price, end_price, i, self.dict_res, n_forcast,
                                   self.intervals_in_hour, self.n_info)
            # получим прибыль от стейкинга
            # Учтем размер интервалла - считаем, что константа задает нам значение для 200 пунктов цены
            # при стоимости в районе 1200  - 0.16
            koef = (high_board - low_board)/start_price
            e3 = persentage_earnings()*n_forcast/24
            e3 = e3*0.16/koef
            
            
            e3 = e3/100 # уход от %
            e3 = (eth_pool+usd_pool)*e3# переведем в деньги
            
            # суммируем прибыли и изначальную сумму
            earn = e1 + e2 + e3 + current_amount - gas_price*2
            if self.wait_dangerous:
                if koef > 0.15:
                    if earn > current_amount:
                        print('упущенная выгода: ', earn - current_amount)
                    else:
                        print('Избежали убытков: ', current_amount - earn)                
                    # пропускаем высокую волотильность
                    earn = current_amount
                else:
                    print()
                    print(koef)
                    print()

            
            if verbose == True:
                print('{} день'.format(i))
                print('start_price = ',start_price)
                print('end_price = ', end_price) 
                print('high_board = ', high_board)
                print('low_board = ', low_board)
                print('Выделяем {} на usd_pool'.format(usd_pool))
                print('Выделяем {} на usd_hedge'.format(usd_hedge))
                print('Выделяем {} на eth_pool'.format(eth_pool))
                print('Непрямые потери/прибыли ', e1)
                print('Доход от хеджа ', e2)
                print('Процентный заработок ',e3)
                print()
            
            earnings[i] = earn
            # переопределяем старт на след день
            current_amount = earn
        return earnings
    
    def plot_results(self):
        fig = plt.figure(figsize = (10, 10))
        mass_for_back = self.periodic_data_for_back
        x = self.dates
        earnings = self.back_test()
        y = np.cumsum(earnings)
        plt.plot(x, y, label='Хеджируем эфир')
        plt.xlabel('Дата бектеста', fontsize=15)
        plt.ylabel('Доходность в %', fontsize=15)
        plt.xticks(fontsize = (20/len(x)+3), rotation=45)
        plt.title('Анализ итоговой доходности', fontsize = 15)
        plt.legend(prop={'size': 10})
        
    def plot_results_alt(self, start_amount, gas_price, verbose, hedge_type, wait_dangerous=False, plot=True):
        '''Альтернативный рассчет, более строгий
        Здесь каждый раз капитал разбивается на несколько частей
        Часть уходит в хедж, часть в пул. Затем все суммируется и новая сумма идет в след день'''
        self.wait_dangerous = wait_dangerous
        fig = plt.figure(figsize = (10, 10))
        mass_for_back = self.periodic_data_for_back
        x = self.dates
        
        earnings_alt = self.back_test_alt(start_amount, gas_price, verbose, hedge_type) 
        y = earnings_alt
        # если влаг отрисовки выключен, просто возвращаем точки
        if plot == False:
            return x, y
        
        
        plt.plot(x, y, label='Хеджируем эфир')
        plt.xlabel('Дата бектеста', fontsize=15)
        plt.ylabel('Всего средств', fontsize=15)
        plt.xticks(fontsize = (20/len(x)+3), rotation=45)
        plt.title('Анализ итоговой доходности старт с {} $'.format(start_amount), fontsize = 15)
        plt.legend(prop={'size': 10})
        
    def plot_price(self):
        # Просто отрисовка того, как изменялся курс, чтобы интерпретировать прибыли и убытки в стратегии
        mass_for_back = self.periodic_data_for_back
        fig = plt.figure(figsize = (10, 10))
        plt.plot(self.dates, mass_for_back[:, 3])
        plt.xticks(fontsize = (20/len(self.dates)+3), rotation=45)
        plt.title('Курс ETH/USDT')
        
    def change_price_distr(self):
        mass_for_back = self.periodic_data_for_back
        change = np.zeros(len(mass_for_back))
        starts = mass_for_back[:, 2]
        ends = mass_for_back[:, 3]
        for i in range(len(change)):
            end = ends[i]
            start = starts[i]
            res = (end - start)/start*100 # итог в процентах +10% или -0.5%
            change[i] = res
        fig = plt.figure(figsize = (10, 10))
        plt.xlabel('Изменение стоимости в %', fontsize=15)
        plt.hist(change, bins=15)
        plt.show()

# %% [markdown]
# ### Следующая строчка посчитает все интерваллы

# %%
back_test_obj = Interval_calculator(df, n_info, n_forcast, intervals_in_hour, calculation='fast')
# Out:
# Добавляю относительные изменения
# Создаю разбивку - данные для рассчета интервала и теста
# Рассчитываю интерваллы
# <ipython-input-262-5815457c01a2>:53: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "bootstrap" failed type inference due to: non-precise type pyobject
# During: typing of argument at <ipython-input-262-5815457c01a2> (57)
#
# File "<ipython-input-262-5815457c01a2>", line 57:
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#         <source elided>
#         процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
#         mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
#         ^
#
#   @jit
# /Users/vladislav705/opt/anaconda3/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "bootstrap" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-262-5815457c01a2>", line 54:
#     @jit
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /Users/vladislav705/opt/anaconda3/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-262-5815457c01a2>", line 54:
#     @jit
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <ipython-input-262-5815457c01a2>:101: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   calculated = self.bootstrap(dict_res[key][0]['change'].values, n_forcast, intervals_in_hour)
# progress = 93.474 %
# Преобразую данные для бэктеста

# %% [markdown]
# ### Поведение при бесплатных фьючерсах(не реальная ситуация, представлена для сравнения)

# %%
back_test_obj.plot_results()
# Out:
# 0 день
# start_price =  1099.15
# end_price =  1061.6
# high_board =  1472.3221202188467
# low_board =  855.2333554993805
# Непрямые потери/прибыли  -2.1716718078340413
# Доход от хеджа  2.0659248891062063
# Процентный заработок  0.6
# 1 день
# start_price =  1061.64
# end_price =  1166.59
# high_board =  1449.7029708319767
# low_board =  822.1095523175774
# Непрямые потери/прибыли  5.2860732164792035
# Доход от хеджа  -6.112642450611955
# Процентный заработок  0.6
# 2 день
# start_price =  1166.48
# end_price =  1226.12
# high_board =  1454.7565091764845
# low_board =  1026.7667358293304
# Непрямые потери/прибыли  3.087552992569309
# Доход от хеджа  -3.443786350869238
# Процентный заработок  0.6
# 3 день
# start_price =  1226.28
# end_price =  1219.0
# high_board =  1497.3217622843988
# low_board =  1017.072244038922
# Непрямые потери/прибыли  -0.3395640892067675
# Доход от хеджа  0.33505106955148933
# Процентный заработок  0.6
# 4 день
# start_price =  1219.0
# end_price =  1219.52
# high_board =  1563.9656757195626
# low_board =  1109.3174243810881
# Непрямые потери/прибыли  0.032342422583298
# Доход от хеджа  -0.03236681739448021
# Процентный заработок  0.6
# 5 день
# start_price =  1219.52
# end_price =  1225.43
# high_board =  1478.941089610493
# low_board =  988.642396662853
# Непрямые потери/прибыли  0.25349404902121897
# Доход от хеджа  -0.25641480519603216
# Процентный заработок  0.6
# 6 день
# start_price =  1225.43
# end_price =  1429.56
# high_board =  1385.6424637933978
# low_board =  1064.4637638702557
# Непрямые потери/прибыли  3.260823999271256
# Доход от хеджа  -8.309366040704647
# Процентный заработок  0.6
# 7 день
# start_price =  1429.47
# end_price =  1265.39
# high_board =  2183.631817360411
# low_board =  1368.320259083317
# Непрямые потери/прибыли  -11.333269263489598
# Доход от хеджа  10.617482246966214
# Процентный заработок  0.6
# 8 день
# start_price =  1265.41
# end_price =  1236.31
# high_board =  1372.1121877434123
# low_board =  890.1408197365729
# Непрямые потери/прибыли  -0.5793431050263864
# Доход от хеджа  0.5091125601061429
# Процентный заработок  0.6
# 9 день
# start_price =  1236.43
# end_price =  1197.57
# high_board =  1353.0839936991754
# low_board =  819.3461921942699
# Непрямые потери/прибыли  -0.803158412717131
# Доход от хеджа  0.6869180233007396
# Процентный заработок  0.6
# 10 день
# start_price =  1197.36
# end_price =  1219.07
# high_board =  1867.3424536995653
# low_board =  972.8929634420119
# Непрямые потери/прибыли  1.3361298236990393
# Доход от хеджа  -1.3581342010844035
# Процентный заработок  0.6
# 11 день
# start_price =  1219.07
# end_price =  1342.97
# high_board =  1401.2895455494706
# low_board =  1038.5428066119548
# Непрямые потери/прибыли  3.3697277593067954
# Доход от хеджа  -5.105450911292847
# Процентный заработок  0.6
# 12 день
# start_price =  1343.07
# end_price =  1411.18
# high_board =  1829.1282827846217
# low_board =  1291.3524974405661
# Непрямые потери/прибыли  4.262384046773193
# Доход от хеджа  -4.583522176166006
# Процентный заработок  0.6
# 13 день
# start_price =  1411.41
# end_price =  1313.46
# high_board =  1725.4198355565925
# low_board =  1206.1038499338645
# Непрямые потери/прибыли  -4.874266735748822
# Доход от хеджа  4.196264069253482
# Процентный заработок  0.6
# 14 день
# start_price =  1313.61
# end_price =  1249.02
# high_board =  1585.9960795224642
# low_board =  1074.9924211815037
# Непрямые потери/прибыли  -2.9395376226321046
# Доход от хеджа  2.6209560485348566
# Процентный заработок  0.6
# 15 день
# start_price =  1248.78
# end_price =  1302.55
# high_board =  1341.696245909628
# low_board =  913.1753123127514
# Непрямые потери/прибыли  0.663485675949671
# Доход от хеджа  -0.9336276693677705
# Процентный заработок  0.6
# 16 день
# start_price =  1302.54
# end_price =  1416.96
# high_board =  1651.8323427199239
# low_board =  1147.4601626073147
# Непрямые потери/прибыли  5.087038842631242
# Доход от хеджа  -6.083434206612557
# Процентный заработок  0.6
# 17 день
# start_price =  1416.83
# end_price =  1340.01
# high_board =  1990.622506800267
# low_board =  1239.114291740245
# Непрямые потери/прибыли  -4.424625694733275
# Доход от хеджа  4.13978416349667
# Процентный заработок  0.6
# 18 день
# start_price =  1340.01
# end_price =  1354.29
# high_board =  1483.9481533459277
# low_board =  1094.5297196196382
# Непрямые потери/прибыли  0.3743552233996361
# Доход от хеджа  -0.3938942027622589
# Процентный заработок  0.6
# 19 день
# start_price =  1354.36
# end_price =  1336.41
# high_board =  1423.5705675155118
# low_board =  1206.7375758431556
# Непрямые потери/прибыли  -0.4782599406354282
# Доход от хеджа  0.4230360542393306
# Процентный заработок  0.6
# 20 день
# start_price =  1336.4
# end_price =  1419.58
# high_board =  1598.8516890407209
# low_board =  1206.7353980125613
# Непрямые потери/прибыли  3.505806582443727
# Доход от хеджа  -4.165977644238661
# Процентный заработок  0.6
# 21 день
# start_price =  1419.58
# end_price =  1537.68
# high_board =  1771.2773547476634
# low_board =  1295.8920233220394
# Непрямые потери/прибыли  5.12140181978511
# Доход от хеджа  -6.154791572168399
# Процентный заработок  0.6
# 22 день
# start_price =  1537.93
# end_price =  1611.74
# high_board =  1821.4220794617722
# low_board =  1407.2227414247948
# Непрямые потери/прибыли  2.8571928397068014
# Доход от хеджа  -3.2848093311285416
# Процентный заработок  0.6
# 23 день
# start_price =  1611.77
# end_price =  1662.78
# high_board =  1829.0782622371892
# low_board =  1347.8235101778052
# Непрямые потери/прибыли  1.2613430371782863
# Доход от хеджа  -1.429069872415592
# Процентный заработок  0.6
# 24 день
# start_price =  1662.79
# end_price =  1679.67
# high_board =  2027.74351668082
# low_board =  1555.5985837440164
# Непрямые потери/прибыли  0.7665415582641444
# Доход от хеджа  -0.7846884459669643
# Процентный заработок  0.6
# 25 день
# start_price =  1679.67
# end_price =  1624.91
# high_board =  1863.14443503747
# low_board =  1404.708780268026
# Непрямые потери/прибыли  -1.5027174477540761
# Доход от хеджа  1.3047780605700523
# Процентный заработок  0.6
# 26 день
# start_price =  1624.89
# end_price =  1660.48
# high_board =  1759.3477389439063
# low_board =  1336.8505582982757
# Непрямые потери/прибыли  0.6048008254127213
# Доход от хеджа  -0.6970533371027843
# Процентный заработок  0.6
# 27 день
# start_price =  1660.63
# end_price =  1753.4
# high_board =  1967.3732319424057
# low_board =  1537.4451975985635
# Непрямые потери/прибыли  3.383064093581778
# Доход от хеджа  -3.985785301242722
# Процентный заработок  0.6
# 28 день
# start_price =  1753.4
# end_price =  1792.02
# high_board =  2100.1812352981988
# low_board =  1480.5405654490175
# Непрямые потери/прибыли  1.1640309038244645
# Доход от хеджа  -1.2326703271691766
# Процентный заработок  0.6
# 29 день
# start_price =  1792.02
# end_price =  1801.02
# high_board =  2093.9142015661528
# low_board =  1579.9635817315702
# Непрямые потери/прибыли  0.2906101372499359
# Доход от хеджа  -0.29500748464522686
# Процентный заработок  0.6
# 30 день
# start_price =  1801.02
# end_price =  1787.33
# high_board =  2084.230526176746
# low_board =  1679.69228830793
# Непрямые потери/прибыли  -0.545061588120721
# Доход от хеджа  0.5321508069170726
# Процентный заработок  0.6
# 31 день
# start_price =  1787.33
# end_price =  1793.83
# high_board =  1948.4460335692804
# low_board =  1631.0257413893485
# Непрямые потери/прибыли  0.18086836884090296
# Доход от хеджа  -0.1845919196608182
# Процентный заработок  0.6
# 32 день
# start_price =  1793.54
# end_price =  1839.31
# high_board =  1957.519214679854
# low_board =  1514.2684516822392
# Непрямые потери/прибыли  0.812324515770424
# Доход от хеджа  -0.9440807793818656
# Процентный заработок  0.6
# 33 день
# start_price =  1839.4
# end_price =  1811.85
# high_board =  1992.1180021246246
# low_board =  1724.3847855363347
# Непрямые потери/прибыли  -0.9319877072436755
# Доход от хеджа  0.8543452304923835
# Процентный заработок  0.6
# 34 день
# start_price =  1811.85
# end_price =  1792.46
# high_board =  2173.8265174850803
# low_board =  1524.5272500341212
# Непрямые потери/прибыли  -0.6126760109710139
# Доход от хеджа  0.596610721010504
# Процентный заработок  0.6
# 35 день
# start_price =  1792.5
# end_price =  1820.23
# high_board =  2060.983994619121
# low_board =  1617.3077003849369
# Непрямые потери/прибыли  0.8878002834765475
# Доход от хеджа  -0.936144480848046
# Процентный заработок  0.6
# 36 день
# start_price =  1820.61
# end_price =  1901.52
# high_board =  2124.2042808610236
# low_board =  1700.5236145259516
# Непрямые потери/прибыли  2.7601476482410625
# Доход от хеджа  -3.18449240111955
# Процентный заработок  0.6
# 37 день
# start_price =  1901.53
# end_price =  1919.77
# high_board =  2152.523793754767
# low_board =  1732.757316780964
# Непрямые потери/прибыли  0.5527168652254666
# Доход от хеджа  -0.5735573942162606
# Процентный заработок  0.6
# 38 день
# start_price =  1919.88
# end_price =  2025.92
# high_board =  2094.741704217323
# low_board =  1772.6732837040065
# Непрямые потери/прибыли  2.0895051991492775
# Доход от хеджа  -2.998763374505157
# Процентный заработок  0.6
# 39 день
# start_price =  2025.91
# end_price =  1948.66
# high_board =  2450.6013957835457
# low_board =  1928.2186426155615
# Непрямые потери/прибыли  -3.387429794736385
# Доход от хеджа  3.100009125640305
# Процентный заработок  0.6
# 40 день
# start_price =  1948.68
# end_price =  1781.82
# high_board =  2211.5055851877464
# low_board =  1756.3458354789427
# Непрямые потери/прибыли  -6.584156362619953
# Доход от хеджа  4.944421674138478
# Процентный заработок  0.6
# 41 день
# start_price =  1781.81
# end_price =  1553.48
# high_board =  1936.7388450732499
# low_board =  1327.635212232239
# Непрямые потери/прибыли  -5.825700652988431
# Доход от хеджа  3.2594376540281056
# Процентный заработок  0.6
# 42 день
# start_price =  1553.47
# end_price =  1674.19
# high_board =  2035.629815760046
# low_board =  717.568023214286
# Непрямые потери/прибыли  2.4868349978204085
# Доход от хеджа  -2.8427037176726353
# Процентный заработок  0.6
# 43 день
# start_price =  1673.95
# end_price =  1660.72
# high_board =  2321.518900325949
# low_board =  1521.7967516880326
# Непрямые потери/прибыли  -0.6465401694529138
# Доход от хеджа  0.639976787149226
# Процентный заработок  0.6
# 44 день
# start_price =  1660.72
# end_price =  1466.13
# high_board =  1984.9954887826102
# low_board =  1432.546975082449
# Непрямые потери/прибыли  -9.069758692498553
# Доход от хеджа  6.877750471040399
# Процентный заработок  0.6
# 45 день
# start_price =  1465.94
# end_price =  1485.33
# high_board =  1827.2068426773928
# low_board =  1168.284349984121
# Непрямые потери/прибыли  0.7057345289390726
# Доход от хеджа  -0.7251959744460709
# Процентный заработок  0.6
# 46 день
# start_price =  1485.53
# end_price =  1362.04
# high_board =  1762.2325401930468
# low_board =  1230.8193114736407
# Непрямые потери/прибыли  -5.336196769004731
# Доход от хеджа  4.328437477365923
# Процентный заработок  0.6
# 47 день
# start_price =  1362.04
# end_price =  1531.86
# high_board =  1547.7772337275069
# low_board =  949.4328115984489
# Непрямые потери/прибыли  2.1009977140466596
# Доход от хеджа  -3.870318455125712
# Процентный заработок  0.6
# 48 день
# start_price =  1531.86
# end_price =  1564.88
# high_board =  1995.676671600748
# low_board =  1461.2980669128056
# Непрямые потери/прибыли  1.8043230907684782
# Доход от хеджа  -1.870920296041492
# Процентный заработок  0.6
# 49 день
# start_price =  1564.88
# end_price =  1631.0
# high_board =  1831.9555300689597
# low_board =  1367.1652770205649
# Непрямые потери/прибыли  2.127352570670693
# Доход от хеджа  -2.4278893596848614
# Процентный заработок  0.6
# 50 день
# start_price =  1630.88
# end_price =  1551.76
# high_board =  2193.9014617659695
# low_board =  1576.7134924708607
# Непрямые потери/прибыли  -4.710352895343828
# Доход от хеджа  4.425596040271309
# Процентный заработок  0.6
# 51 день
# start_price =  1551.76
# end_price =  1485.77
# high_board =  1696.132725671849
# low_board =  1273.0815436538571
# Непрямые потери/прибыли  -1.7901395085108907
# Доход от хеджа  1.4512619823938133
# Процентный заработок  0.6
# 52 день
# start_price =  1485.97
# end_price =  1540.04
# high_board =  1734.691146001803
# low_board =  1354.107967380436
# Непрямые потери/прибыли  2.119509132659725
# Доход от хеджа  -2.377986851880788
# Процентный заработок  0.6
# 53 день
# start_price =  1540.13
# end_price =  1644.99
# high_board =  1757.2356575598417
# low_board =  1378.134030881659
# Непрямые потери/прибыли  2.9575100644490204
# Доход от хеджа  -3.8991322506104136
# Процентный заработок  0.6
# 54 день
# start_price =  1644.99
# end_price =  1742.25
# high_board =  1820.9224062539058
# low_board =  1428.1675689643741
# Непрямые потери/прибыли  1.9163996069054612
# Доход от хеджа  -2.648471494831425
# Процентный заработок  0.6
# 55 день
# start_price =  1742.2
# end_price =  1826.74
# high_board =  1992.2447748709617
# low_board =  1528.5934185209871
# Непрямые потери/прибыли  2.1745305823504646
# Доход от хеджа  -2.61692022167527
# Процентный заработок  0.6
# 56 день
# start_price =  1826.74
# end_price =  1839.13
# high_board =  2024.2172271517975
# low_board =  1628.7293818133985
# Непрямые потери/прибыли  0.3280469821240972
# Доход от хеджа  -0.3386713411381001
# Процентный заработок  0.6
# 57 день
# start_price =  1839.34
# end_price =  1808.85
# high_board =  2137.9252009475495
# low_board =  1683.480602994683
# Непрямые потери/прибыли  -1.1452109207879646
# Доход от хеджа  1.0891375770003893
# Процентный заработок  0.6
# 58 день
# start_price =  1808.99
# end_price =  1748.06
# high_board =  2099.6522686323115
# low_board =  1599.2308065505683
# Непрямые потери/прибыли  -2.1649179679638753
# Доход от хеджа  1.9563553551699582
# Процентный заработок  0.6
# 59 день
# start_price =  1748.06
# end_price =  1884.52
# high_board =  1872.7576244539057
# low_board =  1449.181310937965
# Непрямые потери/прибыли  1.050021914209598
# Доход от хеджа  -2.2981350453232774
# Процентный заработок  0.6
# 60 день
# start_price =  1884.43
# end_price =  1876.09
# high_board =  2425.15205905945
# low_board =  1842.21744943517
# Непрямые потери/прибыли  -0.4136985989481867
# Доход от хеджа  0.4105256406975037
# Процентный заработок  0.6
# 61 день
# start_price =  1875.77
# end_price =  1791.23
# high_board =  1995.899886367277
# low_board =  1668.1295015765113
# Непрямые потери/прибыли  -2.246450878096584
# Доход от хеджа  1.6518249174457822
# Процентный заработок  0.6
# 62 день
# start_price =  1791.03
# end_price =  1789.83
# high_board =  1905.385088967319
# low_board =  1367.647495941135
# Непрямые потери/прибыли  -0.014323097500312798
# Доход от хеджа  0.014248314178649028
# Процентный заработок  0.6
# 63 день
# start_price =  1790.06
# end_price =  1774.84
# high_board =  2120.96079601352
# low_board =  1640.2479018879915
# Непрямые потери/прибыли  -0.5987913231422781
# Доход от хеджа  0.5852738292600991
# Процентный заработок  0.6
# 64 день
# start_price =  1774.84
# end_price =  1791.97
# high_board =  1913.5009219238123
# low_board =  1645.9767139398164
# Непрямые потери/прибыли  0.4693520846068333
# Доход от хеджа  -0.5002523660700144
# Процентный заработок  0.6
# 65 день
# start_price =  1792.1
# end_price =  1814.59
# high_board =  1854.0086214229184
# low_board =  1590.8396593958983
# Непрямые потери/прибыли  0.2415954650028196
# Доход от хеджа  -0.29521857617520536
# Процентный заработок  0.6
# 66 день
# start_price =  1814.73
# end_price =  1847.76
# high_board =  2058.609669384691
# low_board =  1726.7479493035794
# Непрямые потери/прибыли  1.2469882889299733
# Доход от хеджа  -1.3375652974309475
# Процентный заработок  0.6
# 67 день
# start_price =  1847.76
# end_price =  1785.84
# high_board =  1988.3101994043254
# low_board =  1764.6007308829999
# Непрямые потери/прибыли  -2.5770620072148365
# Доход от хеджа  2.1053896633924696
# Процентный заработок  0.6
# 68 день
# start_price =  1785.81
# end_price =  1780.49
# high_board =  1950.8597666001517
# low_board =  1646.6066385697707
# Непрямые потери/прибыли  -0.16421391671608276
# Доход от хеджа  0.1616055398539366
# Процентный заработок  0.6
# 69 день
# start_price =  1780.38
# end_price =  1698.0
# high_board =  1939.1561480475725
# low_board =  1680.9517265424065
# Непрямые потери/прибыли  -3.600936066630278
# Доход от хеджа  2.845317057300861
# Процентный заработок  0.6
# 70 день
# start_price =  1698.0
# end_price =  1725.42
# high_board =  1857.2549146560775
# low_board =  1502.486075919743
# Непрямые потери/прибыли  0.662493061178715
# Доход от хеджа  -0.7248984010713848
# Процентный заработок  0.6
# 71 день
# start_price =  1725.42
# end_price =  1600.54
# high_board =  2009.7204228881262
# low_board =  1643.8301115242016
# Непрямые потери/прибыли  -6.736747477092486
# Доход от хеджа  5.623732545607388
# Процентный заработок  0.6
# 72 день
# start_price =  1600.81
# end_price =  1641.91
# high_board =  1878.053305307656
# low_board =  1419.7436042760023
# Непрямые потери/прибыли  1.4379954948309903
# Доход от хеджа  -1.5531165626880405
# Процентный заработок  0.6
# 73 день
# start_price =  1641.91
# end_price =  1680.11
# high_board =  1826.9793782972724
# low_board =  1572.238172063286
# Непрямые потери/прибыли  1.515803066230359
# Доход от хеджа  -1.6902439110538152
# Процентный заработок  0.6
# 74 день
# start_price =  1680.14
# end_price =  1695.25
# high_board =  1789.68757052525
# low_board =  1537.060619516402
# Непрямые потери/прибыли  0.3630846174422997
# Доход от хеджа  -0.38997975569256155
# Процентный заработок  0.6
# 75 день
# start_price =  1695.24
# end_price =  1782.12
# high_board =  1790.537113558387
# low_board =  1577.478317381771
# Непрямые потери/прибыли  1.2473763103103552
# Доход от хеджа  -2.292286510699221
# Процентный заработок  0.6
# 76 день
# start_price =  1782.12
# end_price =  1840.93
# high_board =  2134.8122644315204
# low_board =  1747.4718792155488
# Непрямые потери/прибыли  2.754292449141804
# Доход от хеджа  -3.0048125851868517
# Процентный заработок  0.6
# 77 день
# start_price =  1840.93
# end_price =  1837.4
# high_board =  2072.8195835150805
# low_board =  1764.3832668385448
# Непрямые потери/прибыли  -0.14526111562190858
# Доход от хеджа  0.14416278469320423
# Процентный заработок  0.6
# 78 день
# start_price =  1837.4
# end_price =  1928.38
# high_board =  2016.3875511843405
# low_board =  1633.2143073259915
# Непрямые потери/прибыли  1.7251241070889378
# Доход от хеджа  -2.3129693142501777
# Процентный заработок  0.6
# 79 день
# start_price =  1928.38
# end_price =  2052.91
# high_board =  2094.2134890817606
# low_board =  1752.5860473212686
# Непрямые потери/прибыли  1.957745621092677
# Доход от хеджа  -3.1347351878816854
# Процентный заработок  0.6
# 80 день
# start_price =  2052.42
# end_price =  2100.26
# high_board =  2293.829291110949
# low_board =  1956.9349899271192
# Непрямые потери/прибыли  1.5047666105816315
# Доход от хеджа  -1.6702644939084477
# Процентный заработок  0.6
# 81 день
# start_price =  2100.26
# end_price =  2081.96
# high_board =  2299.381169488017
# low_board =  1940.3887740539708
# Непрямые потери/прибыли  -0.5055980782322389
# Доход от хеджа  0.4832926761711174
# Процентный заработок  0.6
# 82 день
# start_price =  2081.6
# end_price =  2115.24
# high_board =  2413.1679584342123
# low_board =  2011.915188429393
# Непрямые потери/прибыли  1.2676623335253545
# Доход от хеджа  -1.3354056814281345
# Процентный заработок  0.6
# 83 день
# start_price =  2115.24
# end_price =  2070.01
# high_board =  2451.177050121492
# low_board =  2038.9061381879408
# Непрямые потери/прибыли  -1.8609400439877688
# Доход от хеджа  1.7423770721714316
# Процентный заработок  0.6
# 84 день
# start_price =  2070.01
# end_price =  2002.29
# high_board =  2212.8878492817257
# low_board =  1802.0284431780265
# Непрямые потери/прибыли  -1.4117645254372757
# Доход от хеджа  1.1376696597107048
# Процентный заработок  0.6
# 85 день
# start_price =  2002.41
# end_price =  2043.48
# high_board =  2143.0721537580157
# low_board =  1585.9852731987241
# Непрямые потери/прибыли  0.4422725177317455
# Доход от хеджа  -0.5178762914623487
# Процентный заработок  0.6
# 86 день
# start_price =  2043.48
# end_price =  2068.7
# high_board =  2361.772687790198
# low_board =  1977.583922180443
# Непрямые потери/прибыли  0.9819759985804533
# Доход от хеджа  -1.0224844010405694
# Процентный заработок  0.6
# 87 день
# start_price =  2068.7
# end_price =  2153.52
# high_board =  2179.028569699741
# low_board =  1897.3534023207599
# Непрямые потери/прибыли  0.988645796370613
# Доход от хеджа  -1.6059801779607887
# Процентный заработок  0.6
# 88 день
# start_price =  2153.75
# end_price =  2137.96
# high_board =  2515.451314037709
# low_board =  2039.081985044934
# Непрямые потери/прибыли  -0.568859230918306
# Доход от хеджа  0.5566639979755256
# Процентный заработок  0.6
# 89 день
# start_price =  2137.95
# end_price =  2140.62
# high_board =  2303.4565133272613
# low_board =  1964.997258173783
# Непрямые потери/прибыли  0.06057663213905329
# Доход от хеджа  -0.061069225538869155
# Процентный заработок  0.6
# 90 день
# start_price =  2140.61
# end_price =  2247.14
# high_board =  2369.0423598343205
# low_board =  1958.4118051526902
# Непрямые потери/прибыли  2.122933056630849
# Доход от хеджа  -2.7684758641972502
# Процентный заработок  0.6
# 91 день
# start_price =  2247.39
# end_price =  2335.89
# high_board =  2650.8966410094217
# low_board =  2152.758806970609
# Непрямые потери/прибыли  2.840011532104736
# Доход от хеджа  -3.189818594661809
# Процентный заработок  0.6
# 92 день
# start_price =  2335.89
# end_price =  2465.01
# high_board =  2859.5959480663455
# low_board =  2067.48674272555
# Непрямые потери/прибыли  3.2041056338639518
# Доход от хеджа  -3.6546313557905266
# Процентный заработок  0.6
# 93 день
# start_price =  2465.01
# end_price =  2416.87
# high_board =  2852.36484627495
# low_board =  2287.327126916833
# Непрямые потери/прибыли  -1.4228232401772845
# Доход от хеджа  1.3388100199367767
# Процентный заработок  0.6
# 94 день
# start_price =  2416.86
# end_price =  2394.89
# high_board =  2750.0733182682948
# low_board =  1834.4718720905303
# Непрямые потери/прибыли  -0.3417780106943491
# Доход от хеджа  0.33082204688739586
# Процентный заработок  0.6
# 95 день
# start_price =  2395.12
# end_price =  2141.91
# high_board =  2501.864656103269
# low_board =  2013.4926419175545
# Непрямые потери/прибыли  -5.204333919925763
# Доход от хеджа  2.3107286514553484
# Процентный заработок  0.6
# 96 день
# start_price =  2142.0
# end_price =  2134.27
# high_board =  2893.576295885233
# low_board =  1257.3401253908244
# Непрямые потери/прибыли  -0.16661679516505323
# Доход от хеджа  0.1657628148095342
# Процентный заработок  0.6
# 97 день
# start_price =  2134.27
# end_price =  2261.05
# high_board =  2263.8552265451476
# low_board =  1705.9456353383125
# Непрямые потери/прибыли  0.7047973019119302
# Доход от хеджа  -1.379726648029145
# Процентный заработок  0.6
# 98 день
# start_price =  2261.05
# end_price =  2427.6
# high_board =  2926.2156856691117
# low_board =  2058.2084374161773
# Непрямые потери/прибыли  4.9380163605814875
# Доход от хеджа  -5.644701177085395
# Процентный заработок  0.6
# 99 день
# start_price =  2427.61
# end_price =  2596.24
# high_board =  3208.977966387446
# low_board =  2242.858578435514
# Непрямые потери/прибыли  5.011767371519027
# Доход от хеджа  -5.617986965016526
# Процентный заработок  0.6
# 100 день
# start_price =  2596.23
# end_price =  2302.23
# high_board =  3572.787263194103
# low_board =  2421.890730685487
# Непрямые потери/прибыли  -10.857432903185815
# Доход от хеджа  9.608721352963434
# Процентный заработок  0.6
# 101 день
# start_price =  2302.35
# end_price =  2218.09
# high_board =  3355.388132300773
# low_board =  1851.2820139100577
# Непрямые потери/прибыли  -2.6666359544949336
# Доход от хеджа  2.562215946412112
# Процентный заработок  0.6
# 102 день
# start_price =  2218.79
# end_price =  2217.04
# high_board =  2521.589875312972
# low_board =  1759.2809310766472
# Непрямые потери/прибыли  -0.03141956651488975
# Доход от хеджа  0.03132899947191831
# Процентный заработок  0.6
# 103 день
# start_price =  2216.97
# end_price =  2496.31
# high_board =  2556.600829846217
# low_board =  1793.124092480254
# Непрямые потери/прибыли  3.3000645436334297
# Доход от хеджа  -5.605116063792447
# Процентный заработок  0.6
# 104 день
# start_price =  2496.3
# end_price =  2637.34
# high_board =  2926.9465907651233
# low_board =  2185.194650463108
# Непрямые потери/прибыли  2.743102406851139
# Доход от хеджа  -3.2802568039206546
# Процентный заработок  0.6
# 105 день
# start_price =  2637.57
# end_price =  2752.35
# high_board =  3249.4354366693315
# low_board =  2443.9654540798097
# Непрямые потери/прибыли  2.9956783265157494
# Доход от хеджа  -3.3057407166397432
# Процентный заработок  0.6
# 106 день
# start_price =  2752.35
# end_price =  2727.97
# high_board =  3519.5235895975457
# low_board =  2529.616162536216
# Непрямые потери/прибыли  -0.6974382934812229
# Доход от хеджа  0.6864819181382341
# Процентный заработок  0.6
# 107 день
# start_price =  2727.97
# end_price =  2757.05
# high_board =  2977.0779335907355
# low_board =  2355.678487063287
# Непрямые потери/прибыли  0.4023950151632816
# Доход от хеджа  -0.4273379962046799
# Процентный заработок  0.6
# 108 день
# start_price =  2757.05
# end_price =  2914.37
# high_board =  2947.56221741911
# low_board =  2485.4947546442254
# Непрямые потери/прибыли  1.3812697653950545
# Доход от хеджа  -2.3526468400118206
# Процентный заработок  0.6
# 109 день
# start_price =  2914.5
# end_price =  2975.0
# high_board =  3373.103698180062
# low_board =  2824.8699813329326
# Непрямые потери/прибыли  1.6219150145238448
# Доход от хеджа  -1.7364533724224573
# Процентный заработок  0.6
# 110 день
# start_price =  2975.0
# end_price =  3321.18
# high_board =  3377.457226265028
# low_board =  2914.979113072395
# Непрямые потери/прибыли  5.771054579858048
# Доход от хеджа  -10.126131168147124
# Процентный заработок  0.6
# 111 день
# start_price =  3321.18
# end_price =  3337.67
# high_board =  4099.471997029568
# low_board =  3040.8369260192208
# Непрямые потери/прибыли  0.3611596270125528
# Доход от хеджа  -0.36502661323055025
# Процентный заработок  0.6
# 112 день
# start_price =  3338.01
# end_price =  3426.72
# high_board =  4226.202363581709
# low_board =  2625.509621401406
# Непрямые потери/прибыли  1.400992212707708
# Доход от хеджа  -1.47463319173582
# Процентный заработок  0.6
# 113 день
# start_price =  3426.72
# end_price =  3507.62
# high_board =  4102.089426352346
# low_board =  3080.30660329847
# Непрямые потери/прибыли  1.4669993448370944
# Доход от хеджа  -1.5604602172497908
# Процентный заработок  0.6
# 114 день
# start_price =  3507.51
# end_price =  3469.71
# high_board =  4265.654113693563
# low_board =  3066.2865840049676
# Непрямые потери/прибыли  -0.6983023348916872
# Доход от хеджа  0.6812277994806373
# Процентный заработок  0.6
# 115 день
# start_price =  3469.53
# end_price =  3887.25
# high_board =  3908.4607609480295
# low_board =  3175.856156524595
# Непрямые потери/прибыли  3.7809976487579
# Доход от хеджа  -7.213416291029218
# Процентный заработок  0.6
# 116 день
# start_price =  3887.24
# end_price =  3904.35
# high_board =  5327.616352306401
# low_board =  3754.4996385758354
# Непрямые потери/прибыли  0.4006236135426944
# Доход от хеджа  -0.4030173025377118
# Процентный заработок  0.6
# 117 день
# start_price =  3904.34
# end_price =  4007.06
# high_board =  4517.338398348074
# low_board =  3372.1038986537396
# Непрямые потери/прибыли  1.2902377674995469
# Доход от хеджа  -1.408225803812027
# Процентный заработок  0.6
# 118 день
# start_price =  4006.41
# end_price =  4101.03
# high_board =  5149.89630376449
# low_board =  2582.482729429342
# Непрямые потери/прибыли  1.0083519188518686
# Доход от хеджа  -1.0518714960558917
# Процентный заработок  0.6
# 119 день
# start_price =  4101.04
# end_price =  4101.36
# high_board =  5015.043343129733
# low_board =  3692.7649874686194
# Непрямые потери/прибыли  0.005392682315230601
# Доход от хеджа  -0.005393626491460804
# Процентный заработок  0.6
# 120 день
# start_price =  4101.37
# end_price =  3737.43
# high_board =  4725.633143707459
# low_board =  3052.8402867352097
# Непрямые потери/прибыли  -4.321620331883591
# Доход от хеджа  3.3115122818618237
# Процентный заработок  0.6
# 121 день
# start_price =  3737.44
# end_price =  4040.55
# high_board =  5182.910153175264
# low_board =  2774.2837078677985
# Непрямые потери/прибыли  4.356747431680197
# Доход от хеджа  -4.86704894209063
# Процентный заработок  0.6
# 122 день
# start_price =  4040.2
# end_price =  3808.69
# high_board =  4856.275811563342
# low_board =  3505.2505727279354
# Непрямые потери/прибыли  -3.966695593832914
# Доход от хеджа  3.461257692766149
# Процентный заработок  0.6
# 123 день
# start_price =  3808.68
# end_price =  3496.57
# high_board =  4378.1127767701855
# low_board =  3016.185312387522
# Непрямые потери/прибыли  -4.4053690995500165
# Доход от хеджа  3.426270776912512
# Процентный заработок  0.6
# 124 день
# start_price =  3496.0
# end_price =  3265.36
# high_board =  3916.365314191629
# low_board =  2254.0610006828897
# Непрямые потери/прибыли  -2.1416078334525745
# Доход от хеджа  1.6683207339949357
# Процентный заработок  0.6
# 125 день
# start_price =  3264.41
# end_price =  3409.12
# high_board =  3733.847575939991
# low_board =  2302.6732939653552
# Непрямые потери/прибыли  1.2299349738833287
# Доход от хеджа  -1.4540494287285464
# Процентный заработок  0.6
# 126 день
# start_price =  3409.12
# end_price =  2569.34
# high_board =  4139.824665587646
# low_board =  2560.170259078419
# Непрямые потери/прибыли  -18.86227954973274
# Доход от хеджа  11.394703681859674
# Процентный заработок  0.6
# 127 день
# start_price =  2569.03
# end_price =  2827.19
# high_board =  8367.805697726484
# low_board =  491.3218111714194
# Непрямые потери/прибыли  7.2334775499662385
# Доход от хеджа  -7.398159630262725
# Процентный заработок  0.6
# 128 день
# start_price =  2827.06
# end_price =  2376.85
# high_board =  4591.859770188113
# low_board =  2067.853716211493
# Непрямые потери/прибыли  -12.678027144453296
# Доход от хеджа  11.134870172568538
# Процентный заработок  0.6
# 129 день
# start_price =  2377.46
# end_price =  2373.85
# high_board =  3112.913618337729
# low_board =  1020.3455571006177
# Непрямые потери/прибыли  -0.053497693292958726
# Доход от хеджа  0.05336661781668588
# Процентный заработок  0.6
# 130 день
# start_price =  2374.3
# end_price =  2083.92
# high_board =  3079.7411269419313
# low_board =  1749.7577300202795
# Непрямые потери/прибыли  -7.90911181251256
# Доход от хеджа  6.487026383459246
# Процентный заработок  0.6
# 131 день
# start_price =  2083.45
# end_price =  2620.0
# high_board =  3754.964610593195
# low_board =  1174.1885846003868
# Непрямые потери/прибыли  14.00259850492458
# Доход от хеджа  -16.679651722030272
# Процентный заработок  0.6
# 132 день
# start_price =  2620.0
# end_price =  2600.12
# high_board =  5040.506565652845
# low_board =  2275.059340069184
# Непрямые потери/прибыли  -0.6668721109485354
# Доход от хеджа  0.6641344043770578
# Процентный заработок  0.6
# 133 день
# start_price =  2600.13
# end_price =  2820.44
# high_board =  3877.3870556654874
# low_board =  1919.9869620557506
# Непрямые потери/прибыли  5.052058578840435
# Доход от хеджа  -5.528888784091718
# Процентный заработок  0.6
# 134 день
# start_price =  2820.44
# end_price =  2781.91
# high_board =  3415.765809356574
# low_board =  2144.666305094237
# Непрямые потери/прибыли  -0.6606664784213678
# Доход от хеджа  0.639819254494258
# Процентный заработок  0.6
# 135 день
# start_price =  2781.91
# end_price =  2357.84
# high_board =  3242.123733117725
# low_board =  2316.7200886699875
# Непрямые потери/прибыли  -11.361894633356751
# Доход от хеджа  7.580936227418761
# Процентный заработок  0.6
# 136 день
# start_price =  2358.22
# end_price =  2268.0
# high_board =  2831.588713164847
# low_board =  1613.411876678014
# Непрямые потери/прибыли  -1.6310803794253426
# Доход от хеджа  1.4866465165657428
# Процентный заработок  0.6
# 137 день
# start_price =  2268.0
# end_price =  2433.93
# high_board =  2579.0013225638604
# low_board =  1545.8181629636165
# Непрямые потери/прибыли  1.6147621943420232
# Доход от хеджа  -2.2022508187302305
# Процентный заработок  0.6
# 138 день
# start_price =  2433.94
# end_price =  2627.51
# high_board =  2962.4620209748186
# low_board =  2070.334527008868
# Непрямые потери/прибыли  3.84875750408038
# Доход от хеджа  -4.711555867286152
# Процентный заработок  0.6
# 139 день
# start_price =  2627.55
# end_price =  2582.3
# high_board =  3455.7543282909205
# low_board =  2377.386351333982
# Непрямые потери/прибыли  -1.3590747920196877
# Доход от хеджа  1.322629203715257
# Процентный заработок  0.6
# 140 день
# start_price =  2582.3
# end_price =  2728.96
# high_board =  3118.2585774057543
# low_board =  2163.8036597804653
# Непрямые потери/прибыли  2.7528466668678586
# Доход от хеджа  -3.189192919434894
# Процентный заработок  0.6
# 141 день
# start_price =  2728.97
# end_price =  2816.14
# high_board =  3164.2030886224798
# low_board =  2506.8602815679446
# Непрямые потери/прибыли  1.9031472024058527
# Доход от хеджа  -2.114941088873203
# Процентный заработок  0.6
# 142 день
# start_price =  2816.14
# end_price =  2726.96
# high_board =  3180.966637922176
# low_board =  2380.763783933244
# Непрямые потери/прибыли  -1.6230762712533098
# Доход от хеджа  1.4437755128633893
# Процентный заработок  0.6
# 143 день
# start_price =  2726.76
# end_price =  2563.89
# high_board =  3323.920342165312
# low_board =  2487.4144064000543
# Непрямые потери/прибыли  -4.863371970533093
# Доход от хеджа  4.263989367114437
# Процентный заработок  0.6
# 144 день
# start_price =  2563.88
# end_price =  2714.53
# high_board =  2759.770487554034
# low_board =  1866.5366399949887
# Непрямые потери/прибыли  0.7931024228505557
# Доход от хеджа  -1.2886044210856977
# Процентный заработок  0.6
# 145 день
# start_price =  2714.22
# end_price =  2613.0
# high_board =  2977.9062199344967
# low_board =  2443.909524496164
# Непрямые потери/прибыли  -2.2016516664773667
# Доход от хеджа  1.8414933363000385
# Процентный заработок  0.6
# 146 день
# start_price =  2613.0
# end_price =  2526.99
# high_board =  2736.3494255579776
# low_board =  1974.0137187779446
# Непрямые потери/прибыли  -0.7213935834135543
# Доход от хеджа  0.5325990742576784
# Процентный заработок  0.6
# 147 день
# start_price =  2527.59
# end_price =  2586.03
# high_board =  3167.116844217162
# low_board =  2092.689651391892
# Непрямые потери/прибыли  1.3133329117447357
# Доход от хеджа  -1.3762120815341772
# Процентный заработок  0.6
# 148 день
# start_price =  2586.54
# end_price =  2476.08
# high_board =  3427.5884248778884
# low_board =  2247.488059886544
# Непрямые потери/прибыли  -3.2478304972435756
# Доход от хеджа  3.043602253526303
# Процентный заработок  0.6
# 149 день
# start_price =  2476.32
# end_price =  2351.18
# high_board =  2686.7784954553313
# low_board =  1994.5468446339655
# Непрямые потери/прибыли  -2.0050179067926166
# Доход от хеджа  1.5364003383622618
# Процентный заработок  0.6
# 150 день
# start_price =  2351.16
# end_price =  2407.74
# high_board =  2435.3257234350685
# low_board =  1924.1693162091506
# Непрямые потери/прибыли  0.26305714887082665
# Доход от хеджа  -0.39624355405809975
# Процентный заработок  0.6
# 151 день
# start_price =  2407.31
# end_price =  2519.11
# high_board =  2936.655113376646
# low_board =  2226.4006147166956
# Непрямые потери/прибыли  3.095746772753305
# Доход от хеджа  -3.461263787730379
# Процентный заработок  0.6
# 152 день
# start_price =  2519.11
# end_price =  2565.78
# high_board =  3273.27243777295
# low_board =  2443.9320493851037
# Непрямые потери/прибыли  1.6325733284060506
# Доход от хеджа  -1.6847006797469366
# Процентный заработок  0.6
# 153 день
# start_price =  2565.78
# end_price =  2531.04
# high_board =  3039.410240180444
# low_board =  2433.413328538948
# Непрямые потери/прибыли  -1.0973025803348357
# Доход от хеджа  1.0582283959892769
# Процентный заработок  0.6
# 154 день
# start_price =  2531.05
# end_price =  2417.99
# high_board =  2724.765211229316
# low_board =  2202.8335993404826
# Непрямые потери/прибыли  -2.152761374368528
# Доход от хеджа  1.6579001826307211
# Процентный заработок  0.6
# 155 день
# start_price =  2417.95
# end_price =  2349.56
# high_board =  2545.6945868755097
# low_board =  1969.9155740410524
# Непрямые потери/прибыли  -0.7979138578818601
# Доход от хеджа  0.627526344850838
# Процентный заработок  0.6
# 156 день
# start_price =  2349.54
# end_price =  2212.51
# high_board =  2478.8395123255864
# low_board =  1969.0808689389114
# Непрямые потери/прибыли  -2.2867634680326043
# Доход от хеджа  1.4793301313014013
# Процентный заработок  0.6
# 157 день
# start_price =  2212.74
# end_price =  2214.48
# high_board =  2384.967396291563
# low_board =  1740.4190323535358
# Непрямые потери/прибыли  0.0209057718150385
# Доход от хеджа  -0.021011912675442862
# Процентный заработок  0.6
# 158 день
# start_price =  2214.45
# end_price =  2258.14
# high_board =  2445.441684169145
# low_board =  1978.8271680051198
# Непрямые потери/прибыли  0.8843188941659363
# Доход от хеджа  -0.9766844333079795
# Процентный заработок  0.6
# 159 день
# start_price =  2258.03
# end_price =  1888.73
# high_board =  2781.1346717018
# low_board =  2073.671280853175
# Непрямые потери/прибыли  -15.427269606612127
# Доход от хеджа  12.09300485740227
# Процентный заработок  0.6
# 160 день
# start_price =  1888.9
# end_price =  1862.49
# high_board =  2198.7697687869572
# low_board =  1329.1161897967716
# Непрямые потери/прибыли  -0.519566495199375
# Доход от хеджа  0.49818695811933267
# Процентный заработок  0.6
# 161 день
# start_price =  1862.44
# end_price =  1943.38
# high_board =  2494.5108951169655
# low_board =  1386.7899934328568
# Непрямые потери/прибыли  2.3210226652878863
# Доход от хеджа  -2.479798265594634
# Процентный заработок  0.6
# 162 день
# start_price =  1943.38
# end_price =  1999.87
# high_board =  2169.1062499877257
# low_board =  1571.1167646429146
# Непрямые потери/прибыли  0.9599445904356685
# Доход от хеджа  -1.0972418526240542
# Процентный заработок  0.6
# 163 день
# start_price =  1999.57
# end_price =  1845.82
# high_board =  2373.0752245475037
# low_board =  1856.8805345305884
# Непрямые потери/прибыли  -6.745015642667351
# Доход от хеджа  5.563673815540694
# Процентный заработок  0.6
# 164 день
# start_price =  1845.8
# end_price =  1770.57
# high_board =  2137.041644611741
# low_board =  1433.8892466219318
# Непрямые потери/прибыли  -1.9107141702470631
# Доход от хеджа  1.688147666506046
# Процентный заработок  0.6
# 165 день
# start_price =  1770.94
# end_price =  1833.39
# high_board =  2067.8207375243273
# low_board =  1524.5956891335668
# Непрямые потери/прибыли  1.7245190972408952
# Доход от хеджа  -1.927217933385617
# Процентный заработок  0.6
# 166 день
# start_price =  1833.38
# end_price =  2133.3
# high_board =  2054.774220561136
# low_board =  1648.435028803475
# Непрямые потери/прибыли  3.289738380180607
# Доход от хеджа  -8.913135424068697
# Процентный заработок  0.6
# 167 день
# start_price =  2133.29
# end_price =  2217.46
# high_board =  2704.4228271700886
# low_board =  1983.0210755267274
# Непрямые потери/прибыли  2.8935112294762533
# Доход от хеджа  -3.1236859203806184
# Процентный заработок  0.6
# 168 день
# start_price =  2217.52
# end_price =  2259.42
# high_board =  2596.646609556707
# low_board =  2072.080229362559
# Непрямые потери/прибыли  1.2901590280357977
# Доход от хеджа  -1.365621330475926
# Процентный заработок  0.6
# 169 день
# start_price =  2259.42
# end_price =  2125.96
# high_board =  2990.422823287073
# low_board =  2142.877286524872
# Непрямые потери/прибыли  -5.564305623553323
# Доход от хеджа  5.094600863612171
# Процентный заработок  0.6
# 170 день
# start_price =  2125.95
# end_price =  2110.07
# high_board =  2546.20341765014
# low_board =  1848.7628080810216
# Непрямые потери/прибыли  -0.45862782098049504
# Доход от хеджа  0.45009218740635043
# Процентный заработок  0.6
# 171 день
# start_price =  2110.06
# end_price =  2226.04
# high_board =  2530.802721274529
# low_board =  1965.4490581146813
# Непрямые потери/прибыли  3.526783240095166
# Доход от хеджа  -4.0905782114314055
# Процентный заработок  0.6
# 172 день
# start_price =  2226.04
# end_price =  2378.17
# high_board =  2413.962990483761
# low_board =  2067.0689733666277
# Непрямые потери/прибыли  2.2036981378992015
# Доход от хеджа  -3.702243732490723
# Процентный заработок  0.6
# 173 день
# start_price =  2378.17
# end_price =  2240.68
# high_board =  2699.9892126807513
# low_board =  2294.7549049805034
# Непрямые потери/прибыли  -5.435132747177873
# Доход от хеджа  4.59128209709988
# Процентный заработок  0.6
# 174 день
# start_price =  2240.9
# end_price =  2281.6
# high_board =  2511.033748432919
# low_board =  1878.1622211468978
# Непрямые потери/прибыли  0.7168372316145533
# Доход от хеджа  -0.7752382995578275
# Процентный заработок  0.6
# 175 день
# start_price =  2281.6
# end_price =  2348.72
# high_board =  2654.1838208987915
# low_board =  2067.4786640954007
# Непрямые потери/прибыли  1.6998975517627857
# Доход от хеджа  -1.8681705707085183
# Процентный заработок  0.6
# 176 день
# start_price =  2348.97
# end_price =  2110.0
# high_board =  2472.1489442622606
# low_board =  2113.6634647194533
# Непрямые потери/прибыли  -7.064470639996745
# Доход от хеджа  3.495673173289522
# Процентный заработок  0.6
# 177 день
# start_price =  2110.11
# end_price =  2150.6
# high_board =  2300.025426557046
# low_board =  1813.5276915941272
# Непрямые потери/прибыли  0.6692186109416021
# Доход от хеджа  -0.7490694786115815
# Процентный заработок  0.6
# 178 день
# start_price =  2150.6
# end_price =  2103.87
# high_board =  2527.2383101161877
# low_board =  1990.6702306416803
# Непрямые потери/прибыли  -1.62088960967961
# Доход от хеджа  1.5252316169264746
# Процентный заработок  0.6
# 179 день
# start_price =  2103.87
# end_price =  2164.19
# high_board =  2301.262364048358
# low_board =  1869.6575042714178
# Непрямые потери/прибыли  1.110903755712167
# Доход от хеджа  -1.3112528775040926
# Процентный заработок  0.6
# 180 день
# start_price =  2164.36
# end_price =  2033.32
# high_board =  2417.4118209213193
# low_board =  2098.9789033101447
# Непрямые потери/прибыли  -5.758635675803225
# Доход от хеджа  4.811338317065531
# Процентный заработок  0.6
# 181 день
# start_price =  2033.32
# end_price =  1947.28
# high_board =  2106.910465414841
# low_board =  1656.525003228074
# Непрямые потери/прибыли  -1.1043258330544536
# Доход от хеджа  0.6914039481765916
# Процентный заработок  0.6
# 182 день
# start_price =  1947.29
# end_price =  1998.06
# high_board =  2060.7446306579423
# low_board =  1637.7862611757214
# Непрямые потери/прибыли  0.5428815492119377
# Доход от хеджа  -0.6993605536518365
# Процентный заработок  0.6
# 183 день
# start_price =  1998.24
# end_price =  1924.84
# high_board =  2390.311997636682
# low_board =  1896.4002570628036
# Непрямые потери/прибыли  -3.1938933736638475
# Доход от хеджа  2.915848043307744
# Процентный заработок  0.6
# 184 день
# start_price =  1924.84
# end_price =  1900.68
# high_board =  2114.179725475776
# low_board =  1613.4499909262006
# Непрямые потери/прибыли  -0.5050860546628622
# Доход от хеджа  0.47461412189429103
# Процентный заработок  0.6
# 185 день
# start_price =  1900.95
# end_price =  1907.11
# high_board =  2203.325163112991
# low_board =  1756.662176384003
# Непрямые потери/прибыли  0.21713495893680435
# Доход от хеджа  -0.21936946104692742
# Процентный заработок  0.6
# 186 день
# start_price =  1907.12
# end_price =  1911.61
# high_board =  2150.049584372623
# low_board =  1785.9711683008027
# Непрямые потери/прибыли  0.155640157737591
# Доход от хеджа  -0.15709190071078907
# Процентный заработок  0.6
# 187 день
# start_price =  1911.61
# end_price =  1813.25
# high_board =  1970.7235523843758
# low_board =  1646.5228914778802
# Непрямые потери/прибыли  -1.739342240439412
# Доход от хеджа  0.9381934340546105
# Процентный заработок  0.6
# 188 день
# start_price =  1813.24
# end_price =  1787.99
# high_board =  1902.9770580162397
# low_board =  1539.2290577071471
# Непрямые потери/прибыли  -0.39221110892023736
# Доход от хеджа  0.34353999442418853
# Процентный заработок  0.6
# 189 день
# start_price =  1788.0
# end_price =  1951.74
# high_board =  2157.2172557975205
# low_board =  1655.5340809740135
# Непрямые потери/прибыли  5.245233054320386
# Доход от хеджа  -6.7396869650262685
# Процентный заработок  0.6
# 190 день
# start_price =  1951.71
# end_price =  2010.26
# high_board =  2482.3790573825436
# low_board =  1788.5851504196762
# Непрямые потери/прибыли  2.1680051670506018
# Доход от хеджа  -2.294588939496441
# Процентный заработок  0.6
# 191 день
# start_price =  2010.26
# end_price =  2053.74
# high_board =  2362.4111228977677
# low_board =  1884.7780076286163
# Непрямые потери/прибыли  1.4962271583494058
# Доход от хеджа  -1.5946741420261044
# Процентный заработок  0.6
# 192 день
# start_price =  2053.75
# end_price =  2169.13
# high_board =  2241.022559015335
# low_board =  1900.3536896595556
# Непрямые потери/прибыли  2.1369632879322475
# Доход от хеджа  -3.0883367830815542
# Процентный заработок  0.6
# 193 день
# start_price =  2168.95
# end_price =  2157.39
# high_board =  2459.036806934443
# low_board =  2032.1392029915999
# Непрямые потери/прибыли  -0.369405613385676
# Доход от хеджа  0.36217006746735153
# Процентный заработок  0.6
# 194 день
# start_price =  2157.39
# end_price =  2241.7
# high_board =  2336.144822491669
# low_board =  1964.7858899483197
# Непрямые потери/прибыли  1.4374961433403
# Доход от хеджа  -1.8811105552565928
# Процентный заработок  0.6
# 195 день
# start_price =  2241.71
# end_price =  2260.5
# high_board =  2530.3552500137894
# low_board =  1697.676797964395
# Непрямые потери/прибыли  0.2811017798090898
# Доход от хеджа  -0.29055907204490866
# Процентный заработок  0.6
# 196 день
# start_price =  2260.96
# end_price =  2304.21
# high_board =  2651.1503328045483
# low_board =  2017.198011739014
# Непрямые потери/прибыли  1.112118639249604
# Доход от хеджа  -1.1773704777520821
# Процентный заработок  0.6
# 197 день
# start_price =  2304.11
# end_price =  2310.67
# high_board =  2595.075689511951
# low_board =  2062.8119857596853
# Непрямые потери/прибыли  0.1538834937845568
# Доход от хеджа  -0.15563797055559547
# Процентный заработок  0.6
# 198 день
# start_price =  2310.68
# end_price =  2440.55
# high_board =  2458.4060330176026
# low_board =  2125.915011563716
# Непрямые потери/прибыли  1.3994984265405686
# Доход от хеджа  -2.497158728811371
# Процентный заработок  0.6
# 199 день
# start_price =  2441.14
# end_price =  2530.82
# high_board =  2965.3427903325896
# low_board =  2399.162797154768
# Непрямые потери/прибыли  3.1103747194092257
# Доход от хеджа  -3.4013217958845274
# Процентный заработок  0.6
# 200 день
# start_price =  2530.81
# end_price =  2652.26
# high_board =  2899.5846070542148
# low_board =  2432.3103036583025
# Непрямые потери/прибыли  3.163637667266661
# Доход от хеджа  -3.787277149173107
# Процентный заработок  0.6
# 201 день
# start_price =  2652.45
# end_price =  2614.64
# high_board =  3087.4794122446297
# low_board =  2448.1702035552685
# Непрямые потери/прибыли  -1.0124449950519754
# Доход от хеджа  0.9699897203476926
# Процентный заработок  0.6
# 202 день
# start_price =  2614.65
# end_price =  2489.08
# high_board =  3021.252960435599
# low_board =  2362.8011653149547
# Непрямые потери/прибыли  -3.4348453634252984
# Доход от хеджа  2.965643086007956
# Процентный заработок  0.6
# 203 день
# start_price =  2489.02
# end_price =  2719.37
# high_board =  2822.657839432315
# low_board =  2188.6200704310218
# Непрямые потери/прибыли  3.188763242297399
# Доход от хеджа  -4.869899527928229
# Процентный заработок  0.6
# 204 день
# start_price =  2719.38
# end_price =  2819.68
# high_board =  3639.6720639148443
# low_board =  2651.088962653028
# Непрямые потери/прибыли  3.2464447415053943
# Доход от хеджа  -3.433551204390322
# Процентный заработок  0.6
# 205 день
# start_price =  2819.68
# end_price =  2894.05
# high_board =  4077.4848810216854
# low_board =  2599.5114882349767
# Непрямые потери/прибыли  2.1782703557818417
# Доход от хеджа  -2.2446292480456265
# Процентный заработок  0.6
# 206 день
# start_price =  2894.05
# end_price =  3107.35
# high_board =  3568.083539174152
# low_board =  2760.1695963912107
# Непрямые потери/прибыли  5.176026059614491
# Доход от хеджа  -6.1489537904072895
# Процентный заработок  0.6
# 207 день
# start_price =  3107.48
# end_price =  3034.23
# high_board =  3822.106543868079
# low_board =  2767.0158475722037
# Непрямые потери/прибыли  -1.6793735816684974
# Доход от хеджа  1.5965724717179592
# Процентный заработок  0.6
# 208 день
# start_price =  3034.21
# end_price =  3096.92
# high_board =  3288.2229627252714
# low_board =  2470.315527241179
# Непрямые потери/прибыли  0.5626330505148935
# Доход от хеджа  -0.6418638091321552
# Процентный заработок  0.6
# 209 день
# start_price =  3096.58
# end_price =  3168.54
# high_board =  3710.1983905592247
# low_board =  2767.648500965943
# Непрямые потери/прибыли  1.4241658006432178
# Доход от хеджа  -1.5128743877880946
# Процентный заработок  0.6
# 210 день
# start_price =  3168.54
# end_price =  3234.75
# high_board =  3661.8403084623174
# low_board =  2786.72226086567
# Непрямые потери/прибыли  1.0988538655090085
# Доход от хеджа  -1.1779019491133846
# Процентный заработок  0.6
# 211 день
# start_price =  3234.78
# end_price =  3042.6
# high_board =  3512.908169406206
# low_board =  2981.9531980005013
# Непрямые потери/прибыли  -4.220183155159873
# Доход от хеджа  3.1120798067718045
# Процентный заработок  0.6
# 212 день
# start_price =  3042.6
# end_price =  3299.0
# high_board =  3259.729922889295
# low_board =  2557.8956531807553
# Непрямые потери/прибыли  1.1039004978351752
# Доход от хеджа  -2.6071034694674053
# Процентный заработок  0.6
# 213 день
# start_price =  3299.0
# end_price =  3283.92
# high_board =  3767.621288196252
# low_board =  3097.9682327214864
# Непрямые потери/прибыли  -0.32504164644107103
# Доход от хеджа  0.3198830179666472
# Процентный заработок  0.6
# 214 день
# start_price =  3283.92
# end_price =  3301.92
# high_board =  3638.813243464551
# low_board =  3041.114693205402
# Непрямые потери/прибыли  0.31720484546342576
# Доход от хеджа  -0.3254583851410857
# Процентный заработок  0.6
# 215 день
# start_price =  3301.91
# end_price =  3170.17
# high_board =  3892.956665576808
# low_board =  3177.324958648258
# Непрямые потери/прибыли  -3.668419397878886
# Доход от хеджа  3.295221593484946
# Процентный заработок  0.6
# 216 день
# start_price =  3170.16
# end_price =  3038.63
# high_board =  3425.2128973861536
# ...
# 274 день
# start_price =  3639.7
# end_price =  3804.9
# high_board =  4209.828741293567
# low_board =  3560.6004759849616
# Непрямые потери/прибыли  3.4083741176706317
# Доход от хеджа  -3.985840999669434
# Процентный заработок  0.6
# 275 день
# start_price =  3804.9
# end_price =  3847.75
# high_board =  4153.567899274182
# low_board =  3457.8605312377445
# Непрямые потери/прибыли  0.5297259005317967
# Доход от хеджа  -0.5644077146951111
# Процентный заработок  0.6
# 276 день
# start_price =  3847.76
# end_price =  3894.43
# high_board =  4265.810583608623
# low_board =  3644.6330991894674
# Непрямые потери/прибыли  0.7707231299038053
# Доход от хеджа  -0.8162871384790185
# Процентный заработок  0.6
# 277 день
# start_price =  3894.43
# end_price =  3851.24
# high_board =  4197.034791999792
# low_board =  3558.2612553339172
# Непрямые потери/прибыли  -0.5630751920243204
# Доход от хеджа  0.5253735294523539
# Процентный заработок  0.6
# 278 день
# start_price =  3851.23
# end_price =  3842.21
# high_board =  4327.841028206772
# low_board =  3604.931556666044
# Непрямые потери/прибыли  -0.15587708605078188
# Доход от хеджа  0.15441420643266834
# Процентный заработок  0.6
# 279 день
# start_price =  3842.22
# end_price =  3846.35
# high_board =  4320.503406615719
# low_board =  3626.9538524005507
# Непрямые потери/прибыли  0.07380682170681219
# Доход от хеджа  -0.07412686621726577
# Процентный заработок  0.6
# 280 день
# start_price =  3846.35
# end_price =  4165.5
# high_board =  4231.334105592085
# low_board =  3719.050374221551
# Непрямые потери/прибыли  3.6509588653546254
# Доход от хеджа  -6.235600507974334
# Процентный заработок  0.6
# 281 день
# start_price =  4165.5
# end_price =  4146.53
# high_board =  4764.108096906413
# low_board =  3922.963491864692
# Непрямые потери/прибыли  -0.3292418713131573
# Доход от хеджа  0.3240948389856552
# Процентный заработок  0.6
# 282 день
# start_price =  4146.54
# end_price =  4047.2
# high_board =  4749.54409310736
# low_board =  3730.611338985172
# Непрямые потери/прибыли  -1.5359945239752482
# Доход от хеджа  1.4177936713634305
# Процентный заработок  0.6
# 283 день
# start_price =  4047.2
# end_price =  4113.21
# high_board =  4612.232582219458
# low_board =  3882.7276297696335
# Непрямые потери/прибыли  1.1894904786347915
# Доход от хеджа  -1.2632820160651859
# Процентный заработок  0.6
# 284 день
# start_price =  4113.21
# end_price =  4140.95
# high_board =  4381.30385921693
# low_board =  3846.558710896041
# Непрямые потери/прибыли  0.32062326177801914
# Доход от хеджа  -0.33811589466683944
# Процентный заработок  0.6
# 285 день
# start_price =  4140.95
# end_price =  4211.9
# high_board =  4751.223470661727
# low_board =  4041.9416403704085
# Непрямые потери/прибыли  1.388510545429189
# Доход от хеджа  -1.4742056439954612
# Процентный заработок  0.6
# 286 день
# start_price =  4211.91
# end_price =  4266.76
# high_board =  4511.768173609684
# low_board =  4010.0683589839223
# Непрямые потери/прибыли  0.7071533422048359
# Доход от хеджа  -0.7783402690867709
# Процентный заработок  0.6
# 287 день
# start_price =  4266.76
# end_price =  3999.93
# high_board =  4824.987840425409
# low_board =  3955.2541626479997
# Непрямые потери/прибыли  -5.004119563782982
# Доход от хеджа  4.013854691982718
# Процентный заработок  0.6
# 288 день
# start_price =  3999.93
# end_price =  4369.7
# high_board =  4503.537542450997
# low_board =  3627.7032528479517
# Непрямые потери/прибыли  3.364109466906662
# Доход от хеджа  -5.315566599514912
# Процентный заработок  0.6
# 289 день
# start_price =  4369.7
# end_price =  4355.46
# high_board =  5345.404414980161
# low_board =  4086.4671681459076
# Непрямые потери/прибыли  -0.2544106902105936
# Доход от хеджа  0.2525646443060803
# Процентный заработок  0.6
# 290 день
# start_price =  4355.47
# end_price =  4373.91
# high_board =  4534.224387802867
# low_board =  3919.8784564403836
# Непрямые потери/прибыли  0.11683439283129982
# Доход от хеджа  -0.12318834329448132
# Процентный заработок  0.6
# 291 день
# start_price =  4373.9
# end_price =  4212.0
# high_board =  4862.034597760829
# low_board =  4184.13519643332
# Непрямые потери/прибыли  -3.115680470584692
# Доход от хеджа  2.665338295370724
# Процентный заработок  0.6
# 292 день
# start_price =  4212.03
# end_price =  4333.98
# high_board =  4570.848566780725
# low_board =  3851.8089109378116
# Непрямые потери/прибыли  1.1992941909425126
# Доход от хеджа  -1.4448155701118448
# Процентный заработок  0.6
# 293 день
# start_price =  4333.99
# end_price =  4568.69
# high_board =  4695.159291702825
# low_board =  3963.5363776746144
# Непрямые потери/прибыли  1.8047038760985012
# Доход от хеджа  -2.6733061855428635
# Процентный заработок  0.6
# 294 день
# start_price =  4568.7
# end_price =  4573.98
# high_board =  5098.015539948983
# low_board =  4364.524697829675
# Непрямые потери/прибыли  0.08298311522307866
# Доход от хеджа  -0.08339907421029588
# Процентный заработок  0.6
# 295 день
# start_price =  4573.98
# end_price =  4535.97
# high_board =  4979.200827404413
# low_board =  4283.557201376341
# Непрямые потери/прибыли  -0.5068682331983432
# Доход от хеджа  0.48407043339216393
# Процентный заработок  0.6
# 296 день
# start_price =  4535.96
# end_price =  4491.22
# high_board =  4958.058370609633
# low_board =  4286.311342776435
# Непрямые потери/прибыли  -0.6527850335131369
# Доход от хеджа  0.619775901566423
# Процентный заработок  0.6
# 297 день
# start_price =  4491.22
# end_price =  4549.7
# high_board =  4750.800663178354
# low_board =  4220.148648110713
# Непрямые потери/прибыли  0.565202182047897
# Доход от хеджа  -0.6369503118615235
# Процентный заработок  0.6
# 298 день
# start_price =  4549.69
# end_price =  4724.26
# high_board =  5155.748683086745
# low_board =  4475.9235718169
# Непрямые потери/прибыли  2.92798292493055
# Доход от хеджа  -3.4206235463319667
# Процентный заработок  0.6
# 299 день
# start_price =  4724.25
# end_price =  4804.1
# high_board =  5246.0039986424235
# low_board =  4633.276692805694
# Непрямые потери/прибыли  1.3291308798601076
# Доход от хеджа  -1.439264455315148
# Процентный заработок  0.6
# 300 день
# start_price =  4804.11
# end_price =  4694.06
# high_board =  5185.163389767774
# low_board =  4586.0382489411895
# Непрямые потери/прибыли  -1.669777472380285
# Доход от хеджа  1.4569524874572908
# Процентный заработок  0.6
# 301 день
# start_price =  4694.06
# end_price =  4632.35
# high_board =  4887.934059910229
# low_board =  4195.618173570688
# Непрямые потери/прибыли  -0.42712619719534883
# Доход от хеджа  0.36814789154120814
# Процентный заработок  0.6
# 302 день
# start_price =  4632.35
# end_price =  4766.92
# high_board =  5153.609770995569
# low_board =  3587.96237284309
# Непрямые потери/прибыли  0.8423346085592476
# Доход от хеджа  -0.9671796170442225
# Процентный заработок  0.6
# 303 день
# start_price =  4766.93
# end_price =  4625.38
# high_board =  5200.847148233024
# low_board =  4492.9023496739455
# Непрямые потери/прибыли  -2.1213637372577643
# Доход от хеджа  1.8200298779444188
# Процентный заработок  0.6
# 304 день
# start_price =  4625.37
# end_price =  4639.28
# high_board =  5104.275041587852
# low_board =  4280.109558558784
# Непрямые потери/прибыли  0.17221154284792206
# Доход от хеджа  -0.17474937773500043
# Процентный заработок  0.6
# 305 день
# start_price =  4639.27
# end_price =  4713.47
# high_board =  4822.309537060924
# low_board =  4325.382275932633
# Непрямые потери/прибыли  0.469714966552659
# Доход от хеджа  -0.5891234942899234
# Процентный заработок  0.6
# 306 день
# start_price =  4713.47
# end_price =  4306.49
# high_board =  5419.099371075227
# low_board =  4600.114881004422
# Непрямые потери/прибыли  -8.480491127524626
# Доход от хеджа  7.43932089796564
# Процентный заработок  0.6
# 307 день
# start_price =  4306.48
# end_price =  4111.0
# high_board =  4374.532021947946
# low_board =  3270.719812665333
# Непрямые потери/прибыли  -0.691120598191064
# Доход от хеджа  0.2798502734738117
# Процентный заработок  0.6
# 308 день
# start_price =  4110.99
# end_price =  4284.44
# high_board =  4365.94297956187
# low_board =  3254.60802771628
# Непрямые потери/прибыли  0.6386767984266184
# Доход от хеджа  -0.967927886668933
# Процентный заработок  0.6
# 309 день
# start_price =  4284.44
# end_price =  4033.17
# high_board =  4996.44634785517
# low_board =  4071.6042649824144
# Непрямые потери/прибыли  -5.3129211808292
# Доход от хеджа  4.515053044567772
# Процентный заработок  0.6
# 310 день
# start_price =  4033.16
# end_price =  4270.34
# high_board =  4639.190303485036
# low_board =  3472.914536383506
# Непрямые потери/прибыли  2.4578354110690315
# Доход от хеджа  -3.055805458508145
# Процентный заработок  0.6
# 311 день
# start_price =  4270.33
# end_price =  4359.8
# high_board =  4676.130487994941
# low_board =  4060.9356611426742
# Непрямые потери/прибыли  1.2296720560526886
# Доход от хеджа  -1.3820249705696246
# Процентный заработок  0.6
# 312 день
# start_price =  4359.8
# end_price =  4182.51
# high_board =  5076.910536831429
# low_board =  4243.414709426344
# Непрямые потери/прибыли  -3.885252485617563
# Доход от хеджа  3.4986487780973086
# Процентный заработок  0.6
# 313 день
# start_price =  4181.83
# end_price =  4177.12
# high_board =  4397.627095854527
# low_board =  3408.491178675746
# Непрямые потери/прибыли  -0.02484051483339078
# Доход от хеджа  0.024572206528995222
# Процентный заработок  0.6
# 314 день
# start_price =  4177.21
# end_price =  4285.05
# high_board =  4611.990082294923
# low_board =  3614.8140681132877
# Непрямые потери/прибыли  0.9860233590064382
# Доход от хеджа  -1.1256189270094485
# Процентный заработок  0.6
# 315 день
# start_price =  4285.04
# end_price =  4286.5
# high_board =  4549.766871466265
# low_board =  3835.7024939627427
# Непрямые потери/прибыли  0.012596775449980058
# Доход от хеджа  -0.012631607855481713
# Процентный заработок  0.6
# 316 день
# start_price =  4286.5
# end_price =  4435.01
# high_board =  4783.029530404239
# low_board =  4025.7304539065676
# Непрямые потери/прибыли  1.93188081854605
# Доход от хеджа  -2.2715930196201066
# Процентный заработок  0.6
# 317 день
# start_price =  4435.0
# end_price =  4124.67
# high_board =  4688.305950033105
# low_board =  4036.2725503285683
# Непрямые потери/прибыли  -4.443874583228125
# Доход от хеджа  2.7183519564059115
# Процентный заработок  0.6
# 318 день
# start_price =  4124.68
# end_price =  4031.41
# high_board =  4857.312031598053
# low_board =  3840.4401779915443
# Непрямые потери/прибыли  -1.7340791050370674
# Доход от хеджа  1.6291887108355234
# Процентный заработок  0.6
# 319 день
# start_price =  4031.41
# end_price =  4320.32
# high_board =  4237.039259043858
# low_board =  3450.3897250665814
# Непрямые потери/прибыли  0.6666556544551394
# Доход от хеджа  -1.8733081665927365
# Процентный заработок  0.6
# 320 день
# start_price =  4320.32
# end_price =  4438.54
# high_board =  5493.827803535207
# low_board =  4136.236409404727
# Непрямые потери/прибыли  2.2461885576166463
# Доход от хеджа  -2.3653311162429427
# Процентный заработок  0.6
# 321 день
# start_price =  4438.53
# end_price =  4732.96
# high_board =  5078.720439022811
# low_board =  4221.24964184873
# Непрямые потери/прибыли  3.813720344164029
# Доход от хеджа  -4.952594202827265
# Процентный заработок  0.6
# 322 день
# start_price =  4732.97
# end_price =  4511.47
# high_board =  5689.849548792857
# low_board =  4319.8883053409345
# Непрямые потери/прибыли  -3.6562037434938466
# Доход от хеджа  3.2688046750761743
# Процентный заработок  0.6
# 323 день
# start_price =  4511.84
# end_price =  4523.99
# high_board =  4765.7984693608705
# low_board =  3590.916029026929
# Непрямые потери/прибыли  0.05681666533818852
# Доход от хеджа  -0.0582090988184001
# Процентный заработок  0.6
# 324 день
# start_price =  4523.99
# end_price =  4115.3
# high_board =  4935.856007501992
# low_board =  4145.978118351714
# Непрямые потери/прибыли  -7.13576486358617
# Доход от хеджа  4.710514749786417
# Процентный заработок  0.6
# 325 день
# start_price =  4115.32
# end_price =  4140.79
# high_board =  4399.824559009971
# low_board =  3085.6387152017405
# Непрямые потери/прибыли  0.12798803136644388
# Доход от хеджа  -0.13398549328009765
# Процентный заработок  0.6
# 326 день
# start_price =  4140.79
# end_price =  4184.13
# high_board =  4987.234511430417
# low_board =  3851.6855240614177
# Непрямые потери/прибыли  0.7602125904320189
# Доход от хеджа  -0.7801863003446741
# Процентный заработок  0.6
# 327 день
# start_price =  4184.13
# end_price =  4355.34
# high_board =  4850.715202658035
# low_board =  3793.334411667814
# Непрямые потери/прибыли  2.248298004442284
# Доход от хеджа  -2.57957530062162
# Процентный заработок  0.6
# 328 день
# start_price =  4355.51
# end_price =  4319.11
# high_board =  5472.080915452983
# low_board =  4186.287572995063
# Непрямые потери/прибыли  -0.7376130960143445
# Доход от хеджа  0.7257340617412936
# Процентный заработок  0.6
# 329 день
# start_price =  4319.11
# end_price =  4374.01
# high_board =  4681.287135771067
# low_board =  3802.7469555433113
# Непрямые потери/прибыли  0.4842920858889821
# Доход от хеджа  -0.5240074729520089
# Процентный заработок  0.6
# 330 день
# start_price =  4374.01
# end_price =  4157.02
# high_board =  4730.206194356925
# low_board =  3928.5767075526824
# Непрямые потери/прибыли  -2.8928251029871177
# Доход от хеджа  2.204324560599296
# Процентный заработок  0.6
# 331 день
# start_price =  4157.01
# end_price =  4024.61
# high_board =  4648.931200397772
# low_board =  3588.0102621463643
# Непрямые потери/прибыли  -1.6787469046975811
# Доход от хеджа  1.4767923534228413
# Процентный заработок  0.6
# 332 день
# start_price =  4024.9
# end_price =  4040.26
# high_board =  4781.887028166662
# low_board =  3593.559903276272
# Непрямые потери/прибыли  0.24063562145155704
# Доход от хеджа  -0.24310200906475182
# Процентный заработок  0.6
# 333 день
# start_price =  4040.26
# end_price =  4008.9
# high_board =  4317.495545811703
# low_board =  3640.3844213191096
# Непрямые потери/прибыли  -0.3358456899682616
# Доход от хеджа  0.3178013251640746
# Процентный заработок  0.6
# 334 день
# start_price =  4008.91
# end_price =  3781.4
# high_board =  4315.891489799642
# low_board =  3653.494257389716
# Непрямые потери/прибыли  -3.633135264503262
# Доход от хеджа  2.6300733711472355
# Процентный заработок  0.6
# 335 день
# start_price =  3782.21
# end_price =  3877.66
# high_board =  4350.078413462086
# low_board =  3262.9514845882272
# Непрямые потери/прибыли  1.207461088015549
# Доход от хеджа  -1.3182499184305851
# Процентный заработок  0.6
# 336 день
# start_price =  3877.65
# end_price =  3999.42
# high_board =  4593.738806988951
# low_board =  3601.9858601770884
# Непрямые потери/прибыли  2.0746489086465925
# Доход от хеджа  -2.2674362481821064
# Процентный заработок  0.6
# 337 день
# start_price =  3999.43
# end_price =  3975.95
# high_board =  5525.239237354144
# low_board =  3845.693643937534
# Непрямые потери/прибыли  -0.5374610417692827
# Доход от хеджа  0.5333452537139629
# Процентный заработок  0.6
# 338 день
# start_price =  3975.94
# end_price =  3869.37
# high_board =  4204.435315741859
# low_board =  3447.482886588486
# Непрямые потери/прибыли  -1.0003485914959587
# Доход от хеджа  0.8091030868619801
# Процентный заработок  0.6
# 339 день
# start_price =  3869.36
# end_price =  3997.13
# high_board =  4570.162087425695
# low_board =  3333.911493967743
# Непрямые потери/прибыли  1.7012421896242413
# Доход от хеджа  -1.8718827006575187
# Процентный заработок  0.6
# 340 день
# start_price =  3997.13
# end_price =  3911.03
# high_board =  4390.774144035151
# low_board =  3764.9626079888335
# Непрямые потери/прибыли  -1.504716082313129
# Доход от хеджа  1.3549245405538666
# Процентный заработок  0.6
# 341 день
# start_price =  3911.03
# end_price =  4040.46
# high_board =  4237.925542646326
# low_board =  3574.185713276688
# Непрямые потери/прибыли  1.3072130733462473
# Доход от хеджа  -1.6298773457889275
# Процентный заработок  0.6
# 342 день
# start_price =  4040.47
# end_price =  4047.88
# high_board =  4933.225510648145
# low_board =  3897.6056383812606
# Непрямые потери/прибыли  0.15743902145075594
# Доход от хеджа  -0.15809512767587555
# Процентный заработок  0.6
# 343 день
# start_price =  4047.87
# end_price =  3964.58
# high_board =  4382.451933382878
# low_board =  3908.8807887913995
# Непрямые потери/прибыли  -1.6365541757402013
# Доход от хеджа  1.4537293536581983
# Процентный заработок  0.6
# 344 день
# start_price =  3964.57
# end_price =  4094.68
# high_board =  4175.287490358533
# low_board =  3584.3079121096407
# Непрямые потери/прибыли  0.8088907022916203
# Доход от хеджа  -1.170153128246708
# Процентный заработок  0.6
# 345 день
# start_price =  4094.68
# end_price =  4048.91
# high_board =  4664.9485224510145
# low_board =  3995.4667417696164
# Непрямые потери/прибыли  -0.9905660989990794
# Доход от хеджа  0.9521416930555452
# Процентный заработок  0.6

# %% [markdown]
# ##### Статическое хеджирование (самый простой способ, честный)

# %%
start_amount = 100000
gas_price = 10  # за одну операцию, внутри умножение на 2
back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price, verbose=False, hedge_type='simple')

# %% [markdown]
# #### Используем динамический хедж

# %% [markdown]
# # Сравнение стратегий

# %%
start_amount = 100000
gas_price = 10 # за одну операцию, внутри умножение на 2
dyn_no_wait = back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price,
                               verbose=False, hedge_type='dynamic', wait_dangerous=False,
    plot=False)
dyn_wait = back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price,
                               verbose=False, hedge_type='dynamic', wait_dangerous=True,
    plot=False)
static_wait = back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price,
                               verbose=False, hedge_type='simple', wait_dangerous=True,
    plot=False)
static_no_wait = back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price,
                               verbose=False, hedge_type='simple', wait_dangerous=False,
    plot=False)
x = dyn_wait[0]
plt.plot(x, dyn_wait[1], label='Динамический, пропуски')
plt.plot(x, dyn_no_wait[1], label='Динамический, без пропусков')
plt.plot(x, static_wait[1], label='Статический, пропуски')
plt.plot(x, static_no_wait[1], label='Статический, без пропусков')
plt.xlabel('Дата бектеста', fontsize=15)
plt.ylabel('Всего средств', fontsize=15)
plt.xticks(fontsize = (50/len(x)+3), rotation=45)
plt.title('Анализ итоговой доходности старт с {} $'.format(start_amount), fontsize = 15)
plt.legend(prop={'size': 10})
plt.show()
# Out:
# 0.13899948011563965
#
#
# 0.142306593601372
#
# Избежали убытков:  890.0638409503008
# Избежали убытков:  39.58648060521227
# Избежали убытков:  47.10616587862023
# упущенная выгода:  75.1038553591643
# Избежали убытков:  601.0748270089534
# упущенная выгода:  38.9696307478589
#
# 0.12479775255234812
#
#
# 0.13545403731857505
#
#
# 0.1180030073965639
#
# упущенная выгода:  89.20883828160004
# упущенная выгода:  101.2659277266066
# упущенная выгода:  158.72791323793354
#
# 0.14275093560381458
#
#
# 0.14651500717826796
#
#
# 0.147440793817463
#
# упущенная выгода:  112.35466864272894
# Избежали убытков:  196.9724571974657
# упущенная выгода:  121.34706185254618
# Избежали убытков:  447.33607650488557
# упущенная выгода:  57.938921616994776
# упущенная выгода:  109.49077601639146
# Избежали убытков:  112.12153280776693
# упущенная выгода:  16.674497401254484
# упущенная выгода:  16.5961100266868
# Избежали убытков:  24.801490912228473
# упущенная выгода:  1.5749556625960395
# Избежали убытков:  29.004378022335004
# упущенная выгода:  97.31376052394626
# Избежали убытков:  901.0927801875805
# Избежали убытков:  179.27488804669701
# Избежали убытков:  4.378529362074914
# Избежали убытков:  348.92672717133246
# Избежали убытков:  422.0841570188495
# Избежали убытков:  264.6359185297333
# Избежали убытков:  144.24024079999072
# Избежали убытков:  539.2608836307045
# Избежали убытков:  588.4383340576896
# упущенная выгода:  26.05339083193394
# Избежали убытков:  15.005692147125956
# Избежали убытков:  29.92271043913206
# Избежали убытков:  357.1351951374527
# Избежали убытков:  227.1511036690208
# Избежали убытков:  137.61965038040944
# Избежали убытков:  440.86928682737926
# Избежали убытков:  159.58496819688298
# Избежали убытков:  77.48311316651234
# Избежали убытков:  282.31095470405126
# Избежали убытков:  196.92710309258837
# Избежали убытков:  45.37824332843593
# упущенная выгода:  63.98352755709493
# упущенная выгода:  28.107246714294888
# упущенная выгода:  25.267700436801533
# Избежали убытков:  95.07643335669127
# Избежали убытков:  358.08392168693535
# Избежали убытков:  466.7701850925223
# упущенная выгода:  2.640920804318739
# упущенная выгода:  25.05256175728573
# Избежали убытков:  1322.5020587738109
# Избежали убытков:  1110.2598630722932
# Избежали убытков:  121.88056496060744
# Избежали убытков:  273.95591632578
# Избежали убытков:  1085.3222642241017
# Избежали убытков:  131.5197750099469
# Избежали убытков:  197.59094335920236
# Избежали убытков:  499.7548036619992
# Избежали убытков:  1425.4986386890814
# Избежали убытков:  788.9750003562513
# упущенная выгода:  3.060687788965879
# Избежали убытков:  552.4397141844383
# Избежали убытков:  59.7948411439138
# Избежали убытков:  25.611930430488428
# упущенная выгода:  51.157558511258685
# Избежали убытков:  25.75178056488221
# Избежали убытков:  661.6469203143788
# Избежали убытков:  23.203275781866978
# Избежали убытков:  63.20260598543973
# упущенная выгода:  85.18278369726613
# упущенная выгода:  120.5432944787899
# Избежали убытков:  84.40205873393279
# упущенная выгода:  0.3390049513982376
# упущенная выгода:  79.18047255510464
# упущенная выгода:  58.32232420766377
#
# 0.14726849314136928
#
# Избежали убытков:  196.95108015931328
# Избежали убытков:  23.49725928105181
# упущенная выгода:  78.63121254296857
# Избежали убытков:  545.3817351568578
# упущенная выгода:  25.553331966293626
# упущенная выгода:  4.3421921745321015
# Избежали убытков:  243.78458084371232
# упущенная выгода:  33.02117557784368
# упущенная выгода:  94.00338234982337
# Избежали убытков:  2548.4399237949547
# упущенная выгода:  71.1634141987306
#
# 0.14587126013817037
#
# Избежали убытков:  121.59025378114893
# Избежали убытков:  264.5862012611906
# упущенная выгода:  89.30672997086367
# Избежали убытков:  111.77086998712912
# Избежали убытков:  257.5034361954313
# упущенная выгода:  64.98828528670128
#
# 0.14973097556032225
#
# упущенная выгода:  108.93252382945502
# упущенная выгода:  5.964599307262688
#
# 0.13961890122956297
#
#
# 0.12128368386440067
#
# Избежали убытков:  605.8927656696615
# Избежали убытков:  137.0593573217484
# упущенная выгода:  147.00711596591282
#
# 0.12930831878910465
#
# Избежали убытков:  971.1089715744165
# Избежали убытков:  61.18030578897742
# упущенная выгода:  76.46038893992954
# упущенная выгода:  15.885409446884296
# упущенная выгода:  44.24469580510049
# упущенная выгода:  105.67403241273132
#
# 0.1345678658840832
#
# упущенная выгода:  50.644271076249424
# упущенная выгода:  9.678045042892336
# Избежали убытков:  76.83353413328587
# Избежали убытков:  283.1315973560704
# упущенная выгода:  9.061607649360667
# Избежали убытков:  15.772180132262292
#
# 0.14302331044728092
#
# Избежали убытков:  203.74829458953172
#
# 0.14618967791446147
#
#
# 0.13488559152273108
#
#
# 0.1374608458777766
#
# Избежали убытков:  78.37605124026595
# упущенная выгода:  106.68080907309195
#
# 0.13328577659089638
#
# упущенная выгода:  114.00978217809461
#
# 0.12268481554831237
#
#
# 0.14492015946235182
#
#
# 0.11126240143891014
#
# упущенная выгода:  48.30743849740247
#
# 0.1262594144366032
#
# упущенная выгода:  37.6319444712135
# Избежали убытков:  361.5682941599225
# Избежали убытков:  538.4731360412843
# упущенная выгода:  6.971830271562794
# Избежали убытков:  41.019763413540204
# упущенная выгода:  97.21440062885813
# упущенная выгода:  131.72282464375894
#
# 0.10337315012658198
#
# упущенная выгода:  147.81971275202523
#
# 0.09810620727415682
#
#
# 0.09763157887817578
#
# Избежали убытков:  232.0492380890064
# упущенная выгода:  56.008320989771164
#
# 0.1207587226750319
#
#
# 0.10020498426286792
#
#
# 0.13112057129910656
#
# упущенная выгода:  93.5202717368229
#
# 0.11285007379008075
#
#
# 0.13091830170152394
#
#
# 0.11193993455680865
#
#
# 0.0875618085887399
#
#
# 0.0793720239211718
#
#
# 0.0686921946726298
#
# упущенная выгода:  144.8847753664013
#
# 0.09720251288703743
#
# упущенная выгода:  53.28685502373264
#
# 0.1070197545503291
#
#
# 0.12049680147208801
#
# упущенная выгода:  79.5755806050729
#
# 0.12634249994490002
#
#
# 0.13637878108376053
#
#
# 0.10855153821691958
#
#
# 0.10277008904395121
#
# упущенная выгода:  194.49196150466742
#
# 0.07232265663428145
#
#
# 0.09342785321412203
#
#
# 0.11550778131011342
#
# упущенная выгода:  109.78951445138955
#
# 0.12569149821223882
#
#
# 0.1178129715456535
#
#
# 0.13447875393730588
#
#
# 0.08488026555742118
#
#
# 0.07378628083548411
#
#
# 0.0935343208676483
#
#
# 0.11596800537201785
#
#
# 0.07960026552181618
#
#
# 0.07081774104874279
#
#
# 0.08483709831918464
#
#
# 0.06368584050751168
#
#
# 0.05732232632707006
#
#
# 0.09865741893686361
#
#
# 0.08661978625550795
#
#
# 0.09063264092855519
#
# Избежали убытков:  17.324966357642552
# Избежали убытков:  177.41199905097892
# Избежали убытков:  558.095097132842
# Избежали убытков:  314.57477309543174
# упущенная выгода:  34.632567822540295
# Избежали убытков:  42.4675053004903
# Избежали убытков:  21.29582447989378
# Избежали убытков:  689.2759533435601
# Избежали убытков:  10.866509270315873
# Избежали убытков:  1102.0578855091735
# Избежали убытков:  156.35533213157032
# Избежали убытков:  49.88197935379867
# упущенная выгода:  52.16096774704056
# упущенная выгода:  98.24875688483007
# упущенная выгода:  115.87524228330585
#
# 0.13244553555793676
#
# Избежали убытков:  50.3617679001909
# упущенная выгода:  14.726062634392292
# упущенная выгода:  116.871770864047
#
# 0.14106457142556425
#
# упущенная выгода:  26.09700655953202
# Избежали убытков:  541.2208057710377
# упущенная выгода:  7.977506716066273
# упущенная выгода:  55.29934143582068
# упущенная выгода:  102.76302628339909
# упущенная выгода:  20.817185781430453
# упущенная выгода:  59.566557977566845
# Избежали убытков:  69.1417813089356
# упущенная выгода:  22.562560681370087
#
# 0.14931055183693107
#
# упущенная выгода:  44.15320120588876
#
# 0.14410360657367338
#
#
# 0.12725148479296833
#
# Избежали убытков:  129.83998664621322
# упущенная выгода:  10.994163383817067
#
# 0.13242379785325734
#
# упущенная выгода:  106.89422796378494
#
# 0.13467632947912417
#
#
# 0.14542859835370114
#
# Избежали убытков:  79.61764418019447
# Избежали убытков:  592.9945777506073
# Избежали убытков:  861.0235249500838
# упущенная выгода:  28.311226402336615
# Избежали убытков:  777.8675609291677
# Избежали убытков:  175.3148804040393
# Избежали убытков:  143.2185655792855
# Избежали убытков:  229.2512580928742
# упущенная выгода:  42.82503198966151
# Избежали убытков:  158.78396984793653
# упущенная выгода:  4.190279582951916
# упущенная выгода:  130.8684215098765
# Избежали убытков:  73.51786361575068
# Избежали убытков:  170.609810366077
# упущенная выгода:  16.11043043526297
# Избежали убытков:  5.545963071461301
# Избежали убытков:  201.82379429212597
# Избежали убытков:  58.042147046056925
# упущенная выгода:  101.19943612383213
# упущенная выгода:  72.26637973032484
#
# 0.11731179311671545
#
# Избежали убытков:  1048.9223185412848
# упущенная выгода:  87.96932421876409
#
# 0.1487311347911592
#
# Избежали убытков:  152.52191391763336
# Избежали убытков:  160.7043371964246
# упущенная выгода:  78.40723245024856
#
# 0.14562544193388022
#
# Избежали убытков:  17.2150262517971
#
# 0.1488218406964743
#
#
# 0.13941518750104379
#
#
# 0.11594449458825457
#
# Избежали убытков:  66.40774173717364
#
# 0.13085937053746263
#
#
# 0.08382883197275955
#
#
# 0.11000138293557414
#
#
# 0.07696652567016747
#
# упущенная выгода:  149.7972289872705
#
# 0.10666335483541907
#
#
# 0.1005022066855833
#
# упущенная выгода:  110.0827302460093
#
# 0.12140477367464299
#
#
# 0.09194585031703988
#
# упущенная выгода:  105.56343760841992
#
# 0.12021846967012649
#
#
# 0.11740423519873941
#
#
# 0.11862336796469242
#
#
# 0.10909959855002652
#
#
# 0.06751837795687107
#
#
# 0.07437968526666296
#
#
# 0.08728897641991948
#
#
# 0.11901910184961843
#
# Избежали убытков:  109.07167009302066
# упущенная выгода:  101.89817794154806
#
# 0.14931012411925051
#
#
# 0.08992561555529303
#
#
# 0.1047515440742433
#
# упущенная выгода:  47.38932016566105
#
# 0.13089595115861954
#
# упущенная выгода:  122.36513377127994
# упущенная выгода:  55.14806813233008
#
# 0.14470415671376122
#
#
# 0.1170919269990279
#
# упущенная выгода:  39.62498829350807
#
# 0.11421100672391053
#
#
# 0.14000304405612923
#
# Избежали убытков:  260.9978965488699
# Избежали убытков:  98.59431128374126
# Избежали убытков:  55.54150754373404
# Избежали убытков:  33.31785074193613
# упущенная выгода:  106.6384722001385
# Избежали убытков:  141.4880618766765
# упущенная выгода:  62.96449179347837
# упущенная выгода:  79.70817580384028
# упущенная выгода:  124.087920164573
#
# 0.14532752476803165
#
#
# 0.12415411040261909
#
# упущенная выгода:  103.30257547592919
# упущенная выгода:  12.543399514135672
# упущенная выгода:  34.67732843419071
# Избежали убытков:  31.37094326276565
#
# 0.13341761172701816
#
# Избежали убытков:  57.55411301505228
# Избежали убытков:  476.6296052991238
# Избежали убытков:  182.46924655584735
# Избежали убытков:  110.78240030523739
# Избежали убытков:  221.5404660597851
# Избежали убытков:  2131.727817786261
# Избежали убытков:  1.1607457877398701
# Избежали убытков:  185.8382155848376
# Избежали убытков:  266.60484548560635
# Избежали убытков:  154.3158952594822
# упущенная выгода:  6.719967040728079
# Избежали убытков:  17.368968056340236
# Избежали убытков:  33.52439869387308
# Избежали убытков:  90.6687593110255
# Избежали убытков:  2.2575960774120176
# упущенная выгода:  125.231643063089
# упущенная выгода:  172.3164802526735
#
# 0.11004870211174335
#
# Избежали убытков:  158.59139404007874
# Избежали убытков:  90.78821388990036
# Избежали убытков:  4.768214783529402
# Избежали убытков:  6.215771696617594
#
# 0.13919077465074658
#
# упущенная выгода:  118.3885955412843
#
# 0.1280748543980731
#
#
# 0.09790330961406912
#
# Избежали убытков:  347.57102297058736
# Избежали убытков:  92.60688589248457
# Избежали убытков:  90.94424990752304
# Избежали убытков:  68.23937210226723
# Избежали убытков:  125.66916868757107
# Избежали убытков:  199.93095613496553
# Избежали убытков:  279.6772342322074
# Избежали убытков:  42.15976193131064
#
# 0.13899948011563965
#
#
# 0.142306593601372
#
# Избежали убытков:  761.1147366507066
# упущенная выгода:  79.68676399211108
# Избежали убытков:  70.73012220959936
# упущенная выгода:  69.28311086370377
# упущенная выгода:  95.02713134295482
# упущенная выгода:  37.33509961992968
#
# 0.12479775255234812
#
#
# 0.13545403731857505
#
#
# 0.1180030073965639
#
# упущенная выгода:  194.72437818726758
# упущенная выгода:  182.3659268119809
# упущенная выгода:  71.8146114777046
#
# 0.14275093560381458
#
#
# 0.14651500717826796
#
#
# 0.147440793817463
#
# упущенная выгода:  168.10989153744595
# Избежали убытков:  33.689966415127856
# упущенная выгода:  222.6017880677682
# Избежали убытков:  534.6739164170285
# упущенная выгода:  89.8611840372323
# упущенная выгода:  87.45829292312555
# Избежали убытков:  518.9625209731894
# Избежали убытков:  481.68185020382225
# Избежали убытков:  172.59150734249852
# упущенная выгода:  10.53166764730122
# упущенная выгода:  94.70577742937894
# Избежали убытков:  101.41453576940694
# упущенная выгода:  129.188012372324
# Избежали убытков:  3560.0440634897386
# Избежали убытков:  177.90430847420066
# упущенная выгода:  58.879026823458844
# Избежали убытков:  181.5729999858595
# Избежали убытков:  505.40129941602936
# Избежали убытков:  477.21836618939415
# Избежали убытков:  275.38504310809367
# Избежали убытков:  550.9580652251898
# Избежали убытков:  1311.464075808617
# Избежали убытков:  136.19438403738604
# упущенная выгода:  55.4994432671665
# Избежали убытков:  129.23521206874284
# Избежали убытков:  46.691425286990125
# Избежали убытков:  93.3158962198795
# Избежали убытков:  945.6220168718428
# упущенная выгода:  42.48676485041506
# Избежали убытков:  101.11539528770663
# упущенная выгода:  57.4323698720691
# Избежали убытков:  264.93399482431414
# Избежали убытков:  938.0628117273009
# Избежали убытков:  122.78488478835789
# упущенная выгода:  113.03949229237332
# Избежали убытков:  172.79643089938327
# Избежали убытков:  69.81408806322725
# упущенная выгода:  157.1328099907696
# Избежали убытков:  2092.6977590668394
# Избежали убытков:  289.57584100891836
# упущенная выгода:  24.677161848376272
# Избежали убытков:  281.6949679561949
# Избежали убытков:  12054.103529436092
# упущенная выгода:  17.923153464726056
# Избежали убытков:  2.5534101795055903
# Избежали убытков:  205.53844445767754
# Избежали убытков:  845.9508173041831
# Избежали убытков:  249.37879808677826
# упущенная выгода:  33.17340764118126
# Избежали убытков:  1871.7374858317635
# Избежали убытков:  296.5677901809395
# Избежали убытков:  660.0459804257844
# Избежали убытков:  608.9535755752731
# Избежали убытков:  475.1278485708317
# Избежали убытков:  124.73956855431607
# Избежали убытков:  10.968080148246372
# упущенная выгода:  79.68578499450814
# упущенная выгода:  140.07963676222425
# Избежали убытков:  301.8016950018937
# Избежали убытков:  135.77764304701122
# Избежали убытков:  692.1944780237391
# упущенная выгода:  100.30741145228967
# упущенная выгода:  98.55394131244975
# Избежали убытков:  668.8507830631279
# упущенная выгода:  43.49778447636345
# упущенная выгода:  50.404366808055784
# упущенная выгода:  92.2376020939555
#
# 0.14726849314136928
#
# упущенная выгода:  28.307684557745233
# Избежали убытков:  199.54408112369129
# упущенная выгода:  75.86578736898082
# Избежали убытков:  783.0512746572495
# упущенная выгода:  27.450816604556167
# Избежали убытков:  435.8159977907344
# Избежали убытков:  68.00513226076146
# упущенная выгода:  56.348881308644195
# упущенная выгода:  105.07593580854882
# Избежали убытков:  1451.8090190744842
# упущенная выгода:  78.16262199419725
#
# 0.14587126013817037
#
# упущенная выгода:  45.97611531621078
# Избежали убытков:  362.9826272161881
# упущенная выгода:  86.97686828681617
# Избежали убытков:  320.4284824586066
# Избежали убытков:  60.45374744733272
# упущенная выгода:  69.37908399035223
#
# 0.14973097556032225
#
# упущенная выгода:  134.94162402536313
# упущенная выгода:  184.6358422011981
#
# 0.13961890122956297
#
#
# 0.12128368386440067
#
# Избежали убытков:  56.143698829910136
# Избежали убытков:  8.48385338326625
# упущенная выгода:  143.29337038038648
#
# 0.12930831878910465
#
# упущенная выгода:  135.88554629420105
# упущенная выгода:  63.56773327758128
# упущенная выгода:  149.84402387964656
# Избежали убытков:  89.81511961291835
# упущенная выгода:  63.72745212687005
# упущенная выгода:  148.1581123908545
#
# 0.1345678658840832
#
# упущенная выгода:  52.55060996593966
# упущенная выгода:  4.535499273653841
# Избежали убытков:  381.22213849879336
# упущенная выгода:  44.326542058886844
# Избежали убытков:  56.68886958605435
# упущенная выгода:  11.152210340849706
#
# 0.14302331044728092
#
# Избежали убытков:  44.95960414313595
#
# 0.14618967791446147
#
#
# 0.13488559152273108
#
#
# 0.1374608458777766
#
# Избежали убытков:  86.94960013365198
# упущенная выгода:  128.61734396485554
#
# 0.13328577659089638
#
# упущенная выгода:  150.79154206247767
#
# 0.12268481554831237
#
#
# 0.14492015946235182
#
#
# 0.11126240143891014
#
# упущенная выгода:  85.21478433041193
#
# 0.1262594144366032
#
# Избежали убытков:  142.39449519306072
# Избежали убытков:  662.2262131462921
# Избежали убытков:  96.33295540139079
# Избежали убытков:  10.06746163808566
# упущенная выгода:  141.80967126134783
# упущенная выгода:  81.57371117844013
# упущенная выгода:  169.62992150109494
#
# 0.10337315012658198
#
# упущенная выгода:  140.4648892824771
#
# 0.09810620727415682
#
#
# 0.09763157887817578
#
# Избежали убытков:  489.2439609557623
# упущенная выгода:  36.494739185174694
#
# 0.1207587226750319
#
#
# 0.10020498426286792
#
#
# 0.13112057129910656
#
# упущенная выгода:  72.4625372725277
#
# 0.11285007379008075
#
#
# 0.13091830170152394
#
#
# 0.11193993455680865
#
#
# 0.0875618085887399
#
#
# 0.0793720239211718
#
#
# 0.0686921946726298
#
# упущенная выгода:  122.60569726242102
#
# 0.09720251288703743
#
# упущенная выгода:  169.32792252631043
#
# 0.1070197545503291
#
#
# 0.12049680147208801
#
# упущенная выгода:  79.73026063920406
#
# 0.12634249994490002
#
#
# 0.13637878108376053
#
#
# 0.10855153821691958
#
#
# 0.10277008904395121
#
# упущенная выгода:  184.6418449151679
#
# 0.07232265663428145
#
#
# 0.09342785321412203
#
#
# 0.11550778131011342
#
# упущенная выгода:  132.5795960456744
#
# 0.12569149821223882
#
#
# 0.1178129715456535
#
#
# 0.13447875393730588
#
#
# 0.08488026555742118
#
#
# 0.07378628083548411
#
#
# 0.0935343208676483
#
#
# 0.11596800537201785
#
#
# 0.07960026552181618
#
#
# 0.07081774104874279
#
#
# 0.08483709831918464
#
#
# 0.06368584050751168
#
#
# 0.05732232632707006
#
#
# 0.09865741893686361
#
#
# 0.08661978625550795
#
#
# 0.09063264092855519
#
# Избежали убытков:  52.455245612800354
# Избежали убытков:  26.25115649777581
# Избежали убытков:  512.5102984057012
# Избежали убытков:  291.7122234638664
# упущенная выгода:  44.70053757079586
# упущенная выгода:  45.44222599104978
# упущенная выгода:  102.89688069117256
# Избежали убытков:  285.18634305857995
# Избежали убытков:  136.90317968596355
# Избежали убытков:  3088.1566983822704
# Избежали убытков:  27.846891755791148
# упущенная выгода:  7.1889641208108515
# упущенная выгода:  54.77129188076651
# упущенная выгода:  56.71442120602296
# упущенная выгода:  107.87722127011511
#
# 0.13244553555793676
#
# Избежали убытков:  107.0890547693125
# упущенная выгода:  122.37982089530851
# упущенная выгода:  109.99693654324801
#
# 0.14106457142556425
#
# Избежали убытков:  168.06790139434452
# Избежали убытков:  829.2647710814199
# Избежали убытков:  59.089611457820865
# Избежали убытков:  9.746305960041354
# упущенная выгода:  161.4722220201511
# упущенная выгода:  79.99988114864391
# упущенная выгода:  23.64835768091143
# Избежали убытков:  42.548488688407815
# упущенная выгода:  62.82281028028228
#
# 0.14931055183693107
#
# упущенная выгода:  68.84917257953202
#
# 0.14410360657367338
#
#
# 0.12725148479296833
#
# Избежали убытков:  74.93227048648987
# упущенная выгода:  75.90551889153721
#
# 0.13242379785325734
#
# упущенная выгода:  61.43685956418631
#
# 0.13467632947912417
#
#
# 0.14542859835370114
#
# упущенная выгода:  22.271579183550784
# Избежали убытков:  1127.9581333910028
# Избежали убытков:  228.01601264326018
# Избежали убытков:  1570.6833101923985
# упущенная выгода:  59.336330883408664
# Избежали убытков:  1269.454674000357
# Избежали убытков:  115.81262822638382
# упущенная выгода:  47.62282037967816
# Избежали убытков:  149.63051461080613
# Избежали убытков:  878.1314632957365
# упущенная выгода:  41.244591931652394
# упущенная выгода:  99.3848668650171
# Избежали убытков:  217.21690481668338
# Избежали убытков:  216.64431932923617
# Избежали убытков:  50.41765177750494
# Избежали убытков:  244.87694533064496
# Избежали убытков:  539.1858642832085
# упущенная выгода:  45.575758250124636
# упущенная выгода:  105.29718561292975
# упущенная выгода:  157.11488726716198
#
# 0.11731179311671545
#
# Избежали убытков:  1033.588747293441
# упущенная выгода:  99.87781422762782
#
# 0.1487311347911592
#
# Избежали убытков:  560.4052360757487
# упущенная выгода:  67.72722056737985
# упущенная выгода:  55.94552460331761
#
# 0.14562544193388022
#
# упущенная выгода:  112.98272057696886
#
# 0.1488218406964743
#
#
# 0.13941518750104379
#
#
# 0.11594449458825457
#
# упущенная выгода:  91.40061658500053
#
# 0.13085937053746263
#
#
# 0.08382883197275955
#
#
# 0.11000138293557414
#
#
# 0.07696652567016747
#
# упущенная выгода:  151.7451939034072
#
# 0.10666335483541907
#
#
# 0.1005022066855833
#
# упущенная выгода:  96.27696011551598
#
# 0.12140477367464299
#
#
# 0.09194585031703988
#
# упущенная выгода:  141.98866094919504
#
# 0.12021846967012649
#
#
# 0.11740423519873941
#
#
# 0.11862336796469242
#
#
# 0.10909959855002652
#
#
# 0.06751837795687107
#
#
# 0.07437968526666296
#
#
# 0.08728897641991948
#
#
# 0.11901910184961843
#
# Избежали убытков:  256.9122104392736
# упущенная выгода:  127.25532222448965
#
# 0.14931012411925051
#
#
# 0.08992561555529303
#
#
# 0.1047515440742433
#
# Избежали убытков:  103.98344971817278
#
# 0.13089595115861954
#
# упущенная выгода:  115.29569451676798
# упущенная выгода:  191.61533279242576
#
# 0.14470415671376122
#
#
# 0.1170919269990279
#
# Избежали убытков:  106.0263878126716
#
# 0.11421100672391053
#
#
# 0.14000304405612923
#
# Избежали убытков:  309.0558479674073
# Избежали убытков:  272.8015696809307
# Избежали убытков:  112.13060493608646
# Избежали убытков:  14.419287291020737
# упущенная выгода:  86.41846360590716
# Избежали убытков:  50.039546964588226
# упущенная выгода:  94.46797047350265
# упущенная выгода:  107.68199880929023
# упущенная выгода:  104.46020527606015
#
# 0.14532752476803165
#
#
# 0.12415411040261909
#
# Избежали убытков:  114.28030292964831
# Избежали убытков:  196.00250852949102
# упущенная выгода:  76.83129165116407
# упущенная выгода:  113.90023971101618
#
# 0.13341761172701816
#
# Избежали убытков:  626.6498583467182
# упущенная выгода:  12.085463720504777
# Избежали убытков:  513.1999005234829
# Избежали убытков:  13.381729970584274
# Избежали убытков:  515.9909382783371
# Избежали убытков:  458.43538205516234
# упущенная выгода:  32.99361710011726
# Избежали убытков:  202.26813099026913
# Избежали убытков:  761.7563449746667
# Избежали убытков:  38.902155519477674
# Избежали убытков:  74.18076642233063
# упущенная выгода:  39.35233001141751
# упущенная выгода:  93.57289845647756
# Избежали убытков:  233.9613435734791
# Избежали убытков:  64.35754562728107
# упущенная выгода:  154.0246212039201
# упущенная выгода:  153.36228434514487
#
# 0.11004870211174335
#
# Избежали убытков:  49.359348556623445
# Избежали убытков:  124.20590256355354
# упущенная выгода:  114.51897619006922
# упущенная выгода:  86.35464515941567
#
# 0.13919077465074658
#
# упущенная выгода:  143.73439978182432
#
# 0.1280748543980731
#
#
# 0.09790330961406912
#
# упущенная выгода:  71.87927407538518
# упущенная выгода:  17.212973507746938
# упущенная выгода:  63.009592403046554
# упущенная выгода:  150.63856115748058
# Избежали убытков:  806.7173006068915
# Избежали убытков:  99.98135499219643
# Избежали убытков:  589.5747419608815
# Избежали убытков:  303.0367682101496

# %% [markdown]
# ### Рассмотрим как изменялся курс ETH/USDT

# %%
back_test_obj.plot_price()

# %% [markdown]
# ### Дополнительно проверим как распределены изменения в стоимости (после 24 часов)¶

# %%
back_test_obj.change_price_distr()

# %% [markdown]
# ### Рассмотрим применимость нашей теории - зависимость будущей волатильности от прошлой
# Идея заключается в следующем. Мы зарабатываем только когда волатильность небольшая, если мы видим большую волатильность в прошлом, возможно стоит не минимизировать убытки, а просто подождать, пока рынок успокоится.

# %%
dict_sets = back_test_obj.dict_res

# %%
def calc_vol(prev_diff, future_diff):
    """Функция выдает прошлую и будущую волатильности"""
    # рассчитаем волотильность как разницу между максимальным и минимальным значениями
    # добавим 1 в самое начало
    prev_diff = np.array([1]+list(prev_diff))
    future_diff = np.array([1]+list(future_diff))
    prev_bahavour = np.cumprod(prev_diff)
    future_bahavour = np.cumprod(future_diff)
    prev_vol = np.max(prev_bahavour)-np.min(prev_bahavour)
    future_vol = np.max(future_bahavour)-np.min(future_bahavour)
#     prev_diff_abs = np.mean(np.abs(prev_diff - 1))
#     future_diff_abs = np.mean(np.abs(future_diff - 1))
    return prev_vol, future_vol

# %%
correlation_mat = np.zeros((len(dict_sets), 2))
k = 0
for key in dict_sets:
    prev = dict_sets[key][0]
    future = dict_sets[key][1]
    prev = prev['change'].values
    future = future['change'].values
    correlation_mat[k, :] = calc_vol(prev, future)
    k += 1

# %%
plt.figure(figsize=(8,8))
plt.scatter(correlation_mat[:, 0], correlation_mat[:, 1], s=0.001)
plt.xlabel('prev_vol')
plt.ylabel('future_vol')
plt.plot([0,0.2], [0.025, 0.025], c='0')

# %% [markdown]
# ### Вывод - не имеет смысла выставляться, если волотильность в прошлом была более чем 5%!, это лишь принесет нам убытки, лучше переждать. Нужно протестировать данную стратегию

# %%
np.abs(a-1)
# Out:
# array([0, 3, 2])

# %% [markdown]
# #### Рассмотрим как распределены изменения цены более детально. Больше точек в n_forecast*interval_in_hour раз // Тут за 25 часов мы получаем очень много точек, старт в 5 минуту, в 10ю минуту, все эти старты приносят нам по одной точке. Вверху мы просто смотрели одну точку за 24 часа, 2 точки за 48 часов.

# %%
def make_diff(df, int_in_h, n_forcast):
    res = np.zeros(len(df)-n_forcast*int_in_h)
    opens = df['open'].values.astype(float)
    closes = df['close'].values.astype(float)
    for i in range(len(res)):
        start = opens[i]
        end = closes[i+n_forcast*int_in_h-1]
        res[i] = (end-start)/start*100
    return res

# %%
plt.hist(make_diff(df, 12, 96), bins=100)
plt.show()

# %%
# тоже самое только другим способом
plt.plot(make_diff(df, 12, 24))
plt.show()

# %% [markdown]
# ### Синтетический тест - натравим изменения за год на наш интервал, прикинем какая должна быть доходность для выхода в +

# %%
# изменения за год
diff = make_diff(df, 12, 24)

res = np.zeros(len(diff))
current_amount = 10000
start_price = 1222
high_board = 1350
low_board = 1150

earnings = 0.6

k = 0
for d in diff:
    end_price = start_price*(1+d/100)
    res[k] = new_simulate(current_amount, start_price, end_price, high_board, low_board,  earnings)
    k += 1

# %%
np.sum(res)
# Out:
# 1395.7501768605075

# %% [markdown]
# #### Вывод - около 0.6% в сутки должно быть достаточно

# %% [markdown]
# # проверка логики работы

# %%
# Функция для построения кривой
def simulate(start_price, end, high_board, low_board, hedge, earnings):
    a1 = unforward_earnings(start_price, end, high_board, low_board)
    a2 = earnings
    a3 = -hedge*(end - start_price)/start_price*100
    return a1+a2+a3

# %% [markdown]
# ### новая схема, проверка симметрии(еще раз проверим, что все симметрично, не смотря на уход части средств в хедж) Спойлер - все симметрично, просто доходность падает пропорционально тому, сколько средств ушло в хедж (они не работают)

# %%
def new_simulate(current_amount, start_price, end_price, high_board, low_board,  earnings):
    ratio_hedge = calc_ratio(start_price, high_board, low_board)
    eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
    usd_pool = current_amount - 2*eth_pool
    usd_hedge = eth_pool

    # Получим непрямые прибыли/убытки от пула в процентах
    e1 = unforward_earnings(start_price, end_price, high_board, low_board)
    e1 = e1/100*(eth_pool+usd_pool) # переведем в деньги: прибыль

    # получим прибыль/убыток от хеджа
    e2 = simple_hedge(start_price, end_price, ratio_hedge)
    # небольшой костыль, чтобы вернуться просто к процентам от хеджа
    e2 = e2/(100*ratio_hedge)
    e2 = usd_hedge*e2  # переведем в доллары

    # получим прибыль от стейкинга
    e3 = earnings
    e3 = e3/100 # уход от %
    e3 = (eth_pool+usd_pool)*e3# переведем в деньги
    # суммируем прибыли и изначальную сумму
    earn = e1 + e2 + e3 + current_amount
    return (earn-current_amount)/current_amount*100

# %% [markdown]
# ### Сравним поведение при широком и узком интервале (доходности заданы как 0.5 и 0.25%)

# %%
current_amount = 10000
start_price = 1222
high_board_wide = 1340
low_board_wide = 1100
high_board = 1260
low_board = 1195
earnings_wide = 5
earnings = 2

# %%
end_prises = list(range(1000,1400))
list2 = list(map((lambda x: new_simulate(current_amount, start_price, x, high_board, low_board, earnings)), end_prises))
list3 = list(map((lambda x: (x-start_price)/start_price*100), end_prises))
list5 = list(map((lambda x: new_simulate(current_amount, start_price, x, high_board_wide, low_board_wide, earnings_wide)), end_prises))

# %%
plt.figure(figsize=(10,10))
plt.plot(list3, list2, label='new')
# plt.plot(list3, list5, label='new_wide')
# plt.plot(list3, list4, label='old')
plt.plot(list3, list3, label='ladder')
plt.plot([0, 0], [-20, 20], c='black')
plt.plot([-20, 20], [0, 0], c='black')
plt.xlabel('изменение цены в %', fontsize=15)
plt.ylabel('доходность в %', fontsize=15)
plt.ylim([-10, 10])
plt.xlim([-20, 20])
plt.legend(prop={'size':15})

# %% [markdown]
# #### Вывод - широкий интервалл более вытянутый, но не такой доходный в горбе, ожидаемый результат

# %% [markdown]
# #### Сравним с тем, что было раньше - когда фьючерсы были бесплатные

# %%
# тут требуется вводить хедж
hedge = 0.57

# %%
list4 = list(map((lambda x: simulate(start_price, x, high_board, low_board, hedge, earnings)), end_prises))

# %%
plt.figure(figsize=(10,10))
plt.plot(list3, list2, label='new')
plt.plot(list3, list4, label='old')
plt.plot(list3, list3, label='ladder')
plt.plot([0, 0], [-20, 20], c='black')
plt.plot([-20, 20], [0, 0], c='black')
plt.xlabel('изменение цены в %', fontsize=15)
plt.ylabel('доходность в %', fontsize=15)
plt.ylim([-10, 10])
plt.xlim([-20, 20])
plt.legend(prop={'size':15})

# %%
хедж
        пул usd
        pool eth
при движении на +5%, в пуле +3% хедж -5%

# %% [markdown]
# ##### Вывод, бесплатные фьючерсы конечно приносят большую дохоность при низкой волотильности, однако несут бОльшие убытки при резком изменении цены.

# %% [markdown]
# # Прогнозы в реальном времени

# %% [markdown]
# ###  Функции и зависимости

# %%
from datetime import datetime, timedelta
def dataset_for_current_pred(symbol = 'ETHUSDT'):
  '''Функция возвращает последние доступные данные'''
  api_key = ""
  api_secret = ""
  client = Client(api_key, api_secret)
  current_date = datetime.now().strftime("%d-%m-%Y")
  yesterday = (datetime.now()+timedelta(days=-1)).strftime("%d/%m/%Y")
  tommorow = (datetime.now()+timedelta(days=+1)).strftime("%d/%m/%Y") 

  fromDate = str(datetime.strptime(yesterday, '%d/%m/%Y'))
  toDate = str(datetime.strptime(tommorow, '%d/%m/%Y'))
  symbol = symbol
  interval = Client.KLINE_INTERVAL_5MINUTE
  # посколько реализована подгрузка начиная со вчерашнего дня, разумно обрезать датасет 24 часами 24*60=1440
  df = GetHistoricalData(symbol, interval, fromDate, toDate)[-288:] 
  return df

def bootstrap(mass, n_forcast, intervals_in_hour):
    '''Функция бутстрэпит изменения за прошедшие часы (это длина массива) n_forcast*intervals_in_hour раз, 
    процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
    mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
    mass = np.array(mass) # переводим в numpy
    n = len(mass) # длина выборки для обучения
    size_forecast = n_forcast*intervals_in_hour
    # случайно берем числа до n, размера n_forcast*intervals_in_hour
    indexes = np.random.randint(n, size=size_forecast*10000)
    change = mass[[indexes]]
    change = change.reshape((10000, size_forecast))
    # теперь рассомтрим куммулятивное перемножение- предсказанное поведение
    cum_change = np.cumprod(change, axis=1)
    # минимальное и максимальные значения внутри временного интервалла
    min_ = np.min(cum_change, axis=1)
    max_ = np.max(cum_change, axis=1)
    sorted_res_min = np.sort(min_)
    sorted_res_max = np.sort(max_)
    #######################
    high, low = sorted_res_max[9500], sorted_res_min[500]
    return np.array([high, low])
def make_new_col(df):
    '''Потребуются относительные изменения'''
    print('Добавляю относительные изменения')
    mass = np.zeros(len(df))
    mass[0] = 1 # первую точку доопределяем 1
    values = df['open'].values.astype(float)
    for i in range(1, len(df)):
        mass[i] = values[i]/values[i-1]
        df['change'] = mass
    return df

def calc_ratio(start_price, high_board, low_board):
    return (high_board-start_price)/(high_board-low_board)

# %% [markdown]
# ### Требуется ввести сумму средств

# %%
# требуется ввести сумму средств
current_amount = 10000
n_forcast, intervals_in_hour = 24, 12

# %% [markdown]
# ### Запускаем расчет

# %%
#Получаем данные
df_current = dataset_for_current_pred()

# Добавляем новую колонку
df_current = make_new_col(df_current)

# требуется для абсолютных значений запомнить текущую
current_value = df_current['open'].values.astype(float)[-1]
# Рассчитываем сам интервал
res_interval = bootstrap(df_current['change'].values, n_forcast=24, intervals_in_hour=60)*current_value

# рассчитываем ratio_hedge
start_price = current_value
high_board = res_interval[0]
low_board = res_interval[1]

ratio_hedge = calc_ratio(start_price, high_board, low_board)

eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
usd_pool = current_amount - 2*eth_pool
usd_hedge = eth_pool
print('Распределение средств в долларах')
print('Сумма эфира(в usdt) в пул', eth_pool)
print('Сумма usdt в пул', usd_pool)
print('Покупка фьючерса ',usd_hedge)
# Out:
# Добавляю относительные изменения
# Распределение средств в долларах
# Сумма эфира(в usdt) в пул 3270.4733744540904
# Сумма usdt в пул 3459.053251091819
# Покупка фьючерса  3270.4733744540904
# <ipython-input-704-ac082a017383>:28: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   change = mass[[indexes]]

# %%
res_interval
# Out:
# array([1344.12812009, 1116.64109348])

# %%
current_value
# Out:
# 1221.49

# %%
def calc_ratio(start_price, high_board, low_board):
    return (high_board-start_price)/(high_board-low_board)

# %%
calc_ratio(start, high, low)
# Out:
# 0.5248259860788849

# %%
(1195.48+1101.25)*0.524825986
# Out:
# 1205.38358682578

# %% [markdown]
# ###  Распределение ликвидности

# %%
start = 1195.48
high = 1218.1
low = 1175
eth_amount = 1
usdt_amount = 1101.25

# %%
usdt_amount/(start-low)
# Out:
# 53.77197265624995

# %%
eth_amount*start/(high-start)
# Out:
# 52.85057471264393

# %%
eth_amount*start/(get_tick(high)-get_tick(start))
# Out:
# 6.3589361702127665

# %%
usdt_amount/(get_tick(start)-get_tick(low))
# Out:
# 6.365606936416185

# %%
6.3656/6.3589
# Out:
# 1.0010536413530642

# %%
53.771/52.8505
# Out:
# 1.017417053764865

# %%
def get_tick(price):
    """функция возвращает в какую степень нужно возвести 1.0001"""
    return int(math.log(price, 1.0001))

# %%
1200-1000
# Out:
# 200

# %%
get_tick(1200)-get_tick(1000)
# Out:
# 1823

# %%
1000-800
# Out:
# 200

# %%
get_tick(1000)-get_tick(800)
# Out:
# 2232

# %%
import math

# %%
get_tick(1218.1)-
# Out:
# 70904

# %%
1.0001**70904
# Out:
# 1199.9624020162419
