# %%
import json
import pandas as pd
import requests
import datetime
from binance import Client
import matplotlib.pyplot as plt
import numpy as np
import os
from binance.client import Client
import datetime, time
from datetime import datetime
from numba import jit
import math

# %% [markdown]
# # Бэктест_начало

# %%
# Требуется собрать данные в датафрейм df 
# Задаем даты начала и конца бектеста
start_date = '12/01/2022'
end_date = '26/12/2022'




# interval = '5 min' # '15 min', '30 min'

def GetHistoricalData(symbol, interval, fromDate, toDate):
    klines = client.get_historical_klines(symbol, interval, fromDate, toDate)
    df = pd.DataFrame(klines, columns=['dateTime', 'open', 'high', 'low', 'close', 'volume', 'closeTime', 'quoteAssetVolume', 'numberOfTrades', 'takerBuyBaseVol', 'takerBuyQuoteVol', 'ignore'])
    df.dateTime = pd.to_datetime(df.dateTime, unit='ms')
    df['date'] = df.dateTime.dt.strftime("%d/%m/%Y")
    df['time'] = df.dateTime.dt.strftime("%H:%M:%S")
    df = df.drop(['dateTime', 'closeTime', 'quoteAssetVolume', 'numberOfTrades', 'takerBuyBaseVol','takerBuyQuoteVol', 'ignore'], axis=1)
    column_names = ["date", "time", "open","close", "high", "low", "volume"]
    df = df.reindex(columns=column_names)
    return df
    
api_key = ""
api_secret = ""
client = Client(api_key, api_secret)


fromDate = str(datetime.strptime(start_date, '%d/%m/%Y'))
toDate = str(datetime.strptime(end_date, '%d/%m/%Y'))
symbol = "ETHUSDT"
interval = Client.KLINE_INTERVAL_5MINUTE
df = GetHistoricalData(symbol, interval, fromDate, toDate)

# %% [markdown]
# ## Определим функции прибыли:
# Пока они вне класса, нужно внести их.

# %%
def unforward_earnings(start_price, end_price, high_board, low_board):
    """Функция должна получить всю необходимую информацию и возвратить итоговую прибыль-убыток в пуле.
    Тут не учитываются заработанные комиссии. Только изменение стоимости токенов и их соотношение"""
    # Если после 24(или другого) периода цена оказалась выше изначальной
    p_ETH = (high_board-start_price)/(high_board-low_board)# доля ETH
    p_USDT = (1-p_ETH)# доля USDT
    if end_price >= start_price:
        if end_price >= high_board:
            res = ((high_board-start_price)/2+start_price)/start_price*p_ETH+p_USDT
        else:
            p = (end_price-start_price)/(high_board-start_price) # доля проданного ETH
            a1 = ((end_price-start_price)/2+start_price)/start_price*p*p_ETH
            a2 = p_USDT
            a3 = p_ETH*(1-p)*(end_price)/start_price #непроданный ETH
            res =  a1+a2+a3
    elif end_price < start_price:
        if end_price <= low_board:
            res = (p_USDT/(low_board+(start_price - low_board)/2)+p_ETH/start_price)*end_price
        else:
            p = (start_price-end_price)/(start_price-low_board) # доля обменянных долларов
            a1 = p_USDT*p/(end_price+(start_price - end_price)/2)*end_price# сумма от обменянных долларов
            a2 = p_USDT*(1-p) # остатки долларов
            a3 = p_ETH*end_price/start_price# изначальный подешевевший эфир
            res =  a1+a2+a3
    return (res-1)*100 # возвращаем результат в процентах!

def simple_hedge(start_price, end_price, ratio):
    '''Данная функция принимает начальную и конечную стоимость. А так же параметры хеджирования - долю хеджа
    Возвращает процентный заработок/убыток из за хеджа в % '''
    res = -(end_price-start_price)/start_price
    return res*100*ratio


def return_curent_eth(start_price, end_price, high_board, low_board, eth_pool, usd_pool):
    '''Функция возвращает количество эфира для хеджа, в долларах'''
    # Исходим из того, что равномерно размазаны именно доллары! И эфир в тиках в долларах
    if end_price >= start_price:
        if end_price >= high_board:
            # у нас только usdt
            res = 0
        else:
            p = (end_price-start_price)/(high_board-start_price) # доля проданного ETH (в долларах)
            res = eth_pool*(1-p)
    elif end_price < start_price:
        if end_price <= low_board:
            # долларов нет, все это эфир
            res = usd_pool+eth_pool # в результате имеем старый и новый эфир
        else:
            # рассчитаем сколько долларов стали ETH
            p = (start_price-end_price)/(start_price-low_board)# доля обменянных долларов
            res =  p*usd_pool+eth_pool
    return res


def dynamic_hedge(eth_pool, usd_pool, high_board,
                                   low_board, start_price, end_price, index, dict_res, n_forcast,
                  intervals_in_hour, n_info):
    """Будет делать рехедж n раз за все время
    Для этого нам потребуется open, close за все время сидения в пуле
    Изначально хеджируется весь эфир, затем, вместе с движением цены изменяется доля эфира в пуле.
    Требуется изменять хедж.
    Поскольку мы принебрегаем комиссиями, в данной реализации, считаем,
    что каждый раз мы закрываем позицию и открываем новую на другую сумму
    """
    n_rehedge = 3 # сколько раз делаеся рехедж
    # преобразуем индекс (сложная штука из за того, что до этого использовали каждую 24*12 строчку)
    i = index*n_forcast*intervals_in_hour # получаем индекс в массиве всех строк
    index_in_dict_res = i+intervals_in_hour*n_info # тут i это сплошной, 

    open_prices = dict_res[index_in_dict_res][1]['open'].values.astype(float)
    close_prices = dict_res[index_in_dict_res][1]['close'].values.astype(float)
    leverage = 1
    current_hedge = eth_pool
    money = eth_pool
    start_price0 = start_price
    for i in range(1, n_rehedge+1):
         # 1 - закрываем позицю по хеджу, фиксируем прибыль/убытки
        # 2 - считаем размер новой позиции. Тут потребуется плечо - то есть его рассчет и использование
        # перезаписываем текущую позицию
         
        # смотрим цену закрытия
        ind = i*n_forcast*intervals_in_hour/(n_rehedge+1)-1 # 5минутка для закрытия позиции
        ind = int(ind)
        close_price = close_prices[ind]
        # считаем доходы по закрытому хеджу (фьючу)
        earning = -(close_price-start_price)/start_price*current_hedge*leverage
        money += earning
        # смотрим сколько эфира нужно захеджировать
        ETH_to_hedge = return_curent_eth(start_price0, close_price, high_board, low_board, eth_pool, usd_pool)
        
        # выбираем плечо, максимально 3е, не больше. Основываемся на том, сколько у нас средств
        leverage = math.ceil(ETH_to_hedge/money)
        if ETH_to_hedge == 0:
            current_hedge = 0
        elif leverage > 3:
            print('требуется плечо - ',leverage)
            leverage = 3
            # все деньги, максимальное плечо
            current_hedge = money
        elif leverage <= 3:
            current_hedge = ETH_to_hedge/leverage
        # изменяем цену старта для нового фьючерса
        start_price = open_prices[ind+1]
            
    return money-eth_pool
        

def persentage_earnings(const=1):
    '''Функция принимает необходимые параметры и рассчитывает доходность в % от всех изначальных инвестиций
    Для начала используем константу - 1%'''
#     res = const
    res = 0.5 # тут ручками задать 
    return res

def calc_ratio(start_price, high_board, low_board):
    return (high_board-start_price)/(high_board-low_board)

# %%
################### Инициализация параметров обучения ######################
n_info = 12 # часов для обучения (не совсем обучение, скорее зависимая часть, задает инертность)
n_forcast = 24 # на какой период предсказываем
intervals_in_hour = 12 # какими интервалами оперируем здесь 12 - 5 минутки

# %% [markdown]
# ### Далее класс, его просто инициализировать

# %%
# Класс который принимаем в себя всю необходимую информацию и подготавливает данные, рассчитывает интервалы и тп
class Interval_calculator:
    def __init__(self, df, n_info, n_forcast, intervals_in_hour, calculation='slow'):
        self.calculation = calculation
        self.df = df
        self.n_info = n_info
        self.n_forcast = n_forcast
        self.intervals_in_hour = intervals_in_hour
        self.make_new_col()
        self.preob()
        self.calculate_intervals()
        self.make_data_for_back()
        self.get_periodic()
        self.make_dates()
    
    def make_dates(self):
        n_info, n_forcast, intervals_in_hour = self.n_info, self.n_forcast, self.intervals_in_hour
        df_for_dates = self.df.iloc[n_info*intervals_in_hour:len(df)-n_forcast*intervals_in_hour]
        dates = df_for_dates['date'].values
        final_dates = dates[::intervals_in_hour*n_forcast]
        self.dates = final_dates
        
    def make_new_col(self):
        '''Потребуются относительные изменения'''
        print('Добавляю относительные изменения')
        df = self.df
        mass = np.zeros(len(df))
        mass[0] = 1 # первую точку доопределяем 1
        values = df['open'].values.astype(float)
        for i in range(1, len(df)):
            mass[i] = values[i]/values[i-1]
            df['change'] = mass
        self.df = df
        return    
        
        
    def preob(self):
        '''Функция просто создает кучу разбивок для бутстрэпа и предсказания
        df - датасет
        n_info - сколько часов брать для "обучения"
        n_forcast - на сколько часов давать прогноз
        intervals_in_hour - количество выбранных интерваллов в часе (если минутные данные то 60)
        '''
        print('Создаю разбивку - данные для рассчета интервала и теста')
        df, n_info, n_forcast, intervals_in_hour = self.df, self.n_info, self.n_forcast, self.intervals_in_hour
        self.dict_res = {}
        for i in range(n_info*intervals_in_hour, len(df)-n_forcast*intervals_in_hour):
            fold_info = df[i-n_info*intervals_in_hour : i] # Срез датасета
            fold_res = df[i : i+n_forcast*intervals_in_hour] # Срез датасета
            self.dict_res[i] = [fold_info, fold_res] # В словаре лежат два датасета под каждым ключом
        return 
    
    @jit
    def bootstrap(self, mass, n_forcast, intervals_in_hour):
        '''Функция бутстрэпит изменения за прошедшие часы (это длина массива) n_forcast*intervals_in_hour раз, 
        процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
        mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
        mass = np.array(mass) # переводим в numpy
        n = len(mass) # длина выборки для обучения
        size_forecast = n_forcast*intervals_in_hour
        # случайно берем числа до n, размера n_forcast*intervals_in_hour
        indexes = np.random.randint(n, size=size_forecast*10000)
        change = mass[[indexes]]
        change = change.reshape((10000, size_forecast))
        # теперь рассомтрим куммулятивное перемножение- предсказанное поведение
        cum_change = np.cumprod(change, axis=1)
        # минимальное и максимальные значения внутри временного интервалла
        min_ = np.min(cum_change, axis=1)
        max_ = np.max(cum_change, axis=1)
        sorted_res_min = np.sort(min_)
        sorted_res_max = np.sort(max_)
        high, low = sorted_res_max[9900], sorted_res_min[100]
#         vol = max((high-1), (1-low))
#         return np.array([1+vol, 1-vol])
        return np.array([high, low])
    
    def get_real(self, df):
      '''Функция нужна для валидации - возвращает верхние и нижние границы'''
      high = df['high'].values.astype(float)
      low = df['low'].values.astype(float)
      return np.hstack([high, low])
    
    def calculate_intervals(self):
        print('Рассчитываю интерваллы')
        dict_res, n_forcast, intervals_in_hour = self.dict_res, self.n_forcast, self.intervals_in_hour
        calculated_intervals = np.zeros((len(dict_res), 2))
        real_intervals = np.zeros((len(dict_res), n_forcast*intervals_in_hour*2)) # запоминаем  всю динамику  умножение на 2 тк записываем для верха и для низа
        k = 0
        for key in dict_res:
            if (self.calculation == 'fast') and (k % (self.intervals_in_hour*self.n_forcast) != 0 ):
                # заполняем ненужные интервалы нулями
                calculated_intervals[k, 0:2] = 0
                real_intervals[k, :] = 0
                k += 1
                continue
            real_intervals[k, :] = self.get_real(dict_res[key][1])

            # требуется для абсолютных значений запомнить цену открытия
            last_value = dict_res[key][0]['open'].values.astype(float)[-1]

            calculated = self.bootstrap(dict_res[key][0]['change'].values, n_forcast, intervals_in_hour)

            calculated_intervals[k, 0:2] = calculated*last_value
            k += 1
            j = int(len(dict_res)/200)
            if k % j == 0:
                print('progress = {} %'.format(round(k/len(dict_res)*100, 3)))
        self.intervals = calculated_intervals, real_intervals
        return

    def make_data_for_back(self):
        print('Преобразую данные для бэктеста')
        intervals, n_forcast, intervals_in_hour = self.intervals, self.n_forcast, self.intervals_in_hour
        # mass high, low, start, end
#         k_end = n_forcast*intervals_in_hour-1
        mass = np.zeros((len(intervals[0]), 4))
        for i in range(len(intervals[0])):
            # вычислим индекс в словаре с нарезками, чтобы подтянуть реальную цену открытия и закрытия
            index_in_dict_res = i+intervals_in_hour*self.n_info
            # берем цену open, close 
            open_price = self.dict_res[index_in_dict_res][1]['open'].values[0]
            close_price = self.dict_res[index_in_dict_res][1]['close'].values[-1]
            mass[i, :] = *intervals[0][i], open_price, close_price
            ###### тут брались цены open,close как high в первую и последнюю 5 минутки 
#             mass[i, :] = *intervals[0][i] , intervals[1][i][0], intervals[1][i][k_end]
    #         intervals[0][i] - high, low
        
    #         intervals[1][i][0] - start
    #         intervals[1][i][k] - end
        self.data_for_back = mass
        return
  
    
    def get_periodic(self):
        data_for_back, n_forcast, intervals_in_hour = self.data_for_back, self.n_forcast, self.intervals_in_hour
        '''Просто обрезка, выбор каждого n часового результата'''
        self.periodic_data_for_back = data_for_back[::n_forcast*intervals_in_hour, :]
        return 
    
    def back_test(self):
        '''Функция проводит анализ стратегии, возвращает список прибыли/убытков в каждый период'''
        mass_for_back, n_forcast = self.periodic_data_for_back, self.n_forcast
        earnings = np.zeros(len(mass_for_back))
#         print(ratio_for_hedge, hadge_type)
        for i in range(len(mass_for_back)):
            high_board, low_board, start_price, end_price = mass_for_back[i, :]

            e1 = unforward_earnings(start_price, end_price, high_board, low_board)
            # тут есть допущение - хедж для нас не требует блокировку активов - фьючерсы в общем ,причем бесплатные
            ratio_for_hedge = calc_ratio(start_price, high_board, low_board)
            e2 = simple_hedge(start_price, end_price, ratio_for_hedge)
            e3 = persentage_earnings()*n_forcast/24
            print('{} день'.format(i))
            print('start_price = ',start_price)
            print('end_price = ', end_price) 
            print('high_board = ', high_board)
            print('low_board = ', low_board)
            print('Непрямые потери/прибыли ',e1)
            print('Доход от хеджа ', e2)
            print('Процентный заработок ',e3)
            earnings[i] = e1+e2+e3
        return earnings
    
    def back_test_alt(self, start_amount, gas_price, verbose, hedge_type):
        '''Функция проводит анализ стратегии, возвращает список прибыли/убытков в каждый период'''
        mass_for_back, n_forcast = self.periodic_data_for_back, self.n_forcast
        earnings = np.zeros(len(mass_for_back))
        current_amount = start_amount
        for i in range(len(mass_for_back)):
            high_board, low_board, start_price, end_price = mass_for_back[i, :]
            # Рассчитываем долю эфира в средствах, которые вкладываем в пул
            ratio_hedge = calc_ratio(start_price, high_board, low_board)
            # Итого all_money = eth_pool+usd_pool+usd_hedge, eth_pool=usd_hedge
            # ratio_hedge = eth_pool/(eth_pool+usd_pool)
            # требуется расщепить current_amount на эти части:
            # То есть решить эти два уравнения:
            # current_amount = usd_pool+2*eth_pool
            # ratio_hedge = eth_pool/(eth_pool+usd_pool)
            ###### решаем... #####
            # usd_pool = (current_amount - 2*eth_pool)
            # ##### подставляем
            # ratio_hedge = eth_pool/(eth_pool+(current_amount - 2*eth_pool))
            # #####
            # ratio_hedge = eth_pool/(current_amount - eth_pool)
            # #####
            # ratio_hedge*(current_amount - eth_pool)  = eth_pool
            # ####
            # ratio_hedge*current_amount  = eth_pool+ratio_hedge*eth_pool
            # #####
            # eth_pool = ratio_hedge*current_amount/(1+ratio_hedge) 
            # -> usd_pool = current_amount - 2*eth_pool

            eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
            usd_pool = current_amount - 2*eth_pool
            usd_hedge = eth_pool

            # Получим непрямые прибыли/убытки от пула в процентах
            e1 = unforward_earnings(start_price, end_price, high_board, low_board)
            e1 = e1/100*(eth_pool+usd_pool) # переведем в деньги: прибыль

            # получим прибыль/убыток от хеджа
            if hedge_type == 'simple':
                e2 = simple_hedge(start_price, end_price, ratio_hedge)
                # небольшой костыль, чтобы вернуться просто к процентам от хеджа
                e2 = e2/(100*ratio_hedge)
                e2 = usd_hedge*e2  # переведем в доллары
                
            elif hedge_type == 'dynamic':
                # изначально отправляем деньги как на статический, затем испоьзуем магию
                e2 = dynamic_hedge(eth_pool, usd_pool, high_board,
                                   low_board, start_price, end_price, i, self.dict_res, n_forcast,
                                   self.intervals_in_hour, self.n_info)
            # получим прибыль от стейкинга
            # Учтем размер интервалла - считаем, что константа задает нам значение для 200 пунктов цены
            # при стоимости в районе 1200  - 0.16
            koef = (high_board - low_board)/start_price
            e3 = persentage_earnings()*n_forcast/24
            e3 = e3*0.16/koef
            
            
            e3 = e3/100 # уход от %
            e3 = (eth_pool+usd_pool)*e3# переведем в деньги
            # суммируем прибыли и изначальную сумму
            earn = e1 + e2 + e3 + current_amount - gas_price*2
            
            if verbose == True:
                print('{} день'.format(i))
                print('start_price = ',start_price)
                print('end_price = ', end_price) 
                print('high_board = ', high_board)
                print('low_board = ', low_board)
                print('Выделяем {} на usd_pool'.format(usd_pool))
                print('Выделяем {} на usd_hedge'.format(usd_hedge))
                print('Выделяем {} на eth_pool'.format(eth_pool))
                print('Непрямые потери/прибыли ', e1)
                print('Доход от хеджа ', e2)
                print('Процентный заработок ',e3)
                print()
            earnings[i] = earn
            # переопределяем старт на след день
            current_amount = earn
        return earnings
    
    def plot_results(self):
        fig = plt.figure(figsize = (10, 10))
        mass_for_back = self.periodic_data_for_back
        x = self.dates
        earnings = self.back_test()
        y = np.cumsum(earnings)
        plt.plot(x, y, label='Хеджируем эфир')
        plt.xlabel('Дата бектеста', fontsize=15)
        plt.ylabel('Доходность в %', fontsize=15)
        plt.xticks(fontsize = (20/len(x)+3), rotation=45)
        plt.title('Анализ итоговой доходности', fontsize = 15)
        plt.legend(prop={'size': 10})
        
    def plot_results_alt(self, start_amount, gas_price, verbose, hedge_type):
        '''Альтернативный рассчет, более строгий
        Здесь каждый раз капитал разбивается на несколько частей
        Часть уходит в хедж, часть в пул. Затем все суммируется и новая сумма идет в след день'''
        fig = plt.figure(figsize = (10, 10))
        mass_for_back = self.periodic_data_for_back
        x = self.dates
        
        earnings_alt = self.back_test_alt(start_amount, gas_price, verbose, hedge_type) 
        y = earnings_alt
        
        
        plt.plot(x, y, label='Хеджируем эфир')
        plt.xlabel('Дата бектеста', fontsize=15)
        plt.ylabel('Всего средств', fontsize=15)
        plt.xticks(fontsize = (20/len(x)+3), rotation=45)
        plt.title('Анализ итоговой доходности старт с {} $'.format(start_amount), fontsize = 15)
        plt.legend(prop={'size': 10})
        
    def plot_price(self):
        # Просто отрисовка того, как изменялся курс, чтобы интерпретировать прибыли и убытки в стратегии
        mass_for_back = self.periodic_data_for_back
        fig = plt.figure(figsize = (10, 10))
        plt.plot(self.dates, mass_for_back[:, 3])
        plt.xticks(fontsize = (20/len(self.dates)+3), rotation=45)
        plt.title('Курс ETH/USDT')
        
    def change_price_distr(self):
        mass_for_back = self.periodic_data_for_back
        change = np.zeros(len(mass_for_back))
        starts = mass_for_back[:, 2]
        ends = mass_for_back[:, 3]
        for i in range(len(change)):
            end = ends[i]
            start = starts[i]
            res = (end - start)/start*100 # итог в процентах +10% или -0.5%
            change[i] = res
        fig = plt.figure(figsize = (10, 10))
        plt.xlabel('Изменение стоимости в %', fontsize=15)
        plt.hist(change, bins=15)
        plt.show()

# %% [markdown]
# ### Следующая строчка посчитает все интерваллы

# %%
back_test_obj = Interval_calculator(df, n_info, n_forcast, intervals_in_hour, calculation='fast')
# Out:
# Добавляю относительные изменения
# Создаю разбивку - данные для рассчета интервала и теста
# Рассчитываю интерваллы
# <ipython-input-1007-383f08f23793>:53: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "bootstrap" failed type inference due to: non-precise type pyobject
# During: typing of argument at <ipython-input-1007-383f08f23793> (57)
#
# File "<ipython-input-1007-383f08f23793>", line 57:
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#         <source elided>
#         процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
#         mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
#         ^
#
#   @jit
# /Users/vladislav705/opt/anaconda3/lib/python3.8/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "bootstrap" was compiled in object mode without forceobj=True.
#
# File "<ipython-input-1007-383f08f23793>", line 54:
#     @jit
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#     ^
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /Users/vladislav705/opt/anaconda3/lib/python3.8/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected, this is deprecated behaviour.
#
# For more information visit https://numba.pydata.org/numba-doc/latest/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<ipython-input-1007-383f08f23793>", line 54:
#     @jit
#     def bootstrap(self, mass, n_forcast, intervals_in_hour):
#     ^
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <ipython-input-1007-383f08f23793>:101: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   calculated = self.bootstrap(dict_res[key][0]['change'].values, n_forcast, intervals_in_hour)
# Преобразую данные для бэктеста

# %% [markdown]
# ### Поведение при бесплатных фьючерсах(не реальная ситуация, представлена для сравнения)

# %%
back_test_obj.plot_results()
# Out:
# 0 день
# start_price =  1129.6
# end_price =  1025.71
# high_board =  1317.068754189515
# low_board =  931.9312458104849
# Непрямые потери/прибыли  -5.776977994269905
# Доход от хеджа  4.476742755090854
# Процентный заработок  0.26666666666666666
# 1 день
# start_price =  1025.71
# end_price =  1078.07
# high_board =  1260.2368810489852
# low_board =  823.0031189510148
# Непрямые потери/прибыли  2.432474868639223
# Доход от хеджа  -2.738129514105215
# Процентный заработок  0.26666666666666666
# 2 день
# start_price =  1077.73
# end_price =  1036.24
# high_board =  1268.5023225797602
# low_board =  890.33767742024
# Непрямые потери/прибыли  -2.1574148146528582
# Доход от хеджа  1.9420835327191912
# Процентный заработок  0.26666666666666666
# 3 день
# start_price =  1036.24
# end_price =  1067.14
# high_board =  1182.7479206402588
# low_board =  876.8720793597412
# Непрямые потери/прибыли  1.2776627206647628
# Доход от хеджа  -1.4282823012123145
# Процентный заработок  0.26666666666666666
# 4 день
# start_price =  1067.2
# end_price =  1126.84
# high_board =  1171.6974313866424
# low_board =  962.7625686133576
# Непрямые потери/прибыли  1.9974240628868767
# Доход от хеджа  -2.7950303068255145
# Процентный заработок  0.26666666666666666
# 5 день
# start_price =  1126.89
# end_price =  1109.86
# high_board =  1281.37277389873
# low_board =  970.9072261012702
# Непрямые потери/прибыли  -0.7937323565505139
# Доход от хеджа  0.7519687076414101
# Процентный заработок  0.26666666666666666
# 6 день
# start_price =  1109.8
# end_price =  1193.24
# high_board =  1206.267500716239
# low_board =  1015.9924992837613
# Непрямые потери/прибыли  2.1632770304933047
# Доход от хеджа  -3.8117891366433834
# Процентный заработок  0.26666666666666666
# 7 день
# start_price =  1193.41
# end_price =  1188.42
# high_board =  1327.5334601323696
# low_board =  1050.9465398676305
# Непрямые потери/прибыли  -0.20654050588182482
# Доход от хеджа  0.2027607940371427
# Процентный заработок  0.26666666666666666
# 8 день
# start_price =  1188.41
# end_price =  1185.36
# high_board =  1299.7248134118402
# low_board =  1062.9751865881597
# Непрямые потери/прибыли  -0.12232469437643001
# Доход от хеджа  0.12066941334352203
# Процентный заработок  0.26666666666666666
# 9 день
# start_price =  1185.36
# end_price =  1221.93
# high_board =  1312.837829155476
# low_board =  1075.1421708445241
# Непрямые потери/прибыли  1.4172535776000306
# Доход от хеджа  -1.654581265387285
# Процентный заработок  0.26666666666666666
# 10 день
# start_price =  1221.93
# end_price =  1158.99
# high_board =  1320.8513402714675
# low_board =  1120.5286597285324
# Непрямые потери/прибыли  -3.374124424396119
# Доход от хеджа  2.543550005381701
# Процентный заработок  0.26666666666666666
# 11 день
# start_price =  1159.0
# end_price =  1164.11
# high_board =  1357.5359132176595
# low_board =  959.8440867823407
# Непрямые потери/прибыли  0.21727240717563934
# Доход от хеджа  -0.2201049840384523
# Процентный заработок  0.26666666666666666
# 12 день
# start_price =  1164.12
# end_price =  1231.28
# high_board =  1253.4700287961589
# low_board =  1062.889971203841
# Непрямые потери/прибыли  1.6882484191024894
# Доход от хеджа  -2.704768997219263
# Процентный заработок  0.26666666666666666
# 13 день
# start_price =  1231.31
# end_price =  1234.89
# high_board =  1418.3348579854942
# low_board =  1062.2451420145057
# Непрямые потери/прибыли  0.15124426145955994
# Доход от хеджа  -0.1527057964587294
# Процентный заработок  0.26666666666666666
# 14 день
# start_price =  1234.91
# end_price =  1215.42
# high_board =  1388.391733143422
# low_board =  1077.2882668565778
# Непрямые потери/прибыли  -0.8284554441616132
# Доход от хеджа  0.7786250582021497
# Процентный заработок  0.26666666666666666
# 15 день
# start_price =  1215.5
# end_price =  1198.86
# high_board =  1326.8516248285307
# low_board =  1108.3483751714691
# Непрямые потери/прибыли  -0.7501354574017016
# Доход от хеджа  0.6976490658139273
# Процентный заработок  0.26666666666666666
# 16 день
# start_price =  1198.78
# end_price =  1261.3
# high_board =  1326.628929614558
# low_board =  1087.891070385442
# Непрямые потери/прибыли  2.1100149806661417
# Доход от хеджа  -2.792899329409154
# Процентный заработок  0.26666666666666666
# 17 день
# start_price =  1261.61
# end_price =  1207.84
# high_board =  1370.4880298624314
# low_board =  1158.5919701375685
# Непрямые потери/прибыли  -2.742471743441721
# Доход от хеджа  2.189940354841325
# Процентный заработок  0.26666666666666666
# 18 день
# start_price =  1207.86
# end_price =  1243.99
# high_board =  1308.0450721670554
# low_board =  1109.6349278329444
# Непрямые потери/прибыли  1.2380460864438447
# Доход от хеджа  -1.5103948796366873
# Процентный заработок  0.26666666666666666
# 19 день
# start_price =  1244.0
# end_price =  1233.22
# high_board =  1361.849975650774
# low_board =  1135.690024349226
# Непрямые потери/прибыли  -0.47229889636193345
# Доход от хеджа  0.45155658056167475
# Процентный заработок  0.26666666666666666
# 20 день
# start_price =  1233.23
# end_price =  1321.27
# high_board =  1288.4508596275439
# low_board =  1179.5291403724561
# Непрямые потери/прибыли  1.1350572360682376
# Доход от хеджа  -3.6193003780622743
# Процентный заработок  0.26666666666666666
# 21 день
# start_price =  1321.33
# end_price =  1417.31
# high_board =  1511.6085261482779
# low_board =  1125.931473851722
# Непрямые потери/прибыли  2.6798811367214403
# Доход от хеджа  -3.583731216785094
# Процентный заработок  0.26666666666666666
# 22 день
# start_price =  1417.23
# end_price =  1409.43
# high_board =  1604.6795612677238
# low_board =  1223.7804387322763
# Непрямые потери/прибыли  -0.2765006707179607
# Доход от хеджа  0.270849926361905
# Процентный заработок  0.26666666666666666
# 23 день
# start_price =  1409.38
# end_price =  1368.14
# high_board =  1570.40462379004
# low_board =  1265.4153762099602
# Непрямые потери/прибыли  -1.745661192711112
# Доход от хеджа  1.544892685501953
# Процентный заработок  0.26666666666666666
# 24 день
# start_price =  1368.05
# end_price =  1310.43
# high_board =  1482.487988210908
# low_board =  1243.0920117890917
# Непрямые потери/прибыли  -2.5311501140647397
# Доход от хеджа  2.0133749044501115
# Процентный заработок  0.26666666666666666
# 25 день
# start_price =  1310.43
# end_price =  1323.1
# high_board =  1510.1177347894259
# low_board =  1099.7222652105743
# Непрямые потери/прибыли  0.45552325087685475
# Доход от хеджа  -0.47044799345907984
# Процентный заработок  0.26666666666666666
# 26 день
# start_price =  1323.1
# end_price =  1305.55
# high_board =  1503.4701539308148
# low_board =  1146.5098460691852
# Непрямые потери/прибыли  -0.7030629949242195
# Доход от хеджа  0.6702382356596727
# Процентный заработок  0.26666666666666666
# 27 день
# start_price =  1305.54
# end_price =  1237.43
# high_board =  1501.4786137670833
# low_board =  1103.321386232917
# Непрямые потери/прибыли  -3.0255254163367606
# Доход от хеджа  2.5673561853287237
# Процентный заработок  0.26666666666666666
# 28 день
# start_price =  1237.19
# end_price =  1171.91
# high_board =  1458.4649249177921
# low_board =  1024.475075082208
# Непрямые потери/прибыли  -3.09786535825356
# Доход от хеджа  2.6902731328117993
# Процентный заработок  0.26666666666666666
# 29 день
# start_price =  1171.47
# end_price =  1174.28
# high_board =  1314.4419385805
# low_board =  1038.7780614194999
# Непрямые потери/прибыли  0.12318480175468327
# Доход от хеджа  -0.12440736578128017
# Процентный заработок  0.26666666666666666
# 30 день
# start_price =  1174.51
# end_price =  1219.45
# high_board =  1469.6018172450881
# low_board =  882.9181827549119
# Непрямые потери/прибыли  1.778005024513396
# Доход от хеджа  -1.9245515236327144
# Процентный заработок  0.26666666666666666
# 31 день
# start_price =  1219.39
# end_price =  1243.31
# high_board =  1480.1012093735505
# low_board =  964.7987906264494
# Непрямые потери/прибыли  0.9469380462807209
# Доход от хеджа  -0.992466986871764
# Процентный заработок  0.26666666666666666
# 32 день
# start_price =  1243.47
# end_price =  1263.54
# high_board =  1366.6377481982681
# low_board =  1119.9822518017318
# Непрямые потери/прибыли  0.7403031546015848
# Доход от хеджа  -0.8059688639098005
# Процентный заработок  0.26666666666666666
# 33 день
# start_price =  1263.53
# end_price =  1231.92
# high_board =  1386.9786456463112
# low_board =  1135.7413543536886
# Непрямые потери/прибыли  -1.3886261496995012
# Доход от хеджа  1.2292526840439284
# Процентный заработок  0.26666666666666666
# 34 день
# start_price =  1231.92
# end_price =  1246.2
# high_board =  1345.9530104787984
# low_board =  1113.4269895212017
# Непрямые потери/прибыли  0.5328726740978507
# Доход от хеджа  -0.5684663099774749
# Процентный заработок  0.26666666666666666
# 35 день
# start_price =  1246.38
# end_price =  1326.0
# high_board =  1353.3167047941788
# low_board =  1148.9432952058214
# Непрямые потери/прибыли  2.0981795017195326
# Доход от хеджа  -3.3425207250756577
# Процентный заработок  0.26666666666666666
# 36 день
# start_price =  1325.99
# end_price =  1322.43
# high_board =  1546.419601044745
# low_board =  1093.180398955255
# Непрямые потери/прибыли  -0.1316284534852219
# Доход от хеджа  0.1305726437290592
# Процентный заработок  0.26666666666666666
# 37 день
# start_price =  1322.59
# end_price =  1352.15
# high_board =  1409.770602377126
# low_board =  1232.5893976228742
# Непрямые потери/прибыли  0.913279531278155
# Доход от хеджа  -1.0997181937906628
# Процентный заработок  0.26666666666666666
# 38 день
# start_price =  1352.29
# end_price =  1440.46
# high_board =  1506.5165380622666
# low_board =  1201.0434619377334
# Непрямые потери/прибыли  2.350873188202618
# Доход от хеджа  -3.2918283112673095
# Процентный заработок  0.26666666666666666
# 39 день
# start_price =  1440.45
# end_price =  1416.76
# high_board =  1610.6406553732759
# low_board =  1250.999344626724
# Непрямые потери/прибыли  -0.8328906884537468
# Доход от хеджа  0.7782748773006092
# Процентный заработок  0.26666666666666666
# 40 день
# start_price =  1416.76
# end_price =  1347.38
# high_board =  1518.358392119619
# low_board =  1313.061607880381
# Непрямые потери/прибыли  -3.2717531369212627
# Доход от хеджа  2.4234981751809213
# Процентный заработок  0.26666666666666666
# 41 день
# start_price =  1347.43
# end_price =  1338.77
# high_board =  1541.0759123716484
# low_board =  1140.4040876283514
# Непрямые потери/прибыли  -0.3175892911977396
# Доход от хеджа  0.3106212832819767
# Процентный заработок  0.26666666666666666
# 42 день
# start_price =  1338.63
# end_price =  1285.49
# high_board =  1489.293766030877
# low_board =  1191.226233969123
# Непрямые потери/прибыли  -2.3676050307836594
# Доход от хеджа  2.0065738288960357
# Процентный заработок  0.26666666666666666
# 43 день
# start_price =  1285.49
# end_price =  1333.83
# high_board =  1427.1303331218776
# low_board =  1148.0496668781223
# Непрямые потери/прибыли  1.5828377255607151
# Доход от хеджа  -1.908513041277309
# Процентный заработок  0.26666666666666666
# 44 день
# start_price =  1333.83
# end_price =  1284.01
# high_board =  1529.5657193771444
# low_board =  1148.8942806228556
# Непрямые потери/прибыли  -2.1696043507922314
# Доход от хеджа  1.9205385758963607
# Процентный заработок  0.26666666666666666
# 45 день
# start_price =  1284.0
# end_price =  1236.09
# high_board =  1442.4802760558782
# low_board =  1124.379723944122
# Непрямые потери/прибыли  -2.145301431532809
# Доход от хеджа  1.858968125434802
# Процентный заработок  0.26666666666666666
# 46 день
# start_price =  1236.08
# end_price =  1274.54
# high_board =  1416.1602750525965
# low_board =  1086.8397249474035
# Непрямые потери/прибыли  1.5197273383886767
# Доход от хеджа  -1.7014140449091182
# Процентный заработок  0.26666666666666666
# 47 день
# start_price =  1274.65
# end_price =  1301.42
# high_board =  1419.6683579554613
# low_board =  1126.7316420445388
# Непрямые потери/прибыли  0.9437339370155229
# Доход от хеджа  -1.039696532995385
# Процентный заработок  0.26666666666666666
# 48 день
# start_price =  1301.41
# end_price =  1343.0
# high_board =  1455.83469443202
# low_board =  1131.70530556798
# Непрямые потери/прибыли  1.3175264595445713
# Доход от хеджа  -1.5225554603417681
# Процентный заработок  0.26666666666666666
# 49 день
# start_price =  1342.65
# end_price =  1347.63
# high_board =  1520.8467055250917
# low_board =  1157.3132944749082
# Непрямые потери/прибыли  0.17927120223200088
# Доход от хеджа  -0.1818117159376252
# Процентный заработок  0.26666666666666666
# 50 день
# start_price =  1347.63
# end_price =  1302.9
# high_board =  1419.7120130041428
# low_board =  1268.507986995857
# Непрямые потери/прибыли  -2.081541950148935
# Доход от хеджа  1.5823107524729734
# Процентный заработок  0.26666666666666666
# 51 день
# start_price =  1302.9
# end_price =  1424.74
# high_board =  1420.4130063797581
# low_board =  1187.1469936202416
# Непрямые потери/прибыли  2.271848300132162
# Доход от хеджа  -4.711001878270094
# Процентный заработок  0.26666666666666666
# 52 день
# start_price =  1424.52
# end_price =  1372.07
# high_board =  1771.4726008969258
# low_board =  1077.4273991030743
# Непрямые потери/прибыли  -1.9823337660272777
# Доход от хеджа  1.8405996404914273
# Процентный заработок  0.26666666666666666
# 53 день
# start_price =  1372.01
# end_price =  1336.82
# high_board =  1522.7159744862086
# low_board =  1222.4440255137913
# Непрямые потери/прибыли  -1.4395384999102978
# Доход от хеджа  1.2872938568687453
# Процентный заработок  0.26666666666666666
# 54 день
# start_price =  1336.81
# end_price =  1364.91
# high_board =  1480.875179706386
# low_board =  1202.3248202936136
# Непрямые потери/прибыли  0.9811309406369428
# Доход от хеджа  -1.0871561735911175
# Процентный заработок  0.26666666666666666
# 55 день
# start_price =  1364.91
# end_price =  1384.25
# high_board =  1433.5997406511362
# low_board =  1282.4202593488637
# Непрямые потери/прибыли  0.5531678103463111
# Доход от хеджа  -0.6438007522575285
# Процентный заработок  0.26666666666666666
# 56 день
# start_price =  1384.25
# end_price =  1350.49
# high_board =  1443.7985639324202
# low_board =  1308.02143606758
# Непрямые потери/прибыли  -1.3765737182578786
# Доход от хеджа  1.0696275506859934
# Процентный заработок  0.26666666666666666
# 57 день
# start_price =  1350.49
# end_price =  1349.08
# high_board =  1433.3174679854728
# low_board =  1265.0625320145273
# Непрямые потери/прибыли  -0.05183428993875694
# Доход от хеджа  0.05139659067265884
# Процентный заработок  0.26666666666666666
# 58 день
# start_price =  1349.07
# end_price =  1294.44
# high_board =  1399.165456122507
# low_board =  1296.294543877493
# Непрямые потери/прибыли  -3.067406944414963
# Доход от хеджа  1.9719797907338574
# Процентный заработок  0.26666666666666666
# 59 день
# start_price =  1294.33
# end_price =  1320.48
# high_board =  1383.497130338303
# low_board =  1224.602869661697
# Непрямые потери/прибыли  0.9675161171880164
# Доход от хеджа  -1.133765546347001
# Процентный заработок  0.26666666666666666
# 60 день
# start_price =  1320.6
# end_price =  1327.27
# high_board =  1418.7036960833304
# low_board =  1226.1763039166697
# Непрямые потери/прибыли  0.24861476532065385
# Доход от хеджа  -0.25736375392776145
# Процентный заработок  0.26666666666666666
# 61 день
# start_price =  1326.93
# end_price =  1350.12
# high_board =  1422.1144300695064
# low_board =  1243.9055699304936
# Непрямые потери/прибыли  0.8197375084675329
# Доход от хеджа  -0.9334463398685451
# Процентный заработок  0.26666666666666666
# 62 день
# start_price =  1349.99
# end_price =  1388.08
# high_board =  1435.677223715356
# low_board =  1254.0827762846443
# Непрямые потери/прибыли  1.0354457175405507
# Доход от хеджа  -1.3313551664027155
# Процентный заработок  0.26666666666666666
# 63 день
# start_price =  1388.08
# end_price =  1426.81
# high_board =  1497.390647171902
# low_board =  1287.9693528280982
# Непрямые потери/прибыли  1.1983738171309266
# Доход от хеджа  -1.4563797317961482
# Процентный заработок  0.26666666666666666
# 64 день
# start_price =  1426.81
# end_price =  1519.22
# high_board =  1540.5567257011255
# low_board =  1312.6432742988743
# Непрямые потери/прибыли  1.9193537280321804
# Доход от хеджа  -3.232375243001369
# Процентный заработок  0.26666666666666666
# 65 день
# start_price =  1519.08
# end_price =  1543.0
# high_board =  1816.8637718830903
# low_board =  1233.6562281169097
# Непрямые потери/прибыли  0.7717128690451602
# Доход от хеджа  -0.8040043955790686
# Процентный заработок  0.26666666666666666
# 66 день
# start_price =  1543.01
# end_price =  1550.68
# high_board =  1659.3849750823829
# low_board =  1424.0750249176172
# Непрямые потери/прибыли  0.23773501183561585
# Доход от хеджа  -0.24583625559120356
# Процентный заработок  0.26666666666666666
# 67 день
# start_price =  1550.68
# end_price =  1630.99
# high_board =  1679.4108023958472
# low_board =  1426.9891976041529
# Непрямые потери/прибыли  1.8173392739412098
# Доход от хеджа  -2.6412127988908574
# Процентный заработок  0.26666666666666666
# 68 день
# start_price =  1631.0
# end_price =  1655.2
# high_board =  1794.748921417188
# low_board =  1471.0310785828121
# Непрямые потери/прибыли  0.6950788805902164
# Доход от хеджа  -0.7505389153635951
# Процентный заработок  0.26666666666666666
# 69 день
# start_price =  1655.21
# end_price =  1631.9
# high_board =  1754.1644092836125
# low_board =  1559.8355907163875
# Непрямые потери/прибыли  -0.8021737141619689
# Доход от хеджа  0.7171122019833213
# Процентный заработок  0.26666666666666666
# 70 день
# start_price =  1631.89
# end_price =  1639.62
# high_board =  1798.1521589550541
# low_board =  1473.5478410449455
# Непрямые потери/прибыли  0.23698057422776309
# Доход от хеджа  -0.2426206354534734
# Процентный заработок  0.26666666666666666
# 71 день
# start_price =  1639.53
# end_price =  1631.09
# high_board =  1820.7528259622177
# low_board =  1445.5071740377825
# Непрямые потери/прибыли  -0.2544151385967419
# Доход от хеджа  0.24861098179667873
# Процентный заработок  0.26666666666666666
# 72 день
# start_price =  1631.24
# end_price =  1716.78
# high_board =  1783.9638833788176
# low_board =  1489.6761166211822
# Непрямые потери/прибыли  1.9592495098035956
# Доход от хеджа  -2.7213608510247074
# Процентный заработок  0.26666666666666666
# 73 день
# start_price =  1716.57
# end_price =  1719.01
# high_board =  1896.102737317855
# low_board =  1534.917262682145
# Непрямые потери/прибыли  0.07017467317038673
# Доход от хеджа  -0.07065480208633854
# Процентный заработок  0.26666666666666666
# 74 день
# start_price =  1719.01
# end_price =  1660.91
# high_board =  1839.750111629342
# low_board =  1596.309888370658
# Непрямые потери/прибыли  -2.086574791338114
# Доход от хеджа  1.676320147088954
# Процентный заработок  0.26666666666666666
# 75 день
# start_price =  1660.9
# end_price =  1676.36
# high_board =  1839.8554790401536
# low_board =  1477.9845209598466
# Непрямые потери/прибыли  0.4404338240607597
# Доход от хеджа  -0.4603172752800276
# Процентный заработок  0.26666666666666666
# 76 день
# start_price =  1676.29
# end_price =  1708.44
# high_board =  1773.2561875562703
# low_board =  1586.7438124437297
# Непрямые потери/прибыли  0.8318123838636282
# Доход от хеджа  -0.9971132587124135
# Процентный заработок  0.26666666666666666
# 77 день
# start_price =  1708.4
# end_price =  1615.22
# high_board =  1826.318841611702
# low_board =  1595.561158388298
# Непрямые потери/прибыли  -3.9192309243620826
# Доход от хеджа  2.787148941875511
# Процентный заработок  0.26666666666666666
# 78 день
# start_price =  1615.22
# end_price =  1585.5
# high_board =  1794.537665964342
# low_board =  1445.4823340356581
# Непрямые потери/прибыли  -1.0243081271977594
# Доход от хеджа  0.9452483383289547
# Процентный заработок  0.26666666666666666
# 79 день
# start_price =  1585.49
# end_price =  1596.76
# high_board =  1737.776639645767
# low_board =  1444.543360354233
# Непрямые потери/прибыли  0.35549547299189577
# Доход от хеджа  -0.36915517018415384
# Процентный заработок  0.26666666666666666
# 80 день
# start_price =  1596.75
# end_price =  1608.11
# high_board =  1792.0762116722337
# low_board =  1409.2237883277664
# Непрямые потери/прибыли  0.3524148317859632
# Доход от хеджа  -0.3629698343188081
# Процентный заработок  0.26666666666666666
# 81 день
# start_price =  1608.24
# end_price =  1682.49
# high_board =  1701.339987943239
# low_board =  1515.1800120567611
# Непрямые потери/прибыли  1.3882040050196887
# Доход от хеджа  -2.3089201244875017
# Процентный заработок  0.26666666666666666
# 82 день
# start_price =  1682.49
# end_price =  1698.2
# high_board =  1882.9303222616777
# low_board =  1488.309677738322
# Непрямые потери/прибыли  0.45568745896438223
# Доход от хеджа  -0.47427363649924253
# Процентный заработок  0.26666666666666666
# 83 день
# start_price =  1698.03
# end_price =  1742.63
# high_board =  1861.0497087387148
# low_board =  1548.8302912612855
# Непрямые потери/прибыли  1.1838168527335657
# Доход от хеджа  -1.3714175523980063
# Процентный заработок  0.26666666666666666
# 84 день
# start_price =  1742.48
# end_price =  1740.28
# high_board =  1847.785635022999
# low_board =  1638.114364977001
# Непрямые потери/прибыли  -0.0640742331049271
# Доход от хеджа  0.06341143251255098
# Процентный заработок  0.26666666666666666
# 85 день
# start_price =  1740.2
# end_price =  1766.15
# high_board =  1900.4825873639068
# low_board =  1574.5974126360932
# Непрямые потери/прибыли  0.6740602399044837
# Доход от хеджа  -0.7334321417139738
# Процентный заработок  0.26666666666666666
# 86 день
# start_price =  1766.15
# end_price =  1799.34
# high_board =  1886.9811748658478
# low_board =  1643.0188251341522
# Непрямые потери/прибыли  0.8029256369440629
# Доход от хеджа  -0.9307560275184994
# Процентный заработок  0.26666666666666666
# 87 день
# start_price =  1799.41
# end_price =  1745.28
# high_board =  1958.0527355669267
# low_board =  1643.5072644330733
# Непрямые потери/прибыли  -1.7799996890310865
# Доход от хеджа  1.5172063472600017
# Процентный заработок  0.26666666666666666
# 88 день
# start_price =  1745.28
# end_price =  1727.71
# high_board =  1973.309133757851
# low_board =  1514.1108662421493
# Непрямые потери/прибыли  -0.519272741247645
# Доход от хеджа  0.4999156655102589
# Процентный заработок  0.26666666666666666
# 89 день
# start_price =  1727.71
# end_price =  1739.9
# high_board =  1847.8871618934263
# low_board =  1601.7528381065736
# Непрямые потери/прибыли  0.32702309190728585
# Доход от хеджа  -0.3444947606773576
# Процентный заработок  0.26666666666666666
# 90 день
# start_price =  1739.92
# end_price =  1791.76
# high_board =  1824.7779252441608
# low_board =  1662.0620747558394
# Непрямые потери/прибыли  1.0791969161651815
# Доход от хеджа  -1.5538112489758378
# Процентный заработок  0.26666666666666666
# 91 день
# start_price =  1791.77
# end_price =  1789.67
# high_board =  1939.8681576829874
# low_board =  1643.1118423170126
# Непрямые потери/прибыли  -0.05890562248695996
# Доход от хеджа  0.05849068665553016
# Процентный заработок  0.26666666666666666
# 92 день
# start_price =  1789.67
# end_price =  1766.05
# high_board =  1873.4029401139812
# low_board =  1691.6570598860187
# Непрямые потери/прибыли  -0.6943803471783916
# Доход от хеджа  0.6080491711853035
# Процентный заработок  0.26666666666666666
# 93 день
# start_price =  1766.04
# end_price =  1770.39
# high_board =  1865.383782368364
# low_board =  1654.616217631636
# Непрямые потери/прибыли  0.11355642302732782
# Доход от хеджа  -0.11609823958675808
# Процентный заработок  0.26666666666666666
# 94 день
# start_price =  1770.38
# end_price =  1860.67
# high_board =  1853.050364622591
# low_board =  1682.029635377409
# Непрямые потери/прибыли  1.1286374633034502
# Доход от хеджа  -2.46532544103048
# Процентный заработок  0.26666666666666666
# 95 день
# start_price =  1860.66
# end_price =  1830.73
# high_board =  1991.540250631422
# low_board =  1721.8797493685781
# Непрямые потери/прибыли  -0.8707145735618593
# Доход от хеджа  0.7807221050384681
# Процентный заработок  0.26666666666666666
# 96 день
# start_price =  1830.74
# end_price =  1822.54
# high_board =  1924.3146666332723
# low_board =  1749.2453333667274
# Непрямые потери/прибыли  -0.249919393343645
# Доход от хеджа  0.23940619960645512
# Процентный заработок  0.26666666666666666
# 97 день
# start_price =  1822.68
# end_price =  1821.16
# high_board =  1939.5526997889208
# low_board =  1692.7673002110794
# Непрямые потери/прибыли  -0.03975053083455915
# Доход от хеджа  0.0394936046220829
# Процентный заработок  0.26666666666666666
# 98 день
# start_price =  1821.24
# end_price =  1834.23
# high_board =  1905.2408256719577
# low_board =  1737.7791743280422
# Непрямые потери/прибыли  0.3301117239329576
# Доход от хеджа  -0.3577751366939436
# Процентный заработок  0.26666666666666666
# 99 день
# start_price =  1834.23
# end_price =  1799.26
# high_board =  1910.4001379229755
# low_board =  1762.8398620770242
# Непрямые потери/прибыли  -1.2122261270864132
# Доход от хеджа  0.9841405430443279
# Процентный заработок  0.26666666666666666
# 100 день
# start_price =  1799.49
# end_price =  1822.75
# high_board =  1897.3269115917956
# low_board =  1723.4130884082042
# Непрямые потери/прибыли  0.6407199650852569
# Доход от хеджа  -0.7271581990545509
# Процентный заработок  0.26666666666666666
# 101 день
# start_price =  1822.71
# end_price =  1747.34
# high_board =  1889.4234149501515
# low_board =  1751.4365850498486
# Непрямые потери/прибыли  -3.147624693586981
# Доход от хеджа  1.9992010616036702
# Процентный заработок  0.26666666666666666
# 102 день
# start_price =  1747.36
# end_price =  1796.02
# high_board =  1966.7048116579492
# low_board =  1532.1551883420511
# Непрямые потери/прибыли  1.2497350061343449
# Доход от хеджа  -1.405651638521115
# Процентный заработок  0.26666666666666666
# 103 день
# start_price =  1796.03
# end_price =  1805.56
# high_board =  1915.277753741174
# low_board =  1673.342246258826
# Непрямые потери/прибыли  0.2510844223980957
# Доход от хеджа  -0.2615350556474826
# Процентный заработок  0.26666666666666666
# 104 день
# start_price =  1805.55
# end_price =  1797.55
# high_board =  1916.9548108687743
# low_board =  1691.1851891312256
# Непрямые потери/прибыли  -0.22650213316121048
# Доход от хеджа  0.21863460777396423
# Процентный заработок  0.26666666666666666
# 105 день
# start_price =  1797.55
# end_price =  1786.9
# high_board =  1901.084796224607
# low_board =  1689.215203775393
# Непрямые потери/прибыли  -0.3044602706554378
# Доход от хеджа  0.28952517331001054
# Процентный заработок  0.26666666666666666
# 106 день
# start_price =  1786.9
# end_price =  1775.81
# high_board =  1911.4585843688021
# low_board =  1659.7614156311975
# Непрямые потери/прибыли  -0.3208483730012146
# Доход от хеджа  0.30713310528757887
# Процентный заработок  0.26666666666666666
# 107 день
# start_price =  1775.85
# end_price =  1779.97
# high_board =  1886.60851160085
# low_board =  1658.85148839915
# Непрямые потери/прибыли  0.11072425220040039
# Доход от хеджа  -0.11282264302631924
# Процентный заработок  0.26666666666666666
# 108 день
# start_price =  1779.87
# end_price =  1818.09
# high_board =  1851.8449893790435
# low_board =  1692.5550106209566
# Непрямые потери/прибыли  0.7126595259811186
# Доход от хеджа  -0.9702765935615533
# Процентный заработок  0.26666666666666666
# 109 день
# start_price =  1818.09
# end_price =  1839.4
# high_board =  1925.6250139900699
# low_board =  1716.07498600993
# Непрямые потери/прибыли  0.5418942481961508
# Доход от хеджа  -0.6014925386662927
# Процентный заработок  0.26666666666666666
# 110 день
# start_price =  1839.27
# end_price =  1894.25
# high_board =  1926.6330767559161
# low_board =  1750.5269232440837
# Непрямые потери/прибыли  1.0162868195568997
# Доход от хеджа  -1.482902637272634
# Процентный заработок  0.26666666666666666
# 111 день
# start_price =  1894.26
# end_price =  1921.37
# high_board =  1997.548328784908
# low_board =  1797.4916712150919
# Непрямые потери/прибыли  0.641934473758754
# Доход от хеджа  -0.7389042609005739
# Процентный заработок  0.26666666666666666
# 112 день
# start_price =  1921.24
# end_price =  1926.77
# high_board =  2045.7361112714734
# low_board =  1788.2638887285266
# Непрямые потери/прибыли  0.13608639702931136
# Доход от хеджа  -0.13917746293560504
# Процентный заработок  0.26666666666666666
# 113 день
# start_price =  1926.77
# end_price =  1924.05
# high_board =  1997.3892041019305
# low_board =  1855.0507958980695
# Непрямые потери/прибыли  -0.07138874707455223
# Доход от хеджа  0.0700389686416342
# Процентный заработок  0.26666666666666666
# 114 день
# start_price =  1924.05
# end_price =  1916.59
# high_board =  2009.8235045821807
# low_board =  1833.5364954178194
# Непрямые потери/прибыли  -0.19686901049540406
# Доход от хеджа  0.18864935256153942
# Процентный заработок  0.26666666666666666
# 115 день
# start_price =  1916.59
# end_price =  1961.0
# high_board =  1989.9987957758015
# low_board =  1844.9612042241988
# Непрямые потери/прибыли  0.8180373490894954
# Доход от хеджа  -1.1727868175872422
# Процентный заработок  0.26666666666666666
# 116 день
# start_price =  1961.0
# end_price =  2006.19
# high_board =  2024.751806007108
# low_board =  1892.6481939928922
# Непрямые потери/прибыли  0.7179458989297061
# Доход от хеджа  -1.1120966885589094
# Процентный заработок  0.26666666666666666
# 117 день
# start_price =  2006.18
# end_price =  2001.16
# high_board =  2206.6760021357936
# low_board =  1825.0639978642062
# Непрямые потери/прибыли  -0.13311512307125906
# Доход от хеджа  0.1314672292888001
# Процентный заработок  0.26666666666666666
# 118 день
# start_price =  2001.22
# end_price =  1922.5
# high_board =  2097.3883094340354
# low_board =  1911.3116905659645
# Непрямые потери/прибыли  -2.881718568357594
# Доход от хеджа  2.0329674557189215
# Процентный заработок  0.26666666666666666
# 119 день
# start_price =  1922.53
# end_price =  1933.97
# high_board =  2175.5779780848934
# low_board =  1655.4420219151066
# Непрямые потери/прибыли  0.2829497204840159
# Доход от хеджа  -0.2894935511241936
# Процентный заработок  0.26666666666666666
# 120 день
# start_price =  1933.96
# end_price =  1961.4
# high_board =  2036.7480276349404
# low_board =  1844.5719723650598
# Непрямые потери/прибыли  0.6575960265346792
# Доход от хеджа  -0.7588918306927767
# Процентный заработок  0.26666666666666666
# 121 день
# start_price =  1961.4
# end_price =  1929.44
# high_board =  2078.1364574395725
# low_board =  1840.8635425604275
# Непрямые потери/прибыли  -0.9123186198864541
# Доход от хеджа  0.8016761139053521
# Процентный заработок  0.26666666666666666
# 122 день
# start_price =  1929.62
# end_price =  1875.63
# high_board =  2042.5138239267294
# low_board =  1818.5461760732703
# Непрямые потери/прибыли  -1.7523737172121079
# Доход от хеджа  1.410348465390582
# Процентный заработок  0.26666666666666666
# 123 день
# start_price =  1875.77
# end_price =  1727.22
# high_board =  2032.4328469491306
# low_board =  1706.5071530508694
# Непрямые потери/прибыли  -5.685787979000956
# Доход от хеджа  3.8066284234508783
# Процентный заработок  0.26666666666666666
# 124 день
# start_price =  1727.77
# end_price =  1766.38
# high_board =  2131.986195442842
# low_board =  1362.8138045571582
# Непрямые потери/прибыли  1.118280440284103
# Доход от хеджа  -1.1743671536748441
# Процентный заработок  0.26666666666666666
# 125 день
# start_price =  1766.41
# end_price =  1587.71
# high_board =  2014.1880303769833
# low_board =  1551.1719696230168
# Непрямые потери/прибыли  -7.4700127930974025
# Доход от хеджа  5.413769716621852
# Процентный заработок  0.26666666666666666
# 126 день
# start_price =  1587.68
# end_price =  1534.72
# high_board =  1956.0746297883693
# low_board =  1255.0253702116304
# Непрямые потери/прибыли  -1.881002577618407
# Доход от хеджа  1.7528702015745998
# Процентный заработок  0.26666666666666666
# 127 день
# start_price =  1534.81
# end_price =  1571.87
# high_board =  2166.824617418371
# low_board =  914.3353825816288
# Непрямые потери/прибыли  1.1827159962255696
# Доход от хеджа  -1.2184393490005532
# Процентный заработок  0.26666666666666666
# 128 день
# start_price =  1571.89
# end_price =  1614.58
# high_board =  1800.6132486361957
# low_board =  1325.3267513638043
# Непрямые потери/прибыли  1.1849819356704705
# Доход от хеджа  -1.3069495942037468
# Процентный заработок  0.26666666666666666
# 129 день
# start_price =  1614.96
# end_price =  1615.73
# high_board =  1861.3646426013024
# low_board =  1390.6553573986976
# Непрямые потери/прибыли  0.024919881518226106
# Доход от хеджа  -0.024958879031917663
# Процентный заработок  0.26666666666666666
# 130 день
# start_price =  1615.82
# end_price =  1607.51
# high_board =  1850.4242487026725
# low_board =  1407.5357512973278
# Непрямые потери/прибыли  -0.2772639021982437
# Доход от хеджа  0.27242660382495265
# Процентный заработок  0.26666666666666666
# 131 день
# start_price =  1607.5
# end_price =  1616.87
# high_board =  1803.9102298211294
# low_board =  1413.5697701788706
# Непрямые потери/прибыли  0.28630195074352827
# Доход от хеджа  -0.29329802862270876
# Процентный заработок  0.26666666666666666
# 132 день
# start_price =  1617.14
# end_price =  1634.14
# high_board =  1753.2791822182878
# low_board =  1467.6608177817125
# Непрямые потери/прибыли  0.4697850444789653
# Доход от хеджа  -0.5010698961105028
# Процентный заработок  0.26666666666666666
# 133 день
# start_price =  1634.15
# end_price =  1511.28
# high_board =  1810.8338821980124
# low_board =  1457.9061178019874
# Непрямые потери/прибыли  -5.124092923096879
# Доход от хеджа  3.7641337623367033
# Процентный заработок  0.26666666666666666
# 134 день
# start_price =  1510.85
# end_price =  1457.66
# high_board =  1736.7806163849943
# low_board =  1276.7393836150059
# Непрямые потери/прибыли  -1.9361370278653478
# Доход от хеджа  1.7289680583494418
# Процентный заработок  0.26666666666666666
# 135 день
# start_price =  1457.66
# end_price =  1506.52
# high_board =  1599.992611777595
# low_board =  1337.187388222405
# Непрямые потери/прибыли  1.5037881523069618
# Доход от хеджа  -1.8153804402722016
# Процентный заработок  0.26666666666666666
# 136 день
# start_price =  1506.11
# end_price =  1437.45
# high_board =  1688.8880787217497
# low_board =  1326.5119212782504
# Непрямые потери/прибыли  -2.741336485723278
# Доход от хеджа  2.2993844995604302
# Процентный заработок  0.26666666666666666
# 137 день
# start_price =  1437.61
# end_price =  1488.43
# high_board =  1681.2670514469226
# low_board =  1208.9729485530772
# Непрямые потери/прибыли  1.6335387374346588
# Доход от хеджа  -1.8237278787908768
# Процентный заработок  0.26666666666666666
# 138 день
# start_price =  1488.44
# end_price =  1474.8
# high_board =  1618.1377748835735
# low_board =  1358.4622251164265
# Непрямые потери/прибыли  -0.48188236781807614
# Доход от хеджа  0.4577037843597893
# Процентный заработок  0.26666666666666666
# 139 день
# start_price =  1474.8
# end_price =  1447.68
# high_board =  1583.4470745743574
# low_board =  1363.1929254256424
# Непрямые потери/прибыли  -1.0213527422346602
# Доход от хеджа  0.9070902416325755
# Процентный заработок  0.26666666666666666
# 140 день
# start_price =  1447.68
# end_price =  1336.47
# high_board =  1563.6506241570287
# low_board =  1348.1893758429715
# Непрямые потери/прибыли  -6.165018516247278
# Доход от хеджа  4.134757932360964
# Процентный заработок  0.26666666666666666
# 141 день
# start_price =  1336.15
# end_price =  1346.6
# high_board =  1601.3946852348358
# low_board =  1063.185314765164
# Непрямые потери/прибыли  0.37784706047576666
# Доход от хеджа  -0.3854397582717222
# Процентный заработок  0.26666666666666666
# 142 день
# start_price =  1346.53
# end_price =  1435.39
# high_board =  1480.9993703939795
# low_board =  1209.9806296060206
# Непрямые потери/прибыли  2.1924182148178373
# Доход от хеджа  -3.27426875262292
# Процентный заработок  0.26666666666666666
# 143 день
# start_price =  1435.26
# end_price =  1429.92
# high_board =  1705.503145760846
# low_board =  1170.456854239154
# Непрямые потери/прибыли  -0.18978054587330817
# Доход от хеджа  0.18792043322937424
# Процентный заработок  0.26666666666666666
# 144 день
# start_price =  1429.87
# end_price =  1540.65
# high_board =  1501.9464093345523
# low_board =  1350.6535906654476
# Непрямые потери/прибыли  1.2007191080557256
# Доход от хеджа  -3.690962522092465
# Процентный заработок  0.26666666666666666
# 145 день
# start_price =  1540.66
# end_price =  1552.14
# high_board =  1694.095532859654
# low_board =  1379.384467140346
# Непрямые потери/прибыли  0.3496958088534452
# Доход от хеджа  -0.3632862939815526
# Процентный заработок  0.26666666666666666
# 146 день
# start_price =  1552.19
# end_price =  1530.75
# high_board =  1664.7071642757553
# low_board =  1440.2128357242448
# Непрямые потери/прибыли  -0.7587153411382053
# Доход от хеджа  0.6922983624483968
# Процентный заработок  0.26666666666666666
# 147 день
# start_price =  1531.01
# end_price =  1562.01
# high_board =  1672.3898829345405
# low_board =  1410.5701170654593
# Непрямые потери/прибыли  0.9735036107566764
# Доход от хеджа  -1.093374281232085
# Процентный заработок  0.26666666666666666
# 148 день
# start_price =  1562.0
# end_price =  1489.55
# high_board =  1640.3615793739841
# low_board =  1500.1984206260158
# Непрямые потери/прибыли  -3.789678443431832
# Доход от хеджа  2.5931441809490132
# Процентный заработок  0.26666666666666666
# 149 день
# start_price =  1489.6
# end_price =  1559.99
# high_board =  1610.0135633817838
# low_board =  1373.4864366182162
# Непрямые потери/прибыли  1.7025291401664422
# Доход от хеджа  -2.405668347286282
# Процентный заработок  0.26666666666666666
# 150 день
# start_price =  1559.99
# end_price =  1589.6
# high_board =  1721.929090634438
# low_board =  1409.090909365562
# Непрямые потери/прибыли  0.8927094867827945
# Доход от хеджа  -0.9825361469050535
# Процентный заработок  0.26666666666666666
# 151 день
# start_price =  1589.76
# end_price =  1589.15
# high_board =  1722.8364099983714
# low_board =  1469.5635900016287
# Непрямые потери/прибыли  -0.02020715525663519
# Доход от хеджа  0.02016093920373529
# Процентный заработок  0.26666666666666666
# 152 день
# start_price =  1589.28
# end_price =  1561.16
# high_board =  1722.1616289301821
# low_board =  1444.558371069818
# Непрямые потери/прибыли  -0.9373589741004884
# Доход от хеджа  0.8469451452346329
# Процентный заработок  0.26666666666666666
# 153 день
# start_price =  1561.18
# end_price =  1563.57
# high_board =  1689.4873022017714
# low_board =  1426.5126977982286
# Непрямые потери/прибыли  0.07399778091086162
# Доход от хеджа  -0.0746934440894676
# Процентный заработок  0.26666666666666666
# 154 день
# start_price =  1563.63
# end_price =  1526.02
# high_board =  1675.191293768846
# low_board =  1453.5087062311538
# Непрямые потери/прибыли  -1.4169841393337101
# Доход от хеджа  1.2104623875888625
# Процентный заработок  0.26666666666666666
# 155 день
# start_price =  1526.28
# end_price =  1481.38
# high_board =  1718.8508051975477
# low_board =  1339.6491948024523
# Непрямые потери/прибыли  -1.6707013829918127
# Доход от хеджа  1.4939374040363909
# Процентный заработок  0.26666666666666666
# 156 день
# start_price =  1481.39
# end_price =  1499.11
# high_board =  1600.019563579523
# low_board =  1369.2204364204767
# Непрямые потери/прибыли  0.5689080569921678
# Доход от хеджа  -0.6148272099939788
# Процентный заработок  0.26666666666666666
# 157 день
# start_price =  1499.19
# end_price =  1531.19
# high_board =  1656.1401335519638
# low_board =  1350.539866448036
# Непрямые потери/прибыли  0.9844758428347866
# Доход от хеджа  -1.0962289365595894
# Процентный заработок  0.26666666666666666
# 158 день
# start_price =  1531.25
# end_price =  1578.13
# high_board =  1695.0296862904622
# low_board =  1364.4703137095378
# Непрямые потери/прибыли  1.2997880120949823
# Доход от хеджа  -1.5168829180964813
# Процентный заработок  0.26666666666666666
# 159 день
# start_price =  1578.14
# end_price =  1575.78
# high_board =  1748.6755018787503
# low_board =  1423.1844981212498
# Непрямые потери/прибыли  -0.07889313649223073
# Доход от хеджа  0.07835059326899069
# Процентный заработок  0.26666666666666666
# 160 день
# start_price =  1575.79
# end_price =  1663.97
# high_board =  1666.369293930944
# low_board =  1480.3707060690558
# Непрямые потери/прибыли  1.3986693489478785
# Доход от хеджа  -2.725153930252
# Процентный заработок  0.26666666666666666
# 161 день
# start_price =  1663.93
# end_price =  1677.89
# high_board =  1864.377169190757
# low_board =  1482.142830809243
# Непрямые потери/прибыли  0.42464688601762113
# Доход от хеджа  -0.4399674971414761
# Процентный заработок  0.26666666666666666
# 162 день
# start_price =  1677.89
# end_price =  1671.84
# high_board =  1789.2085049244454
# low_board =  1570.1514950755547
# Непрямые потери/прибыли  -0.18822052687894608
# Доход от хеджа  0.18323232764527744
# Процентный заработок  0.26666666666666666
# 163 день
# start_price =  1671.86
# end_price =  1745.97
# high_board =  1768.0500331488415
# low_board =  1568.5499668511584
# Непрямые потери/прибыли  1.3139495977970483
# Доход от хеджа  -2.137292373708276
# Процентный заработок  0.26666666666666666
# 164 день
# start_price =  1745.68
# end_price =  1675.0
# high_board =  1952.5261107791898
# low_board =  1541.2338892208104
# Непрямые потери/прибыли  -2.3913222881469576
# Доход от хеджа  2.036239078295127
# Процентный заработок  0.26666666666666666
# 165 день
# start_price =  1675.01
# end_price =  1724.25
# high_board =  1814.1425038948685
# low_board =  1543.8574961051315
# Непрямые потери/прибыли  1.2454651911032677
# Доход от хеджа  -1.5132381587881982
# Процентный заработок  0.26666666666666666
# 166 день
# start_price =  1724.46
# end_price =  1818.33
# high_board =  1845.5115991772732
# low_board =  1616.0284008227268
# Непрямые потери/прибыли  1.7580785786664554
# Доход от хеджа  -2.871397578804996
# Процентный заработок  0.26666666666666666
# 167 день
# start_price =  1818.19
# end_price =  1825.42
# high_board =  2032.046492981278
# low_board =  1603.393507018722
# Непрямые потери/прибыли  0.19503457624723275
# Доход от хеджа  -0.19838810072584198
# Процентный заработок  0.26666666666666666
# 168 день
# start_price =  1825.42
# end_price =  1832.99
# high_board =  1938.4246240082023
# low_board =  1712.5553759917977
# Непрямые потери/прибыли  0.20052874977092294
# Доход от хеджа  -0.20747806244962744
# Процентный заработок  0.26666666666666666
# 169 день
# start_price =  1832.98
# end_price =  1873.83
# high_board =  1942.3631887015285
# low_board =  1722.4368112984716
# Непрямые потери/прибыли  0.9014527033455177
# Доход от хеджа  -1.1084282694466483
# Процентный заработок  0.26666666666666666
# 170 день
# start_price =  1873.82
# end_price =  1814.12
# high_board =  2001.5615688885264
# low_board =  1735.5584311114735
# Непрямые потери/прибыли  -1.8933124082681885
# Доход от хеджа  1.5300018193320915
# Процентный заработок  0.26666666666666666
# 171 день
# start_price =  1814.12
# end_price =  1833.85
# high_board =  1924.3404894414855
# low_board =  1702.8395105585143
# Непрямые потери/прибыли  0.49274991437184834
# Доход от хеджа  -0.5411875029116606
# Процентный заработок  0.26666666666666666
# 172 день
# start_price =  1834.2
# end_price =  1795.43
# high_board =  1957.6756526431086
# low_board =  1715.4643473568913
# Непрямые потери/прибыли  -1.248522404038943
# Доход от хеджа  1.077546528618958
# Процентный заработок  0.26666666666666666
# 173 день
# start_price =  1795.44
# end_price =  1742.87
# high_board =  1980.3449675753636
# low_board =  1616.0150324246365
# Непрямые потери/прибыли  -1.700387290647487
# Доход от хеджа  1.4860068211495847
# Процентный заработок  0.26666666666666666
# 174 день
# start_price =  1743.03
# end_price =  1795.81
# high_board =  1909.5958012068934
# low_board =  1577.0641987931065
# Непрямые потери/прибыли  1.276452463527522
# Доход от хеджа  -1.5167619907245273
# Процентный заработок  0.26666666666666666
# 175 день
# start_price =  1795.73
# end_price =  1805.27
# high_board =  1946.1447131981593
# low_board =  1650.9352868018407
# Непрямые потери/прибыли  0.26210290851940155
# Доход от хеджа  -0.2706870228767547
# Процентный заработок  0.26666666666666666
# 176 день
# start_price =  1805.16
# end_price =  1792.48
# high_board =  1912.1363655835999
# low_board =  1676.5836344163997
# Непрямые потери/прибыли  -0.3379820824035651
# Доход от хеджа  0.31900922862301095
# Процентный заработок  0.26666666666666666
# 177 день
# start_price =  1792.35
# end_price =  1779.29
# high_board =  1884.8902578256352
# low_board =  1704.3297421743646
# Непрямые потери/прибыли  -0.3998945845040014
# Доход от хеджа  0.3734463985687367
# Процентный заработок  0.26666666666666666
# 178 день
# start_price =  1779.29
# end_price =  1752.2
# high_board =  1919.63164435891
# low_board =  1637.4283556410899
# Непрямые потери/прибыли  -0.8307957391018417
# Доход от хеджа  0.7571584217282269
# Процентный заработок  0.26666666666666666
# 179 день
# start_price =  1752.21
# end_price =  1782.83
# high_board =  1875.7847458776203
# low_board =  1620.2752541223797
# Непрямые потери/прибыли  0.7404556554990283
# Доход от хеджа  -0.8451654203795136
# Процентный заработок  0.26666666666666666
# 180 день
# start_price =  1782.83
# end_price =  1881.5
# high_board =  1884.88491520531
# low_board =  1678.3150847946897
# Непрямые потери/прибыли  1.4124822692662908
# Доход от хеджа  -2.734275228964244
# Процентный заработок  0.26666666666666666
# 181 день
# start_price =  1881.49
# end_price =  1922.14
# high_board =  2043.3461945523522
# low_board =  1716.7538054476477
# Непрямые потери/прибыли  0.9362778474461653
# Доход от хеджа  -1.070734758585301
# Процентный заработок  0.26666666666666666
# 182 день
# start_price =  1922.24
# end_price =  1898.59
# high_board =  2050.417906620223
# low_board =  1804.702093379777
# Непрямые потери/прибыли  -0.7013817658218402
# Доход от хеджа  0.6418057483337553
# Процентный заработок  0.26666666666666666
# 183 день
# start_price =  1898.6
# end_price =  1858.32
# high_board =  1967.8200273694647
# low_board =  1823.5599726305352
# Непрямые потери/прибыли  -1.3173505613667036
# Доход от хеджа  1.0179856578512236
# Процентный заработок  0.26666666666666666
# 184 день
# start_price =  1858.31
# end_price =  1877.64
# high_board =  1969.0084233064513
# low_board =  1731.9715766935487
# Непрямые потери/прибыли  0.4433665225302974
# Доход от хеджа  -0.48577959040446195
# Процентный заработок  0.26666666666666666
# 185 день
# start_price =  1877.64
# end_price =  1798.39
# high_board =  1966.8004844833395
# low_board =  1786.6195155166606
# Непрямые потери/прибыли  -3.0367999722092476
# Доход от хеджа  2.0885767727419533
# Процентный заработок  0.26666666666666666
# 186 день
# start_price =  1798.26
# end_price =  1770.6
# high_board =  2009.685640750328
# low_board =  1582.5343592496718
# Непрямые потери/прибыли  -0.8115219343515889
# Доход от хеджа  0.7613347159037759
# Процентный заработок  0.26666666666666666
# 187 день
# start_price =  1770.92
# end_price =  1751.88
# high_board =  1861.0973482018055
# low_board =  1670.5226517981944
# Непрямые потери/прибыли  -0.5627434547127552
# Доход от хеджа  0.5087450830375255
# Процентный заработок  0.26666666666666666
# 188 день
# start_price =  1751.93
# end_price =  1808.17
# high_board =  1870.4969330320068
# low_board =  1635.4630669679934
# Непрямые потери/прибыли  1.2353555283306505
# Доход от хеджа  -1.6194282247963903
# Процентный заработок  0.26666666666666666
# 189 день
# start_price =  1808.15
# end_price =  1801.32
# high_board =  1981.485987438628
# low_board =  1631.7540125613718
# Непрямые потери/прибыли  -0.19090998077671006
# Доход от хеджа  0.18721457076955714
# Процентный заработок  0.26666666666666666
# 190 день
# start_price =  1801.2
# end_price =  1780.19
# high_board =  1895.6855098773192
# low_board =  1700.8744901226808
# Непрямые потери/прибыли  -0.6290070092358047
# Доход от хеджа  0.5657385922225431
# Процентный заработок  0.26666666666666666
# 191 день
# start_price =  1780.2
# end_price =  1785.38
# high_board =  1861.0134871024868
# low_board =  1706.126512897513
# Непрямые потери/прибыли  0.14695461851126357
# Доход от хеджа  -0.15182032414575516
# Процентный заработок  0.26666666666666666
# 192 день
# start_price =  1785.29
# end_price =  1782.28
# high_board =  1848.5243372364698
# low_board =  1715.15566276353
# Непрямые потери/прибыли  -0.08184283326665431
# Доход от хеджа  0.07993865916928089
# Процентный заработок  0.26666666666666666
# 193 день
# start_price =  1782.31
# end_price =  1823.14
# high_board =  1872.1095828586895
# low_board =  1695.4104171413105
# Непрямые потери/прибыли  0.8995485726403407
# Доход от хеджа  -1.164222414491555
# Процентный заработок  0.26666666666666666
# 194 день
# start_price =  1823.12
# end_price =  1813.9
# high_board =  1904.1000427223269
# low_board =  1736.8599572776732
# Непрямые потери/прибыли  -0.25885575388246984
# Доход от хеджа  0.24487998300500705
# Процентный заработок  0.26666666666666666
# 195 день
# start_price =  1813.9
# end_price =  1823.69
# high_board =  1904.7718462663634
# low_board =  1726.8281537336366
# Непрямые потери/прибыли  0.26077638653614343
# Доход от хеджа  -0.2756234118403593
# Процентный заработок  0.26666666666666666
# 196 день
# start_price =  1823.68
# end_price =  1760.05
# high_board =  1911.9037845528164
# low_board =  1744.4162154471837
# Непрямые потери/прибыли  -2.5124141101149022
# Доход от хеджа  1.8378767868659702
# Процентный заработок  0.26666666666666666
# 197 день
# start_price =  1760.12
# end_price =  1802.38
# high_board =  1899.2738576637526
# low_board =  1615.946142336247
# Непрямые потери/прибыли  1.0001564981510835
# Доход от хеджа  -1.1792161156238685
# Процентный заработок  0.26666666666666666
# 198 день
# start_price =  1802.38
# end_price =  1817.18
# high_board =  1900.3387525454973
# low_board =  1705.1012474545028
# Непрямые потери/прибыли  0.38087506204420585
# Доход от хеджа  -0.41199823213989006
# Процентный заработок  0.26666666666666666
# 199 день
# start_price =  1817.21
# end_price =  1812.0
# high_board =  1894.4108970860784
# low_board =  1736.7091029139215
# Непрямые потери/прибыли  -0.1450946185590274
# Доход от хеджа  0.14035190699173536
# Процентный заработок  0.26666666666666666
# 200 день
# start_price =  1812.0
# end_price =  1825.67
# high_board =  1884.8075070104214
# low_board =  1746.8324929895784
# Непрямые потери/прибыли  0.36072219276543915
# Доход от хеджа  -0.39809436943840254
# Процентный заработок  0.26666666666666666
# 201 день
# ...
# end_price =  4223.88
# high_board =  4784.535576986791
# low_board =  4395.464423013209
# Непрямые потери/прибыли  -6.860229758936887
# Доход от хеджа  4.101506564508015
# Процентный заработок  0.26666666666666666
# 975 день
# start_price =  4223.89
# end_price =  3875.51
# high_board =  4724.2622267813385
# low_board =  3750.597773218662
# Непрямые потери/прибыли  -5.77764013980504
# Доход от хеджа  4.238620128629427
# Процентный заработок  0.26666666666666666
# 976 день
# start_price =  3876.0
# end_price =  3975.0
# high_board =  4739.57611426347
# low_board =  2960.4238857365294
# Непрямые потери/прибыли  1.1687007684557216
# Доход от хеджа  -1.2397637649310533
# Процентный заработок  0.26666666666666666
# 977 день
# start_price =  3975.0
# end_price =  4069.91
# high_board =  4276.348775378957
# low_board =  3661.2712246210426
# Непрямые потери/прибыли  0.9855916549314614
# Доход от хеджа  -1.1698074826529727
# Процентный заработок  0.26666666666666666
# 978 день
# start_price =  4069.93
# end_price =  4191.52
# high_board =  4306.246882875083
# low_board =  3828.433117124917
# Непрямые потери/прибыли  1.0974469358031813
# Доход от хеджа  -1.4775664136100286
# Процентный заработок  0.26666666666666666
# 979 день
# start_price =  4191.86
# end_price =  4157.41
# high_board =  4480.035852919667
# low_board =  3897.6441470803334
# Непрямые потери/прибыли  -0.43106084630277763
# Доход от хеджа  0.40665382582088105
# Процентный заработок  0.26666666666666666
# 980 день
# start_price =  4157.41
# end_price =  4141.28
# high_board =  4393.061447552123
# low_board =  3892.038552447877
# Непрямые потери/прибыли  -0.18874119953573576
# Доход от хеджа  0.18248368854713362
# Процентный заработок  0.26666666666666666
# 981 день
# start_price =  4141.28
# end_price =  4142.59
# high_board =  4394.842186666494
# low_board =  3882.3978133335063
# Непрямые потери/прибыли  0.01561173397541804
# Доход от хеджа  -0.015652166538406228
# Процентный заработок  0.26666666666666666
# 982 день
# start_price =  4142.58
# end_price =  4059.87
# high_board =  4355.918151778384
# low_board =  3930.1018482216173
# Непрямые потери/прибыли  -1.1961691093812732
# Доход от хеджа  1.0003071186484498
# Процентный заработок  0.26666666666666666
# 983 день
# start_price =  4059.87
# end_price =  4345.3
# high_board =  4372.283874765522
# low_board =  3734.5761252344773
# Непрямые потери/прибыли  1.8708749416594506
# Доход от хеджа  -3.4442614338671835
# Процентный заработок  0.26666666666666666
# 984 день
# start_price =  4345.3
# end_price =  4359.99
# high_board =  4967.67299496053
# low_board =  3763.747005039471
# Непрямые потери/прибыли  0.17270190368701144
# Доход от хеджа  -0.17476440408206603
# Процентный заработок  0.26666666666666666
# 985 день
# start_price =  4360.0
# end_price =  4358.95
# high_board =  4528.045841453197
# low_board =  4168.114158546803
# Непрямые потери/прибыли  -0.011278863750008306
# Доход от хеджа  0.011243732440850595
# Процентный заработок  0.26666666666666666
# 986 день
# start_price =  4358.94
# end_price =  4268.98
# high_board =  4545.864183340131
# low_board =  4160.695816659869
# Непрямые потери/прибыли  -1.2450991338217476
# Доход от хеджа  1.0015749076404414
# Процентный заработок  0.26666666666666666
# 987 день
# start_price =  4268.98
# end_price =  4370.0
# high_board =  4581.067929210034
# low_board =  3971.5320707899664
# Непрямые потери/прибыли  1.0155120510424664
# Доход от хеджа  -1.21160471777876
# Процентный заработок  0.26666666666666666
# 988 день
# start_price =  4369.99
# end_price =  4362.53
# high_board =  4616.129152738173
# low_board =  4101.110847261827
# Непрямые потери/прибыли  -0.08282356140989489
# Доход от хеджа  0.08158614634114672
# Процентный заработок  0.26666666666666666
# 989 день
# start_price =  4362.53
# end_price =  4414.35
# high_board =  4613.459948861989
# low_board =  4116.2200511380115
# Непрямые потери/прибыли  0.5375440206184745
# Доход от хеджа  -0.5994397131766636
# Процентный заработок  0.26666666666666666
# 990 день
# start_price =  4414.35
# end_price =  4378.93
# high_board =  4552.981354111047
# low_board =  4251.738645888952
# Непрямые потери/прибыли  -0.4166172408062163
# Доход от хеджа  0.3692552806640729
# Процентный заработок  0.26666666666666666
# 991 день
# start_price =  4378.93
# end_price =  4281.49
# high_board =  4628.554446101344
# low_board =  4143.685553898656
# Непрямые потери/прибыли  -1.3717030969220723
# Доход от хеджа  1.1455975200185629
# Процентный заработок  0.26666666666666666
# 992 день
# start_price =  4281.48
# end_price =  4184.26
# high_board =  4529.274033568918
# low_board =  4048.425966431084
# Непрямые потери/прибыли  -1.4023457196722044
# Доход от хеджа  1.1701584350746086
# Процентный заработок  0.26666666666666666
# 993 день
# start_price =  4184.26
# end_price =  4123.77
# high_board =  4428.159517518787
# low_board =  3943.3604824812132
# Непрямые потери/прибыли  -0.8181472109279664
# Доход от хеджа  0.7273008853655102
# Процентный заработок  0.26666666666666666
# 994 день
# start_price =  4123.67
# end_price =  4190.88
# high_board =  4360.301686917292
# low_board =  3915.4983130827077
# Непрямые потери/прибыли  0.7439350952766821
# Доход от хеджа  -0.867071315723193
# Процентный заработок  0.26666666666666666
# 995 день
# start_price =  4190.88
# end_price =  3991.08
# high_board =  4589.414925121946
# low_board =  3763.865074878054
# Непрямые потери/прибыли  -2.892516373023468
# Доход от хеджа  2.3015125192064696
# Процентный заработок  0.26666666666666666
# 996 день
# start_price =  3991.08
# end_price =  4007.78
# high_board =  4257.596771930601
# low_board =  3744.0632280693985
# Непрямые потери/прибыли  0.21035728920015817
# Доход от хеджа  -0.21716096634143567
# Процентный заработок  0.26666666666666666
# 997 день
# start_price =  4007.78
# end_price =  4017.87
# high_board =  4520.3122826492745
# low_board =  3535.267717350726
# Непрямые потери/прибыли  0.12970495783197755
# Доход от хеджа  -0.13099437243336567
# Процентный заработок  0.26666666666666666
# 998 день
# start_price =  4017.69
# end_price =  4015.89
# high_board =  4237.636391661879
# low_board =  3783.9236083381206
# Непрямые потери/прибыли  -0.02180749440769958
# Доход от хеджа  0.02171860400540173
# Процентный заработок  0.26666666666666666
# 999 день
# start_price =  4016.09
# end_price =  4048.98
# high_board =  4225.741137062385
# low_board =  3813.6588629376156
# Непрямые потери/прибыли  0.38397011207036424
# Доход от хеджа  -0.4166522441651642
# Процентный заработок  0.26666666666666666
# 1000 день
# start_price =  4048.99
# end_price =  4038.86
# high_board =  4217.677927775494
# low_board =  3875.242072224507
# Непрямые потери/прибыли  -0.1269496466777431
# Доход от хеджа  0.12324449005995854
# Процентный заработок  0.26666666666666666
# 1001 день
# start_price =  4038.87
# end_price =  4131.64
# high_board =  4163.139242723704
# low_board =  3924.2007572762964
# Непрямые потери/прибыли  0.748705764657398
# Доход от хеджа  -1.1946074731305034
# Процентный заработок  0.26666666666666666
# 1002 день
# start_price =  4131.64
# end_price =  4014.55
# high_board =  4414.194633189986
# low_board =  3854.9053668100137
# Непрямые потери/прибыли  -1.732655402243788
# Доход от хеджа  1.4317371074754641
# Процентный заработок  0.26666666666666666
# 1003 день
# start_price =  4014.55
# end_price =  3906.64
# high_board =  4304.613911507229
# low_board =  3741.666088492771
# Непрямые потери/прибыли  -1.6461367582968456
# Доход от хеджа  1.3850019229275434
# Процентный заработок  0.26666666666666666
# 1004 день
# start_price =  3906.65
# end_price =  3795.61
# high_board =  4154.480242104911
# low_board =  3684.2597578950886
# Непрямые потери/прибыли  -1.8384937247762911
# Доход от хеджа  1.4980548180758597
# Процентный заработок  0.26666666666666666
# 1005 день
# start_price =  3795.77
# end_price =  3722.52
# high_board =  4072.3436881146768
# low_board =  3511.4963118853234
# Непрямые потери/прибыли  -1.078890828263579
# Доход от хеджа  0.951642673885653
# Процентный заработок  0.26666666666666666
# 1006 день
# start_price =  3722.73
# end_price =  3770.47
# high_board =  3969.9705963431725
# low_board =  3459.409403656827
# Непрямые потери/прибыли  0.5610467847555256
# Доход от хеджа  -0.6210017966118885
# Процентный заработок  0.26666666666666666
# 1007 день
# start_price =  3770.47
# end_price =  3840.38
# high_board =  3973.790070680405
# low_board =  3573.829929319595
# Непрямые потери/прибыли  0.7805111225309691
# Доход от хеджа  -0.942556410058936
# Процентный заработок  0.26666666666666666
# 1008 день
# start_price =  3840.38
# end_price =  3869.39
# high_board =  4201.733391713662
# low_board =  3507.9466082863382
# Непрямые потери/прибыли  0.3776480028027551
# Доход от хеджа  -0.39344102480175924
# Процентный заработок  0.26666666666666666
# 1009 день
# start_price =  3869.7
# end_price =  3820.85
# high_board =  4050.5437859978406
# low_board =  3685.896214002159
# Непрямые потери/прибыли  -0.711156171155447
# Доход от хеджа  0.6260622748180243
# Процентный заработок  0.26666666666666666
# 1010 день
# start_price =  3820.53
# end_price =  4032.57
# high_board =  4016.423385785899
# low_board =  3623.9366142141007
# Непрямые потери/прибыли  1.2795607547301024
# Доход от хеджа  -2.7700584309620857
# Процентный заработок  0.26666666666666666
# 1011 день
# start_price =  4032.57
# end_price =  3996.92
# high_board =  4980.476961184501
# low_board =  3106.043038815499
# Непрямые потери/прибыли  -0.45551184779580867
# Доход от хеджа  0.4470675999535078
# Процентный заработок  0.26666666666666666
# 1012 день
# start_price =  3996.93
# end_price =  4072.82
# high_board =  4162.243745897666
# low_board =  3837.756254102334
# Непрямые потери/прибыли  0.7452859304910131
# Доход от хеджа  -0.9673174377746191
# Процентный заработок  0.26666666666666666
# 1013 день
# start_price =  4073.18
# end_price =  4002.79
# high_board =  4274.236624033297
# low_board =  3855.7633759667037
# Непрямые потери/прибыли  -0.976895267167377
# Доход от хеджа  0.8302866378126424
# Процентный заработок  0.26666666666666666
# 1014 день
# start_price =  4002.79
# end_price =  3950.48
# high_board =  4279.262158950655
# low_board =  3734.837841049345
# Непрямые потери/прибыли  -0.7268404688221208
# Доход от хеджа  0.6636449624484764
# Процентный заработок  0.26666666666666666
# 1015 день
# start_price =  3950.47
# end_price =  3785.06
# high_board =  4080.0085137938772
# low_board =  3814.331486206123
# Непрямые потери/прибыли  -3.3262979316077024
# Доход от хеджа  2.0415400300819653
# Процентный заработок  0.26666666666666666
# 1016 день
# start_price =  3785.05
# end_price =  3846.15
# high_board =  4059.93278635963
# low_board =  3488.18721364037
# Непрямые потери/прибыли  0.6898402440456142
# Доход от хеджа  -0.7760939956177749
# Процентный заработок  0.26666666666666666
# 1017 день
# start_price =  3846.15
# end_price =  3913.64
# high_board =  4115.067433279309
# low_board =  3571.992566720692
# Непрямые потери/прибыли  0.7598710852785961
# Доход от хеджа  -0.8689053348084724
# Процентный заработок  0.26666666666666666
# 1018 день
# start_price =  3913.17
# end_price =  3944.25
# high_board =  4249.003580143746
# low_board =  3581.8564198562535
# Непрямые потери/прибыли  0.3813106074825656
# Доход от хеджа  -0.39981103086795233
# Процентный заработок  0.26666666666666666
# 1019 день
# start_price =  3944.26
# end_price =  3987.61
# high_board =  4171.7014460497485
# low_board =  3737.398553950252
# Непрямые потери/прибыли  0.5207213706845737
# Доход от хеджа  -0.5755730529013005
# Процентный заработок  0.26666666666666666
# 1020 день
# start_price =  3987.6
# end_price =  3987.7
# high_board =  4140.380111657656
# low_board =  3831.299888342344
# Непрямые потери/прибыли  0.0012392013120532397
# Доход от хеджа  -0.0012396069954127165
# Процентный заработок  0.26666666666666666
# 1021 день
# start_price =  3987.7
# end_price =  3936.0
# high_board =  4177.509159179004
# low_board =  3796.3708408209955
# Непрямые потери/прибыли  -0.7341636575641686
# Доход от хеджа  0.6456581191496581
# Процентный заработок  0.26666666666666666
# 1022 день
# start_price =  3935.99
# end_price =  3939.98
# high_board =  4186.734463713073
# low_board =  3696.6055362869274
# Непрямые потери/прибыли  0.05144826423444382
# Доход от хеджа  -0.05186088537385816
# Процентный заработок  0.26666666666666666
# 1023 день
# start_price =  3940.0
# end_price =  3850.0
# high_board =  4072.776316020799
# low_board =  3814.403683979201
# Непрямые потери/прибыли  -1.5763109698424649
# Доход от хеджа  1.1738710518619189
# Процентный заработок  0.26666666666666666
# 1024 день
# start_price =  3850.0
# end_price =  3772.84
# high_board =  4058.4854197130635
# low_board =  3640.5945802869364
# Непрямые потери/прибыли  -1.1867698709533192
# Доход от хеджа  0.9998718155990662
# Процентный заработок  0.26666666666666666
# 1025 день
# start_price =  3772.84
# end_price =  3905.01
# high_board =  3974.7310060218556
# low_board =  3580.8289939781453
# Непрямые потери/прибыли  1.2078007083936582
# Доход от хеджа  -1.7955325190276403
# Процентный заработок  0.26666666666666666
# 1026 день
# start_price =  3905.0
# end_price =  4002.92
# high_board =  4204.261155648031
# low_board =  3627.7788443519694
# Непрямые потери/прибыли  1.0887476618629544
# Доход от хеджа  -1.301711462956101
# Процентный заработок  0.26666666666666666
# 1027 день
# start_price =  4002.92
# end_price =  3985.06
# high_board =  4236.24024658164
# low_board =  3773.759753418359
# Непрямые потери/прибыли  -0.2337282165517096
# Доход от хеджа  0.2250938094590396
# Процентный заработок  0.26666666666666666
# 1028 день
# start_price =  3985.05
# end_price =  4017.0
# high_board =  4111.291084265933
# low_board =  3882.0289157340667
# Непрямые потери/прибыли  0.3856085404041032
# Доход от хеджа  -0.4414742807535883
# Процентный заработок  0.26666666666666666
# 1029 день
# start_price =  4017.01
# end_price =  4038.3
# high_board =  4147.910098394907
# low_board =  3886.189901605093
# Непрямые потери/прибыли  0.24352245223360214
# Доход от хеджа  -0.26507909755363857
# Процентный заработок  0.26666666666666666
# 1030 день
# start_price =  4038.3
# end_price =  3980.11
# high_board =  4158.849245850481
# low_board =  3922.6507541495193
# Непрямые потери/прибыли  -0.9142080174431744
# Доход от хеджа  0.7354229118158421
# Процентный заработок  0.26666666666666666
# 1031 день
# start_price =  3980.45
# end_price =  3994.45
# high_board =  4195.312952840847
# low_board =  3742.6470471591538
# Непрямые потери/прибыли  0.16150842056250614
# Доход от хеджа  -0.16694738372784576
# Процентный заработок  0.26666666666666666
# 1032 день
# start_price =  3994.45
# end_price =  3957.48
# high_board =  4121.728463196347
# low_board =  3874.791536803654
# Непрямые потери/прибыли  -0.546652174519946
# Доход от хеджа  0.4770471942695489
# Процентный заработок  0.26666666666666666
# 1033 день
# start_price =  3957.47
# end_price =  3933.23
# high_board =  4129.886732062076
# low_board =  3790.233267937924
# Непрямые потери/прибыли  -0.3328506244864471
# Доход от хеджа  0.3109269345838776
# Процентный заработок  0.26666666666666666
# 1034 день
# start_price =  3933.22
# end_price =  4112.83
# high_board =  4091.3708645770457
# low_board =  3792.6291354229543
# Непрямые потери/прибыли  1.064312140152035
# Доход от хеджа  -2.417452525522915
# Процентный заработок  0.26666666666666666
# 1035 день
# start_price =  4112.84
# end_price =  4074.99
# high_board =  4437.254374577936
# low_board =  3774.405625422064
# Непрямые потери/прибыли  -0.47680838752078847
# Доход от хеджа  0.4504117560267312
# Процентный заработок  0.26666666666666666
# 1036 день
# start_price =  4075.0
# end_price =  4099.18
# high_board =  4192.949575438892
# low_board =  3960.9304245611083
# Непрямые потери/прибыли  0.2707291366154774
# Доход от хеджа  -0.30164854327387525
# Процентный заработок  0.26666666666666666
# 1037 день
# start_price =  4099.18
# end_price =  4066.81
# high_board =  4216.417261897497
# low_board =  3999.6827381025028
# Непрямые потери/прибыли  -0.48635647010688565
# Доход от хеджа  0.4271528232903875
# Процентный заработок  0.26666666666666666
# 1038 день
# start_price =  4066.8
# end_price =  4040.22
# high_board =  4219.238902069645
# low_board =  3887.601097930356
# Непрямые потери/прибыли  -0.32670106702579194
# Доход от хеджа  0.3004235287176739
# Процентный заработок  0.26666666666666666
# 1039 день
# start_price =  4040.23
# end_price =  4063.07
# high_board =  4131.500014395774
# low_board =  3934.779985604226
# Непрямые потери/прибыли  0.22946498806475368
# Доход от хеджа  -0.262282642307277
# Процентный заработок  0.26666666666666666
# 1040 день
# start_price =  4063.07
# end_price =  4100.0
# high_board =  4181.713505051016
# low_board =  3947.1464949489837
# Непрямые потери/прибыли  0.3881795188639181
# Доход от хеджа  -0.45972914732137193
# Процентный заработок  0.26666666666666666

# %% [markdown]
# ##### Статическое хеджирование (самый простой способ, честный)

# %%
start_amount = 100000
gas_price = 10  # за одну операцию, внутри умножение на 2
back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price, verbose=False, hedge_type='simple')

# %%
start_amount = 100000
gas_price = 10  # за одну операцию, внутри умножение на 2
back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price, verbose=False, hedge_type='simple')

# %% [markdown]
# #### Используем динамический хедж

# %%
start_amount = 100000
gas_price = 10 # за одну операцию, внутри умножение на 2
back_test_obj.plot_results_alt(start_amount = start_amount, gas_price = gas_price, verbose=False, hedge_type='dynamic')

# %% [markdown]
# ### Рассмотрим как изменялся курс ETH/USDT

# %%
back_test_obj.plot_price()

# %% [markdown]
# ### Дополнительно проверим как распределены изменения в стоимости (после 24 часов)¶

# %%
back_test_obj.change_price_distr()

# %% [markdown]
# #### Рассмотрим как распределены изменения цены более детально. Больше точек в n_forecast*interval_in_hour раз // Тут за 25 часов мы получаем очень много точек, старт в 5 минуту, в 10ю минуту, все эти старты приносят нам по одной точке. Вверху мы просто смотрели одну точку за 24 часа, 2 точки за 48 часов.

# %%
def make_diff(df, int_in_h, n_forcast):
    res = np.zeros(len(df)-n_forcast*int_in_h)
    opens = df['open'].values.astype(float)
    closes = df['close'].values.astype(float)
    for i in range(len(res)):
        start = opens[i]
        end = closes[i+n_forcast*int_in_h-1]
        res[i] = (end-start)/start*100
    return res

# %%
plt.hist(make_diff(df, 12, 96), bins=100)
plt.show()

# %%
# тоже самое только другим способом
plt.plot(make_diff(df, 12, 24))
plt.show()

# %% [markdown]
# ### Синтетический тест - натравим изменения за год на наш интервал, прикинем какая должна быть доходность для выхода в +

# %%
# изменения за год
diff = make_diff(df, 12, 24)

res = np.zeros(len(diff))
current_amount = 10000
start_price = 1222
high_board = 1350
low_board = 1150

earnings = 0.6

k = 0
for d in diff:
    end_price = start_price*(1+d/100)
    res[k] = new_simulate(current_amount, start_price, end_price, high_board, low_board,  earnings)
    k += 1

# %%
np.sum(res)
# Out:
# 1395.7501768605075

# %% [markdown]
# #### Вывод - около 0.6% в сутки должно быть достаточно

# %% [markdown]
# # проверка логики работы

# %%
# Функция для построения кривой
def simulate(start_price, end, high_board, low_board, hedge, earnings):
    a1 = unforward_earnings(start_price, end, high_board, low_board)
    a2 = earnings
    a3 = -hedge*(end - start_price)/start_price*100
    return a1+a2+a3

# %% [markdown]
# ### новая схема, проверка симметрии(еще раз проверим, что все симметрично, не смотря на уход части средств в хедж) Спойлер - все симметрично, просто доходность падает пропорционально тому, сколько средств ушло в хедж (они не работают)

# %%
def new_simulate(current_amount, start_price, end_price, high_board, low_board,  earnings):
    ratio_hedge = calc_ratio(start_price, high_board, low_board)
    eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
    usd_pool = current_amount - 2*eth_pool
    usd_hedge = eth_pool

    # Получим непрямые прибыли/убытки от пула в процентах
    e1 = unforward_earnings(start_price, end_price, high_board, low_board)
    e1 = e1/100*(eth_pool+usd_pool) # переведем в деньги: прибыль

    # получим прибыль/убыток от хеджа
    e2 = simple_hedge(start_price, end_price, ratio_hedge)
    # небольшой костыль, чтобы вернуться просто к процентам от хеджа
    e2 = e2/(100*ratio_hedge)
    e2 = usd_hedge*e2  # переведем в доллары

    # получим прибыль от стейкинга
    e3 = earnings
    e3 = e3/100 # уход от %
    e3 = (eth_pool+usd_pool)*e3# переведем в деньги
    # суммируем прибыли и изначальную сумму
    earn = e1 + e2 + e3 + current_amount
    return (earn-current_amount)/current_amount*100

# %% [markdown]
# ### Сравним поведение при широком и узком интервале (доходности заданы как 0.5 и 0.25%)

# %%
current_amount = 10000
start_price = 1222
high_board_wide = 1340
low_board_wide = 1100
high_board = 1260
low_board = 1195
earnings_wide = 0.25
earnings = 0.5

# %%
end_prises = list(range(1000,1400))
list2 = list(map((lambda x: new_simulate(current_amount, start_price, x, high_board, low_board, earnings)), end_prises))
list3 = list(map((lambda x: (x-start_price)/start_price*100), end_prises))
list5 = list(map((lambda x: new_simulate(current_amount, start_price, x, high_board_wide, low_board_wide, earnings_wide)), end_prises))

# %%
plt.figure(figsize=(10,10))
plt.plot(list3, list2, label='new')
plt.plot(list3, list5, label='new_wide')
# plt.plot(list3, list4, label='old')
plt.plot(list3, list3, label='ladder')
plt.plot([0, 0], [-20, 20], c='black')
plt.plot([-20, 20], [0, 0], c='black')
plt.xlabel('изменение цены в %', fontsize=15)
plt.ylabel('доходность в %', fontsize=15)
plt.ylim([-10, 10])
plt.xlim([-20, 20])
plt.legend(prop={'size':15})

# %% [markdown]
# #### Вывод - широкий интервалл более вытянутый, но не такой доходный в горбе, ожидаемый результат

# %% [markdown]
# #### Сравним с тем, что было раньше - когда фьючерсы были бесплатные

# %%
# тут требуется вводить хедж
hedge = 0.57

# %%
list4 = list(map((lambda x: simulate(start_price, x, high_board, low_board, hedge, earnings)), end_prises))

# %%
plt.figure(figsize=(10,10))
plt.plot(list3, list2, label='new')
plt.plot(list3, list4, label='old')
plt.plot(list3, list3, label='ladder')
plt.plot([0, 0], [-20, 20], c='black')
plt.plot([-20, 20], [0, 0], c='black')
plt.xlabel('изменение цены в %', fontsize=15)
plt.ylabel('доходность в %', fontsize=15)
plt.ylim([-10, 10])
plt.xlim([-20, 20])
plt.legend(prop={'size':15})

# %%
хедж
        пул usd
        pool eth
при движении на +5%, в пуле +3% хедж -5%

# %% [markdown]
# ##### Вывод, бесплатные фьючерсы конечно приносят большую дохоность при низкой волотильности, однако несут бОльшие убытки при резком изменении цены.

# %% [markdown]
# # Прогнозы в реальном времени

# %% [markdown]
# ###  Функции и зависимости

# %%
from datetime import datetime, timedelta
def dataset_for_current_pred(symbol = 'ETHUSDT'):
  '''Функция возвращает последние доступные данные'''
  api_key = ""
  api_secret = ""
  client = Client(api_key, api_secret)
  current_date = datetime.now().strftime("%d-%m-%Y")
  yesterday = (datetime.now()+timedelta(days=-1)).strftime("%d/%m/%Y")
  tommorow = (datetime.now()+timedelta(days=+1)).strftime("%d/%m/%Y") 

  fromDate = str(datetime.strptime(yesterday, '%d/%m/%Y'))
  toDate = str(datetime.strptime(tommorow, '%d/%m/%Y'))
  symbol = symbol
  interval = Client.KLINE_INTERVAL_5MINUTE
  # посколько реализована подгрузка начиная со вчерашнего дня, разумно обрезать датасет 24 часами 24*60=1440
  df = GetHistoricalData(symbol, interval, fromDate, toDate)[-288:] 
  return df

def bootstrap(mass, n_forcast, intervals_in_hour):
    '''Функция бутстрэпит изменения за прошедшие часы (это длина массива) n_forcast*intervals_in_hour раз, 
    процедура повторяется 10000 раз, в резульатате мы перемножеаем значения и выдаем прогноз в каждой точке таким образом (10000 симуляций)'''
    mass_res = np.zeros((10000, 2)) # 2 - нижняя и верхняя границы для каждой симуляции
    mass = np.array(mass) # переводим в numpy
    n = len(mass) # длина выборки для обучения
    size_forecast = n_forcast*intervals_in_hour
    # случайно берем числа до n, размера n_forcast*intervals_in_hour
    indexes = np.random.randint(n, size=size_forecast*10000)
    change = mass[[indexes]]
    change = change.reshape((10000, size_forecast))
    # теперь рассомтрим куммулятивное перемножение- предсказанное поведение
    cum_change = np.cumprod(change, axis=1)
    # минимальное и максимальные значения внутри временного интервалла
    min_ = np.min(cum_change, axis=1)
    max_ = np.max(cum_change, axis=1)
    sorted_res_min = np.sort(min_)
    sorted_res_max = np.sort(max_)
    #######################
    high, low = sorted_res_max[9500], sorted_res_min[500]
    return np.array([high, low])
def make_new_col(df):
    '''Потребуются относительные изменения'''
    print('Добавляю относительные изменения')
    mass = np.zeros(len(df))
    mass[0] = 1 # первую точку доопределяем 1
    values = df['open'].values.astype(float)
    for i in range(1, len(df)):
        mass[i] = values[i]/values[i-1]
        df['change'] = mass
    return df

def calc_ratio(start_price, high_board, low_board):
    return (high_board-start_price)/(high_board-low_board)

# %% [markdown]
# ### Требуется ввести сумму средств

# %%
# требуется ввести сумму средств
current_amount = 10000
n_forcast, intervals_in_hour = 24, 12

# %% [markdown]
# ### Запускаем расчет

# %%
#Получаем данные
df_current = dataset_for_current_pred()

# Добавляем новую колонку
df_current = make_new_col(df_current)

# требуется для абсолютных значений запомнить текущую
current_value = df_current['open'].values.astype(float)[-1]
# Рассчитываем сам интервал
res_interval = bootstrap(df_current['change'].values, n_forcast=24, intervals_in_hour=60)*current_value

# рассчитываем ratio_hedge
start_price = current_value
high_board = res_interval[0]
low_board = res_interval[1]

ratio_hedge = calc_ratio(start_price, high_board, low_board)

eth_pool = ratio_hedge*current_amount/(1+ratio_hedge)
usd_pool = current_amount - 2*eth_pool
usd_hedge = eth_pool
print('Распределение средств в долларах')
print('Сумма эфира(в usdt) в пул', eth_pool)
print('Сумма usdt в пул', usd_pool)
print('Покупка фьючерса ',usd_hedge)
# Out:
# Добавляю относительные изменения
# Распределение средств в долларах
# Сумма эфира(в usdt) в пул 3270.4733744540904
# Сумма usdt в пул 3459.053251091819
# Покупка фьючерса  3270.4733744540904
# <ipython-input-704-ac082a017383>:28: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   change = mass[[indexes]]

# %%
res_interval
# Out:
# array([1344.12812009, 1116.64109348])

# %%
current_value
# Out:
# 1221.49
